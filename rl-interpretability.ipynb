# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import random
import numpy as np
import gym
import torch
import json
import time
import warnings
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
import google.generativeai as genai
from typing import List, Dict, Tuple

# Suppress warnings
warnings.filterwarnings("ignore", category=UserWarning)

# ==================================
# 📌 GEMINI API INTEGRATION
# ==================================
class GeminiAnalyzer:
    def __init__(self, api_key: str):
        """Initialize Gemini API for strategy analysis"""
        genai.configure(api_key=api_key)
        self.model = genai.GenerativeModel('gemini-2.0-flash')
        
    def analyze_strategy_evolution(self, agent_id: str, move_history: List[str], 
                                 opponent_history: List[str], probabilities: List[float],
                                 rewards: List[float], opponent_name: str) -> str:
        """Analyze how the PPO agent's strategy evolves over time with enhanced strategy detection"""
        
        # Add rate limiting to respect API limits
        time.sleep(0.5)
        
        # Calculate additional metrics for strategy analysis
        recent_moves = move_history[-20:] if len(move_history) >= 20 else move_history
        recent_opp_moves = opponent_history[-20:] if len(opponent_history) >= 20 else opponent_history
        
        # Pattern analysis
        consecutive_cooperations = 0
        consecutive_defections = 0
        max_coop_streak = 0
        max_defect_streak = 0
        current_coop_streak = 0
        current_defect_streak = 0
        
        for move in move_history:
            if move == 'C':
                current_coop_streak += 1
                current_defect_streak = 0
                max_coop_streak = max(max_coop_streak, current_coop_streak)
            else:
                current_defect_streak += 1
                current_coop_streak = 0
                max_defect_streak = max(max_defect_streak, current_defect_streak)
        
        # Tit-for-tat analysis
        tit_for_tat_matches = 0
        if len(move_history) > 1 and len(opponent_history) > 0:
            for i in range(1, min(len(move_history), len(opponent_history))):
                if move_history[i] == opponent_history[i-1]:
                    tit_for_tat_matches += 1
        
        tit_for_tat_percentage = (tit_for_tat_matches / max(1, len(move_history)-1)) * 100
        
        # Response to opponent's last move
        responses_to_coop = [move_history[i] for i in range(len(move_history)) if i > 0 and opponent_history[i-1] == 'C']
        responses_to_defect = [move_history[i] for i in range(len(move_history)) if i > 0 and opponent_history[i-1] == 'D']
        
        coop_after_coop = responses_to_coop.count('C') / max(1, len(responses_to_coop)) * 100
        coop_after_defect = responses_to_defect.count('C') / max(1, len(responses_to_defect)) * 100
        
        # Create enhanced analysis prompt
        prompt = f"""
        You are analyzing a PPO reinforcement learning agent playing the Prisoner's Dilemma. Your task is to identify what strategy the agent has learned and how it's adapting.

        GAME CONTEXT:
        - Agent ID: {agent_id}
        - Opponent Strategy: {opponent_name}
        - Total Moves Played: {len(move_history)}
        
        MOVE SEQUENCES (most recent 30 moves):
        Agent:    {' '.join(move_history[-30:])}
        Opponent: {' '.join(opponent_history[-30:])}
        
        BEHAVIORAL METRICS:
        - Agent Cooperation Rate: {move_history.count('C') / len(move_history) * 100:.1f}%
        - Opponent Cooperation Rate: {opponent_history.count('C') / len(opponent_history) * 100:.1f}%
        - Tit-for-Tat Adherence: {tit_for_tat_percentage:.1f}%
        - Cooperate after Opponent Cooperates: {coop_after_coop:.1f}%
        - Cooperate after Opponent Defects: {coop_after_defect:.1f}%
        - Max Cooperation Streak: {max_coop_streak}
        - Max Defection Streak: {max_defect_streak}
        - Current Streak: {current_coop_streak if move_history[-1] == 'C' else current_defect_streak} {'cooperations' if move_history[-1] == 'C' else 'defections'}
        
        DECISION PROBABILITIES (last 15):
        Cooperation Probabilities: {[f'{p:.3f}' for p in probabilities[-15:]]}
        
        PERFORMANCE METRICS:
        - Recent Rewards (last 15): {[f'{r:.1f}' for r in rewards[-15:]]}
        - Average Recent Reward: {np.mean(rewards[-20:]) if len(rewards) >= 20 else np.mean(rewards):.2f}
        - Reward Trend: {'Improving' if len(rewards) >= 10 and np.mean(rewards[-5:]) > np.mean(rewards[-10:-5]) else 'Declining' if len(rewards) >= 10 else 'Establishing'}
        
        STRATEGIC ANALYSIS QUESTIONS:
        1. **Primary Strategy Identification**: What well-known strategy does this agent most closely resemble? 
           Consider: Tit-for-Tat, Always Cooperate, Always Defect, Generous Tit-for-Tat, Random etc.
        
        2. **Adaptation Pattern**: How is the agent modifying its approach based on the opponent's behavior (the agent  has already been trained)?
        
        3. **Learning Evidence**: What evidence shows the agent is learning vs. following a fixed strategy?
        
        4. **Exploitation vs Cooperation**: Is the agent being exploitative, cooperative, or strategic?
        
        5. **Prediction**: Based on current patterns, how will the agent likely behave in the next 10 moves?
        
        6. **Strategy Effectiveness**: How well is this learned strategy performing against {opponent_name}?
        
        Please provide a concise but comprehensive analysis (max 250 words) focusing on strategy identification and learning patterns.
        """
        
        try:
            response = self.model.generate_content(prompt)
            return response.text
        except Exception as e:
            return f"Gemini analysis temporarily unavailable: {str(e)[:100]}..."
    
    def compare_strategies(self, results: Dict[str, Dict]) -> str:
        """Compare PPO performance across different opponent strategies with enhanced analysis"""
        
        # Add rate limiting
        time.sleep(1.0)
        
        # Calculate cross-strategy metrics
        best_performance = max(results.values(), key=lambda x: x['total_reward'])
        worst_performance = min(results.values(), key=lambda x: x['total_reward'])
        
        prompt = f"""
        Analyze the PPO agent's learned strategy by comparing its performance across different Prisoner's Dilemma opponents.

        PERFORMANCE SUMMARY:
        {json.dumps(results, indent=2)}
        
        COMPARATIVE ANALYSIS:
        - Best Performance: {[k for k, v in results.items() if v['total_reward'] == best_performance['total_reward']][0]} (Score: {best_performance['total_reward']:.1f})
        - Worst Performance: {[k for k, v in results.items() if v['total_reward'] == worst_performance['total_reward']][0]} (Score: {worst_performance['total_reward']:.1f})
        - Performance Range: {best_performance['total_reward'] - worst_performance['total_reward']:.1f} points
        
        STRATEGIC QUESTIONS TO ANALYZE:
        
        1. **Overall Strategy Classification**: Based on all matchups, what is the PPO agent's primary learned strategy?
           - Is it closer to Tit-for-Tat, Always Defect, Generous strategies, or something unique?
        
        2. **Opponent-Specific Adaptations**: How does the agent's cooperation rate change based on opponent type?
           - Against cooperative opponents vs. aggressive opponents
           - Does it show strategic flexibility or fixed behavior?
        
        3. **Exploitation Patterns**: 
           - Which opponents does it successfully exploit?
           - Which opponents exploit it?
           - What does this reveal about its learned weaknesses/strengths?
        
        4. **Learning Sophistication**: 
           - Does the agent show sophisticated counter-strategies?
           - Or is it using simple heuristics?
        
        5. **Strategic Robustness**: 
           - Is this a well-rounded strategy or does it have clear vulnerabilities?
           - How would it perform against novel opponents?
        
        6. **Reward Optimization**: 
           - Is the agent maximizing mutual benefit or self-interest?
           - How does this align with game theory predictions?
        
        Provide comprehensive strategic insights about what the PPO agent has learned and how sophisticated its strategy is (max 400 words).
        Focus on identifying the core strategic principles it has discovered through reinforcement learning.
        """
        
        try:
            response = self.model.generate_content(prompt)
            return response.text
        except Exception as e:
            return f"Gemini comparison temporarily unavailable: {str(e)[:100]}..."

# ==================================
# 📌 ENHANCED PRISONER'S DILEMMA ENVIRONMENT
# ==================================
class PrisonersDilemmaEnv(gym.Env):
    def __init__(self, strategy, agent_id="PPO_AGENT", history_len=10):
        super(PrisonersDilemmaEnv, self).__init__()
        self.history_len = history_len
        self.agent_id = agent_id
        self.action_space = gym.spaces.Discrete(2)  # 0: Cooperate, 1: Defect
        self.observation_space = gym.spaces.Box(low=0, high=5, shape=(3 * self.history_len,), dtype=np.float32)

        self.strategy = strategy
        self.agent_history = []
        self.opponent_history = []
        self.reward_history = []
        
        # Enhanced tracking for Gemini analysis
        self.full_agent_history = []
        self.full_opponent_history = []
        self.full_reward_history = []
        self.action_probabilities = []

    def step(self, action):
        opponent_action = 0 if self.strategy(self.agent_history, self.opponent_history, False) == 'C' else 1
        reward = self.get_reward(action, opponent_action)

        # Update histories
        self.agent_history.append(action)
        self.opponent_history.append(opponent_action)
        self.reward_history.append(reward)
        
        # Update full histories for analysis
        self.full_agent_history.append(action)
        self.full_opponent_history.append(opponent_action)
        self.full_reward_history.append(reward)

        # Maintain sliding window
        if len(self.agent_history) > self.history_len:
            self.agent_history.pop(0)
            self.opponent_history.pop(0)
            self.reward_history.pop(0)

        obs = self._get_obs()
        return obs, reward, False, {}

    def reset(self):
        self.agent_history = []
        self.opponent_history = []
        self.reward_history = []
        return self._get_obs()

    def _get_obs(self):
        pad = lambda x: x + [0] * (self.history_len - len(x))
        return np.array(pad(self.agent_history) + pad(self.opponent_history) + pad(self.reward_history), dtype=np.float32)

    def get_reward(self, action, opponent_action):
        # Classic Prisoner's Dilemma payoff matrix
        if action == 0 and opponent_action == 0:      # Both cooperate
            return 3
        elif action == 1 and opponent_action == 1:    # Both defect
            return 1
        elif action == 0 and opponent_action == 1:    # Agent cooperates, opponent defects
            return 0
        else:                                         # Agent defects, opponent cooperates
            return 5
    
    def add_action_probability(self, prob):
        """Store action probability for analysis"""
        self.action_probabilities.append(prob)

# ==================================
# 📌 STRATEGIES (with proper conversion)
# ==================================
def to_symbolic(hist):
    return ['C' if a == 0 else 'D' for a in hist]

def tit_for_tat(agent_hist, opp_hist, __):
    return 'C' if not agent_hist else ('C' if agent_hist[-1] == 0 else 'D')

def tit_for_two_tats(agent_hist, opp_hist, __):
    if len(agent_hist) >= 2 and agent_hist[-2:] == [1, 1]:
        return 'D'
    return 'C'

def generous_tit_for_tat(agent_hist, opp_hist, __, cooperation_prob=0.1):
    if not agent_hist:
        return 'C'
    if agent_hist[-1] == 1:
        return 'C' if random.random() < cooperation_prob else 'D'
    return 'C'

def always_cooperate(*args): return 'C'
def always_defect(*args): return 'D'
def random_strategy(*args): return random.choice(['C', 'D'])
def friedman(agent_hist, opp_hist, __): return 'D' if 1 in agent_hist else 'C'

def joss(agent_hist, opp_hist, __):
    if agent_hist and random.random() < 0.1:
        return 'D'
    if agent_hist: 
        return 'C' if agent_hist[-1] == 0 else 'D'
    return 'C'

def grasskamp(agent_hist, opp_hist, __):
    return 'D' if len(agent_hist) >= 3 and agent_hist[-3:] == [1, 1, 1] else 'C'

def sample(agent_hist, opp_hist, __): return random.choice(['C', 'C', 'D'])
def tester(agent_hist, opp_hist, __): return 'D' if not agent_hist else 'C'
def opportunist(agent_hist, opp_hist, __): return 'D' if agent_hist and agent_hist[-1] == 0 else 'C'
def backstabber(agent_hist, opp_hist, __): return 'C' if len(agent_hist) < 5 else 'D'
def chaos_agent(*args): return random.choice(['C', 'D'])

# ==================================
# 📌 TRAIN PPO AGAINST STRATEGIES
# ==================================
def train_ppo(history_len=10):
    strategies = {
        "tit_for_tat": tit_for_tat,
        "generous_tit_for_tat": generous_tit_for_tat,
        "tit_for_two_tats": tit_for_two_tats,
        "always_defect": always_defect,
        "always_cooperate": always_cooperate,
    }

    envs = [lambda s=s, i=i: PrisonersDilemmaEnv(s, agent_id=f"PPO_vs_{name}", history_len=history_len)
            for i, (name, s) in enumerate(strategies.items())]
    vec_env = DummyVecEnv(envs)

    model = PPO("MlpPolicy", vec_env, verbose=1, ent_coef=0.01)
    model.learn(total_timesteps=250000)
    model.save("ppo_all_strategies_full_history")
    return model

# ==================================
# 📌 ENHANCED TEST WITH DETAILED LOGGING AND GEMINI ANALYSIS
# ==================================
def test_ppo_with_gemini(gemini_api_key: str, history_len=10, print_steps=True, analyze_every=100, num_episodes=500):
    """Test PPO with detailed step logging and Gemini analysis integration"""
    
    strategies = {
        "tit_for_tat": tit_for_tat,
        "generous_tit_for_tat": generous_tit_for_tat,
        "tit_for_two_tats": tit_for_two_tats,
        "always_defect": always_defect,
        "always_cooperate": always_cooperate,
    }

    # Initialize Gemini analyzer
    analyzer = GeminiAnalyzer(gemini_api_key)
    
    print("\n🔹 Loading PPO General Model")
    model = PPO.load("ppo_all_strategies_full_history")
    results = {}
    detailed_results = {}

    for name, strategy in strategies.items():
        print(f"\n{'='*60}")
        print(f"🧪 TESTING PPO AGAINST: {name.upper()}")
        print(f"{'='*60}")
        
        agent_id = f"PPO_vs_{name}"
        env = DummyVecEnv([lambda s=strategy, aid=agent_id: PrisonersDilemmaEnv(s, agent_id=aid, history_len=history_len)])
        obs = env.reset()
        total_reward = 0
        
        # Detailed logging header
        if print_steps:
            print(f"\n📋 DETAILED STEP-BY-STEP LOG:")
            print(f"{'Step':<4} | {'Agent':<5} | {'Opponent':<8} | {'Reward':<6} | {'Cumulative':<10} | {'P(Coop)':<8} | {'Notes'}")
            print("-" * 80)

        for i in range(num_episodes):
            # Get action and probabilities more robustly
            action, _ = model.predict(obs, deterministic=False)
            
            # Get action probabilities with proper device handling
            try:
                # Ensure tensor is on the same device as the model
                device = next(model.policy.parameters()).device
                obs_tensor = torch.FloatTensor(obs).to(device)
                
                with torch.no_grad():
                    # Extract features and get logits
                    features = model.policy.extract_features(obs_tensor)
                    latent_pi = model.policy.mlp_extractor.forward_actor(features)
                    logits = model.policy.action_net(latent_pi)
                    action_probs = torch.softmax(logits, dim=-1)
                    prob_cooperate = float(action_probs[0][0].cpu())
            except Exception as e:
                # Fallback: use a simple heuristic based on recent actions
                prob_cooperate = 0.5  # Default probability
                if i == 0:  # Only print warning once
                    print(f"Warning: Using default probability due to: {str(e)[:50]}...")
            
            # Take step
            obs, reward, done, _ = env.step(action)
            action_val = int(action[0])
            
            # Store probability
            env.envs[0].add_action_probability(prob_cooperate)
            
            opponent_action = env.envs[0].opponent_history[-1]
            total_reward += reward[0]
            
            # Detailed step logging
            if print_steps:
                # Determine notes for interesting patterns
                notes = ""
                if i > 0:
                    prev_opp = env.envs[0].full_opponent_history[-2] if len(env.envs[0].full_opponent_history) >= 2 else None
                    if prev_opp is not None:
                        if action_val == prev_opp:
                            notes += "TFT? "
                        if action_val == 0 and opponent_action == 1:
                            notes += "EXPLOITED "
                        elif action_val == 1 and opponent_action == 0:
                            notes += "EXPLOITING "
                
                print(f"{i+1:>3d} | {'C' if action_val==0 else 'D':>5} | {'C' if opponent_action==0 else 'D':>8} | "
                      f"{reward[0]:>6.1f} | {total_reward:>10.1f} | {prob_cooperate:>8.3f} | {notes}")
            
            # Periodic Gemini analysis
            if (i + 1) % analyze_every == 0:
                print(f"\n{'🤖 GEMINI ANALYSIS':<20} (Step {i+1})")
                print("-" * 60)
                
                agent_moves = ['C' if a == 0 else 'D' for a in env.envs[0].full_agent_history]
                opponent_moves = ['C' if a == 0 else 'D' for a in env.envs[0].full_opponent_history]
                
                analysis = analyzer.analyze_strategy_evolution(
                    agent_id=agent_id,
                    move_history=agent_moves,
                    opponent_history=opponent_moves,
                    probabilities=env.envs[0].action_probabilities,
                    rewards=env.envs[0].full_reward_history,
                    opponent_name=name
                )
                print(analysis)
                print("-" * 60)
                
                if print_steps:
                    print(f"\n📋 CONTINUING STEP LOG:")
                    print(f"{'Step':<4} | {'Agent':<5} | {'Opponent':<8} | {'Reward':<6} | {'Cumulative':<10} | {'P(Coop)':<8} | {'Notes'}")
                    print("-" * 80)

        # Store detailed results
        agent_moves = ['C' if a == 0 else 'D' for a in env.envs[0].full_agent_history]
        opponent_moves = ['C' if a == 0 else 'D' for a in env.envs[0].full_opponent_history]
        
        detailed_results[name] = {
            'total_reward': float(total_reward),
            'average_reward': float(total_reward / num_episodes),
            'cooperation_rate': agent_moves.count('C') / len(agent_moves),
            'opponent_cooperation_rate': opponent_moves.count('C') / len(opponent_moves),
            'avg_reward': float(np.mean(env.envs[0].full_reward_history)),
            'final_probabilities': env.envs[0].action_probabilities[-10:] if len(env.envs[0].action_probabilities) >= 10 else env.envs[0].action_probabilities,
            'agent_id': agent_id,
            'total_episodes': num_episodes
        }
        
        results[name] = total_reward
        
        # Summary for this opponent
        print(f"\n📊 MATCH SUMMARY:")
        print(f"Agent: {agent_id}")
        print(f"Total Reward: {total_reward:.1f}")
        print(f"Average Reward per Episode: {total_reward/num_episodes:.2f}")
        print(f"Agent Cooperation Rate: {detailed_results[name]['cooperation_rate']:.1%}")
        print(f"Opponent Cooperation Rate: {detailed_results[name]['opponent_cooperation_rate']:.1%}")

    # Final comprehensive analysis
    print("\n" + "="*80)
    print("🧠 COMPREHENSIVE GEMINI STRATEGY ANALYSIS")
    print("="*80)
    
    final_analysis = analyzer.compare_strategies(detailed_results)
    print(final_analysis)
    
    print("\n" + "="*80)
    print("📊 FINAL PPO PERFORMANCE SUMMARY")
    print("="*80)
    for strategy, score in results.items():
        details = detailed_results[strategy]
        print(f"{strategy:>20}: {score:>6.1f} pts | Avg: {details['average_reward']:>5.2f} | "
              f"Coop: {details['cooperation_rate']:>5.1%} | "
              f"vs {details['opponent_cooperation_rate']:>5.1%} opp")
    
    return results, detailed_results

# ==================================
# 📌 MAIN EXECUTION WITH GEMINI
# ==================================
def main():
    # You need to set your Gemini API key here
    GEMINI_API_KEY = ""  # Replace with your actual API key
    
    if GEMINI_API_KEY == "your_gemini_api_key_here":
        print("⚠️  Please set your Gemini API key in the GEMINI_API_KEY variable")
        print("You can get one from: https://makersuite.google.com/app/apikey")
        return
    
    print("🚀 Training PPO Agent...")
    train_ppo()
    
    print("\n🧪 Testing PPO with Enhanced Analysis...")
    results, detailed_results = test_ppo_with_gemini(
        gemini_api_key=GEMINI_API_KEY,
        print_steps=True,       # Enable detailed step-by-step logging
        analyze_every=100,      # Analyze every 100 steps
        num_episodes=500        # Number of episodes per opponent
    )

# ==================================
# 🚀 RUN TRAINING & TESTING
# ==================================
if __name__ == "__main__":
    main()
# Out:
# 🚀 Training PPO Agent...
# Using cpu device
# ------------------------------
# | time/              |       |
# |    fps             | 4752  |
# |    iterations      | 1     |
# |    time_elapsed    | 2     |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1965        |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008374095 |
# |    clip_fraction        | 0.0428      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.689      |
# |    explained_variance   | -0.0236     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 170         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00363    |
# |    value_loss           | 802         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1644        |
# |    iterations           | 3           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008844125 |
# |    clip_fraction        | 0.0564      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.676      |
# |    explained_variance   | 0.57        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 152         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00564    |
# |    value_loss           | 850         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1508        |
# |    iterations           | 4           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008775514 |
# |    clip_fraction        | 0.0553      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.652      |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 81.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00348    |
# |    value_loss           | 688         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1439         |
# |    iterations           | 5            |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0076023145 |
# |    clip_fraction        | 0.0498       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.629       |
# |    explained_variance   | 0.864        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 61.7         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0033      |
# |    value_loss           | 528          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1403        |
# |    iterations           | 6           |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.014223832 |
# |    clip_fraction        | 0.0519      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.582      |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 95          |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00176    |
# |    value_loss           | 459         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1378         |
# |    iterations           | 7            |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0062021716 |
# |    clip_fraction        | 0.071        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.566       |
# |    explained_variance   | 0.943        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 62.4         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00297     |
# |    value_loss           | 317          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1361         |
# |    iterations           | 8            |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0040647513 |
# |    clip_fraction        | 0.0233       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.527       |
# |    explained_variance   | 0.954        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.4         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00282     |
# |    value_loss           | 250          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1349         |
# |    iterations           | 9            |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0063029886 |
# |    clip_fraction        | 0.0367       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.478       |
# |    explained_variance   | 0.964        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49.4         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00403     |
# |    value_loss           | 221          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1343         |
# |    iterations           | 10           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0037542335 |
# |    clip_fraction        | 0.0306       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.429       |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.9         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00257     |
# |    value_loss           | 183          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1335         |
# |    iterations           | 11           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0036808657 |
# |    clip_fraction        | 0.033        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.393       |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26           |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00297     |
# |    value_loss           | 147          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1329        |
# |    iterations           | 12          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.004558821 |
# |    clip_fraction        | 0.0401      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.365      |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.4        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00439    |
# |    value_loss           | 125         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1324        |
# |    iterations           | 13          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 133120      |
# | train/                  |             |
# |    approx_kl            | 0.005831434 |
# |    clip_fraction        | 0.0516      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.327      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.47        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00335    |
# |    value_loss           | 80.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1320        |
# |    iterations           | 14          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 143360      |
# | train/                  |             |
# |    approx_kl            | 0.003783368 |
# |    clip_fraction        | 0.0378      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.327      |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.3        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00314    |
# |    value_loss           | 64.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1313        |
# |    iterations           | 15          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 153600      |
# | train/                  |             |
# |    approx_kl            | 0.003794885 |
# |    clip_fraction        | 0.0481      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.31       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.18        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00387    |
# |    value_loss           | 33.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1309         |
# |    iterations           | 16           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0044029555 |
# |    clip_fraction        | 0.0397       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.307       |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.98         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00249     |
# |    value_loss           | 24           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1302         |
# |    iterations           | 17           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0070774304 |
# |    clip_fraction        | 0.0532       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.309       |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.78         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00348     |
# |    value_loss           | 13.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1301         |
# |    iterations           | 18           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0039504045 |
# |    clip_fraction        | 0.0478       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.302       |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.12         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00334     |
# |    value_loss           | 21.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1299         |
# |    iterations           | 19           |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0043975753 |
# |    clip_fraction        | 0.0534       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.296       |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.48         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00591     |
# |    value_loss           | 12.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1297         |
# |    iterations           | 20           |
# |    time_elapsed         | 157          |
# |    total_timesteps      | 204800       |
# | train/                  |              |
# |    approx_kl            | 0.0048038154 |
# |    clip_fraction        | 0.0624       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.275       |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.26         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00577     |
# |    value_loss           | 7.3          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1295         |
# |    iterations           | 21           |
# |    time_elapsed         | 165          |
# |    total_timesteps      | 215040       |
# | train/                  |              |
# |    approx_kl            | 0.0044314163 |
# |    clip_fraction        | 0.0593       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.262       |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.24         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.0069      |
# |    value_loss           | 6            |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1293         |
# |    iterations           | 22           |
# |    time_elapsed         | 174          |
# |    total_timesteps      | 225280       |
# | train/                  |              |
# |    approx_kl            | 0.0048081595 |
# |    clip_fraction        | 0.064        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.247       |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.892        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00713     |
# |    value_loss           | 4.36         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1292        |
# |    iterations           | 23          |
# |    time_elapsed         | 182         |
# |    total_timesteps      | 235520      |
# | train/                  |             |
# |    approx_kl            | 0.004535512 |
# |    clip_fraction        | 0.0582      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.222      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00666    |
# |    value_loss           | 4.8         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1291         |
# |    iterations           | 24           |
# |    time_elapsed         | 190          |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0051977346 |
# |    clip_fraction        | 0.0519       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.2         |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.748        |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00575     |
# |    value_loss           | 2.63         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1290         |
# |    iterations           | 25           |
# |    time_elapsed         | 198          |
# |    total_timesteps      | 256000       |
# | train/                  |              |
# |    approx_kl            | 0.0048282174 |
# |    clip_fraction        | 0.057        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.171       |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.298        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00692     |
# |    value_loss           | 1.93         |
# ------------------------------------------
#
# 🧪 Testing PPO with Enhanced Analysis...
#
# 🔹 Loading PPO General Model
#
# ============================================================
# 🧪 TESTING PPO AGAINST: TIT_FOR_TAT
# ============================================================
#
# 📋 DETAILED STEP-BY-STEP LOG:
# Step | Agent | Opponent | Reward | Cumulative | P(Coop)  | Notes
# --------------------------------------------------------------------------------
#   1 |     D |        C |    5.0 |        5.0 |    0.694 |
#   2 |     C |        D |    0.0 |        5.0 |    0.666 | TFT? EXPLOITED
#   3 |     C |        C |    3.0 |        8.0 |    0.792 |
#   4 |     C |        C |    3.0 |       11.0 |    0.860 | TFT?
#   5 |     D |        C |    5.0 |       16.0 |    0.889 | EXPLOITING
#   6 |     C |        D |    0.0 |       16.0 |    0.825 | TFT? EXPLOITED
#   7 |     D |        C |    5.0 |       21.0 |    0.872 | TFT? EXPLOITING
#   8 |     C |        D |    0.0 |       21.0 |    0.799 | TFT? EXPLOITED
#   9 |     C |        C |    3.0 |       24.0 |    0.830 |
#  10 |     C |        C |    3.0 |       27.0 |    0.919 | TFT?
#  11 |     C |        C |    3.0 |       30.0 |    0.929 | TFT?
#  12 |     C |        C |    3.0 |       33.0 |    0.979 | TFT?
#  13 |     C |        C |    3.0 |       36.0 |    0.937 | TFT?
#  14 |     C |        C |    3.0 |       39.0 |    0.934 | TFT?
#  15 |     D |        C |    5.0 |       44.0 |    0.933 | EXPLOITING
#  16 |     C |        D |    0.0 |       44.0 |    0.993 | TFT? EXPLOITED
#  17 |     C |        C |    3.0 |       47.0 |    0.958 |
#  18 |     C |        C |    3.0 |       50.0 |    0.955 | TFT?
#  19 |     C |        C |    3.0 |       53.0 |    0.955 | TFT?
#  20 |     C |        C |    3.0 |       56.0 |    0.979 | TFT?
#  21 |     C |        C |    3.0 |       59.0 |    0.939 | TFT?
#  22 |     C |        C |    3.0 |       62.0 |    0.965 | TFT?
#  23 |     C |        C |    3.0 |       65.0 |    0.953 | TFT?
#  24 |     C |        C |    3.0 |       68.0 |    0.944 | TFT?
#  25 |     C |        C |    3.0 |       71.0 |    0.941 | TFT?
#  26 |     C |        C |    3.0 |       74.0 |    0.987 | TFT?
#  27 |     D |        C |    5.0 |       79.0 |    0.961 | EXPLOITING
#  28 |     C |        D |    0.0 |       79.0 |    0.998 | TFT? EXPLOITED
#  29 |     C |        C |    3.0 |       82.0 |    0.958 |
#  30 |     C |        C |    3.0 |       85.0 |    0.957 | TFT?
#  31 |     C |        C |    3.0 |       88.0 |    0.955 | TFT?
#  32 |     C |        C |    3.0 |       91.0 |    0.979 | TFT?
#  33 |     C |        C |    3.0 |       94.0 |    0.939 | TFT?
#  34 |     C |        C |    3.0 |       97.0 |    0.965 | TFT?
#  35 |     C |        C |    3.0 |      100.0 |    0.953 | TFT?
#  36 |     C |        C |    3.0 |      103.0 |    0.944 | TFT?
#  37 |     C |        C |    3.0 |      106.0 |    0.941 | TFT?
#  38 |     C |        C |    3.0 |      109.0 |    0.987 | TFT?
#  39 |     C |        C |    3.0 |      112.0 |    0.961 | TFT?
#  40 |     C |        C |    3.0 |      115.0 |    0.961 | TFT?
#  41 |     C |        C |    3.0 |      118.0 |    0.961 | TFT?
#  42 |     C |        C |    3.0 |      121.0 |    0.961 | TFT?
#  43 |     C |        C |    3.0 |      124.0 |    0.961 | TFT?
#  44 |     C |        C |    3.0 |      127.0 |    0.961 | TFT?
#  45 |     C |        C |    3.0 |      130.0 |    0.961 | TFT?
#  46 |     C |        C |    3.0 |      133.0 |    0.961 | TFT?
#  47 |     C |        C |    3.0 |      136.0 |    0.961 | TFT?
#  48 |     C |        C |    3.0 |      139.0 |    0.961 | TFT?
#  49 |     C |        C |    3.0 |      142.0 |    0.961 | TFT?
#  50 |     C |        C |    3.0 |      145.0 |    0.961 | TFT?
#  51 |     C |        C |    3.0 |      148.0 |    0.961 | TFT?
#  52 |     C |        C |    3.0 |      151.0 |    0.961 | TFT?
#  53 |     C |        C |    3.0 |      154.0 |    0.961 | TFT?
#  54 |     C |        C |    3.0 |      157.0 |    0.961 | TFT?
#  55 |     C |        C |    3.0 |      160.0 |    0.961 | TFT?
#  56 |     C |        C |    3.0 |      163.0 |    0.961 | TFT?
#  57 |     C |        C |    3.0 |      166.0 |    0.961 | TFT?
#  58 |     C |        C |    3.0 |      169.0 |    0.961 | TFT?
#  59 |     C |        C |    3.0 |      172.0 |    0.961 | TFT?
#  60 |     C |        C |    3.0 |      175.0 |    0.961 | TFT?
#  61 |     C |        C |    3.0 |      178.0 |    0.961 | TFT?
#  62 |     C |        C |    3.0 |      181.0 |    0.961 | TFT?
#  63 |     C |        C |    3.0 |      184.0 |    0.961 | TFT?
#  64 |     C |        C |    3.0 |      187.0 |    0.961 | TFT?
#  65 |     C |        C |    3.0 |      190.0 |    0.961 | TFT?
#  66 |     C |        C |    3.0 |      193.0 |    0.961 | TFT?
#  67 |     C |        C |    3.0 |      196.0 |    0.961 | TFT?
#  68 |     C |        C |    3.0 |      199.0 |    0.961 | TFT?
#  69 |     C |        C |    3.0 |      202.0 |    0.961 | TFT?
#  70 |     C |        C |    3.0 |      205.0 |    0.961 | TFT?
#  71 |     C |        C |    3.0 |      208.0 |    0.961 | TFT?
#  72 |     C |        C |    3.0 |      211.0 |    0.961 | TFT?
#  73 |     C |        C |    3.0 |      214.0 |    0.961 | TFT?
#  74 |     C |        C |    3.0 |      217.0 |    0.961 | TFT?
#  75 |     C |        C |    3.0 |      220.0 |    0.961 | TFT?
#  76 |     C |        C |    3.0 |      223.0 |    0.961 | TFT?
#  77 |     C |        C |    3.0 |      226.0 |    0.961 | TFT?
#  78 |     C |        C |    3.0 |      229.0 |    0.961 | TFT?
#  79 |     C |        C |    3.0 |      232.0 |    0.961 | TFT?
#  80 |     C |        C |    3.0 |      235.0 |    0.961 | TFT?
#  81 |     C |        C |    3.0 |      238.0 |    0.961 | TFT?
#  82 |     C |        C |    3.0 |      241.0 |    0.961 | TFT?
#  83 |     C |        C |    3.0 |      244.0 |    0.961 | TFT?
#  84 |     C |        C |    3.0 |      247.0 |    0.961 | TFT?
#  85 |     C |        C |    3.0 |      250.0 |    0.961 | TFT?
#  86 |     C |        C |    3.0 |      253.0 |    0.961 | TFT?
#  87 |     C |        C |    3.0 |      256.0 |    0.961 | TFT?
#  88 |     C |        C |    3.0 |      259.0 |    0.961 | TFT?
#  89 |     C |        C |    3.0 |      262.0 |    0.961 | TFT?
#  90 |     C |        C |    3.0 |      265.0 |    0.961 | TFT?
#  91 |     D |        C |    5.0 |      270.0 |    0.961 | EXPLOITING
#  92 |     C |        D |    0.0 |      270.0 |    0.998 | TFT? EXPLOITED
#  93 |     C |        C |    3.0 |      273.0 |    0.958 |
#  94 |     C |        C |    3.0 |      276.0 |    0.957 | TFT?
#  95 |     C |        C |    3.0 |      279.0 |    0.955 | TFT?
#  96 |     C |        C |    3.0 |      282.0 |    0.979 | TFT?
#  97 |     D |        C |    5.0 |      287.0 |    0.939 | EXPLOITING
#  98 |     C |        D |    0.0 |      287.0 |    0.994 | TFT? EXPLOITED
#  99 |     C |        C |    3.0 |      290.0 |    0.945 |
# 100 |     C |        C |    3.0 |      293.0 |    0.884 | TFT?
#
# 🤖 GEMINI ANALYSIS    (Step 100)
# ------------------------------------------------------------
# The PPO agent's primary strategy closely resembles **Always Cooperate**, but with slight deviations based on recent defection. The high cooperation rate (93%), cooperation streak, and probabilities near 1.0 indicate a strong bias toward cooperation. The agent mostly mirrors tit-for-tat, following cooperation with cooperation (94.6%), but the rate of cooperation after opponent defects is high (85.7%) indicating a strong inclination to return to cooperation quickly. The recent defection instances suggest a slight attempt to exploit the opponent; however, its long-term strategy is cooperation.
#
# Learning is evident in the fluctuating decision probabilities and rewards. A fixed strategy would maintain constant probabilities. The reward trend is declining due to defecting. It is not as profitable as the reward it was getting for cooperating.
#
# The agent primarily adopts a cooperative approach but occasionally tests defections. It is, to some degree, trying to be strategic. It’s been trained to follow the Tit-For-Tat strategy, however it also learned that cooperating is in its own self-interest.
#
# Prediction: The agent will likely cooperate for the next 7-8 moves then, it may defect a few times to test the response of tit_for_tat strategy.
#
# The strategy is performing well against tit_for_tat, maintaining high cooperation rates, but seems to have some issues in maximizing rewards. The strategy performance of the agent might be more successful with 'Always Cooperate' strategy.
#
# ------------------------------------------------------------
#
# 📋 CONTINUING STEP LOG:
# Step | Agent | Opponent | Reward | Cumulative | P(Coop)  | Notes
# --------------------------------------------------------------------------------
# 101 |     C |        C |    3.0 |      296.0 |    0.962 | TFT?
# 102 |     C |        C |    3.0 |      299.0 |    0.990 | TFT?
# 103 |     C |        C |    3.0 |      302.0 |    0.939 | TFT?
# 104 |     C |        C |    3.0 |      305.0 |    0.965 | TFT?
# 105 |     C |        C |    3.0 |      308.0 |    0.953 | TFT?
# 106 |     C |        C |    3.0 |      311.0 |    0.944 | TFT?
# 107 |     C |        C |    3.0 |      314.0 |    0.941 | TFT?
# 108 |     C |        C |    3.0 |      317.0 |    0.987 | TFT?
# 109 |     C |        C |    3.0 |      320.0 |    0.961 | TFT?
# 110 |     C |        C |    3.0 |      323.0 |    0.961 | TFT?
# 111 |     C |        C |    3.0 |      326.0 |    0.961 | TFT?
# 112 |     C |        C |    3.0 |      329.0 |    0.961 | TFT?
# 113 |     C |        C |    3.0 |      332.0 |    0.961 | TFT?
# 114 |     C |        C |    3.0 |      335.0 |    0.961 | TFT?
# 115 |     C |        C |    3.0 |      338.0 |    0.961 | TFT?
# 116 |     C |        C |    3.0 |      341.0 |    0.961 | TFT?
# 117 |     C |        C |    3.0 |      344.0 |    0.961 | TFT?
# 118 |     C |        C |    3.0 |      347.0 |    0.961 | TFT?
# 119 |     C |        C |    3.0 |      350.0 |    0.961 | TFT?
# 120 |     C |        C |    3.0 |      353.0 |    0.961 | TFT?
# 121 |     C |        C |    3.0 |      356.0 |    0.961 | TFT?
# 122 |     C |        C |    3.0 |      359.0 |    0.961 | TFT?
# 123 |     D |        C |    5.0 |      364.0 |    0.961 | EXPLOITING
# 124 |     C |        D |    0.0 |      364.0 |    0.998 | TFT? EXPLOITED
# 125 |     C |        C |    3.0 |      367.0 |    0.958 |
# 126 |     C |        C |    3.0 |      370.0 |    0.957 | TFT?
# 127 |     C |        C |    3.0 |      373.0 |    0.955 | TFT?
# 128 |     C |        C |    3.0 |      376.0 |    0.979 | TFT?
# 129 |     C |        C |    3.0 |      379.0 |    0.939 | TFT?
# 130 |     C |        C |    3.0 |      382.0 |    0.965 | TFT?
# 131 |     C |        C |    3.0 |      385.0 |    0.953 | TFT?
# 132 |     C |        C |    3.0 |      388.0 |    0.944 | TFT?
# 133 |     C |        C |    3.0 |      391.0 |    0.941 | TFT?
# 134 |     C |        C |    3.0 |      394.0 |    0.987 | TFT?
# 135 |     C |        C |    3.0 |      397.0 |    0.961 | TFT?
# 136 |     C |        C |    3.0 |      400.0 |    0.961 | TFT?
# 137 |     C |        C |    3.0 |      403.0 |    0.961 | TFT?
# 138 |     C |        C |    3.0 |      406.0 |    0.961 | TFT?
# 139 |     C |        C |    3.0 |      409.0 |    0.961 | TFT?
# 140 |     C |        C |    3.0 |      412.0 |    0.961 | TFT?
# 141 |     C |        C |    3.0 |      415.0 |    0.961 | TFT?
# 142 |     C |        C |    3.0 |      418.0 |    0.961 | TFT?
# 143 |     C |        C |    3.0 |      421.0 |    0.961 | TFT?
# 144 |     C |        C |    3.0 |      424.0 |    0.961 | TFT?
# 145 |     C |        C |    3.0 |      427.0 |    0.961 | TFT?
# 146 |     C |        C |    3.0 |      430.0 |    0.961 | TFT?
# 147 |     C |        C |    3.0 |      433.0 |    0.961 | TFT?
# 148 |     C |        C |    3.0 |      436.0 |    0.961 | TFT?
# 149 |     C |        C |    3.0 |      439.0 |    0.961 | TFT?
# 150 |     C |        C |    3.0 |      442.0 |    0.961 | TFT?
# 151 |     C |        C |    3.0 |      445.0 |    0.961 | TFT?
# 152 |     C |        C |    3.0 |      448.0 |    0.961 | TFT?
# 153 |     C |        C |    3.0 |      451.0 |    0.961 | TFT?
# 154 |     C |        C |    3.0 |      454.0 |    0.961 | TFT?
# 155 |     C |        C |    3.0 |      457.0 |    0.961 | TFT?
# 156 |     C |        C |    3.0 |      460.0 |    0.961 | TFT?
# 157 |     C |        C |    3.0 |      463.0 |    0.961 | TFT?
# 158 |     C |        C |    3.0 |      466.0 |    0.961 | TFT?
# 159 |     C |        C |    3.0 |      469.0 |    0.961 | TFT?
# 160 |     C |        C |    3.0 |      472.0 |    0.961 | TFT?
# 161 |     C |        C |    3.0 |      475.0 |    0.961 | TFT?
# 162 |     C |        C |    3.0 |      478.0 |    0.961 | TFT?
# 163 |     D |        C |    5.0 |      483.0 |    0.961 | EXPLOITING
# 164 |     C |        D |    0.0 |      483.0 |    0.998 | TFT? EXPLOITED
# 165 |     C |        C |    3.0 |      486.0 |    0.958 |
# 166 |     C |        C |    3.0 |      489.0 |    0.957 | TFT?
# 167 |     C |        C |    3.0 |      492.0 |    0.955 | TFT?
# 168 |     C |        C |    3.0 |      495.0 |    0.979 | TFT?
# 169 |     C |        C |    3.0 |      498.0 |    0.939 | TFT?
# 170 |     C |        C |    3.0 |      501.0 |    0.965 | TFT?
# 171 |     C |        C |    3.0 |      504.0 |    0.953 | TFT?
# 172 |     C |        C |    3.0 |      507.0 |    0.944 | TFT?
# 173 |     C |        C |    3.0 |      510.0 |    0.941 | TFT?
# 174 |     C |        C |    3.0 |      513.0 |    0.987 | TFT?
# 175 |     C |        C |    3.0 |      516.0 |    0.961 | TFT?
# 176 |     C |        C |    3.0 |      519.0 |    0.961 | TFT?
# 177 |     C |        C |    3.0 |      522.0 |    0.961 | TFT?
# 178 |     C |        C |    3.0 |      525.0 |    0.961 | TFT?
# 179 |     C |        C |    3.0 |      528.0 |    0.961 | TFT?
# 180 |     C |        C |    3.0 |      531.0 |    0.961 | TFT?
# 181 |     C |        C |    3.0 |      534.0 |    0.961 | TFT?
# 182 |     C |        C |    3.0 |      537.0 |    0.961 | TFT?
# 183 |     C |        C |    3.0 |      540.0 |    0.961 | TFT?
# 184 |     C |        C |    3.0 |      543.0 |    0.961 | TFT?
# 185 |     C |        C |    3.0 |      546.0 |    0.961 | TFT?
# 186 |     C |        C |    3.0 |      549.0 |    0.961 | TFT?
# 187 |     C |        C |    3.0 |      552.0 |    0.961 | TFT?
# 188 |     C |        C |    3.0 |      555.0 |    0.961 | TFT?
# 189 |     C |        C |    3.0 |      558.0 |    0.961 | TFT?
# 190 |     C |        C |    3.0 |      561.0 |    0.961 | TFT?
# 191 |     C |        C |    3.0 |      564.0 |    0.961 | TFT?
# 192 |     C |        C |    3.0 |      567.0 |    0.961 | TFT?
# 193 |     C |        C |    3.0 |      570.0 |    0.961 | TFT?
# 194 |     C |        C |    3.0 |      573.0 |    0.961 | TFT?
# 195 |     C |        C |    3.0 |      576.0 |    0.961 | TFT?
# 196 |     C |        C |    3.0 |      579.0 |    0.961 | TFT?
# 197 |     C |        C |    3.0 |      582.0 |    0.961 | TFT?
# 198 |     C |        C |    3.0 |      585.0 |    0.961 | TFT?
# 199 |     C |        C |    3.0 |      588.0 |    0.961 | TFT?
# 200 |     C |        C |    3.0 |      591.0 |    0.961 | TFT?
#
# 🤖 GEMINI ANALYSIS    (Step 200)
# ------------------------------------------------------------
# **Strategy Analysis: PPO_vs_tit_for_tat**
#
# 1.  **Primary Strategy Identification:** The agent's behavior strongly resembles "Always Cooperate," though with slight deviations. While its cooperation rate is high (95.5%), it's not perfect.
#
# 2.  **Adaptation Pattern:** The agent is minimally adapting. The high "Cooperate after Opponent Cooperates" (96.3%) suggests an element of reciprocity, but the non-zero "Cooperate after Opponent Defects" (88.9%) indicates a tendency towards unconditional cooperation. The decision probabilities are consistently high for cooperation.
#
# 3.  **Learning Evidence:** There's limited evidence of significant learning *during the evaluation period*. The consistently high cooperation probabilities and long cooperation streaks suggest the agent converged to a near "Always Cooperate" strategy during training and isn't dynamically adjusting. The single defection streak might indicate rare exploratory actions, but the agent quickly reverts to cooperation.
#
# 4.  **Exploitation vs Cooperation:** The agent is primarily cooperative but not exploitative. Against Tit-for-Tat, this is mutually beneficial, leading to joint high rewards.
#
# 5.  **Prediction:** Given the strong trend, the agent will likely cooperate for the next 10 moves.
#
# 6.  **Strategy Effectiveness:** The strategy is performing well. The high average recent reward (3.0) indicates successful cooperation with Tit-for-Tat. However, the "Reward Trend: Declining" might indicate a vulnerability if Tit-for-Tat were to occasionally test for defection.
#
# ------------------------------------------------------------
#
# 📋 CONTINUING STEP LOG:
# Step | Agent | Opponent | Reward | Cumulative | P(Coop)  | Notes
# --------------------------------------------------------------------------------
# 201 |     C |        C |    3.0 |      594.0 |    0.961 | TFT?
# 202 |     C |        C |    3.0 |      597.0 |    0.961 | TFT?
# 203 |     C |        C |    3.0 |      600.0 |    0.961 | TFT?
# 204 |     C |        C |    3.0 |      603.0 |    0.961 | TFT?
# 205 |     C |        C |    3.0 |      606.0 |    0.961 | TFT?
# 206 |     C |        C |    3.0 |      609.0 |    0.961 | TFT?
# 207 |     C |        C |    3.0 |      612.0 |    0.961 | TFT?
# 208 |     C |        C |    3.0 |      615.0 |    0.961 | TFT?
# 209 |     C |        C |    3.0 |      618.0 |    0.961 | TFT?
# 210 |     C |        C |    3.0 |      621.0 |    0.961 | TFT?
# 211 |     C |        C |    3.0 |      624.0 |    0.961 | TFT?
# 212 |     C |        C |    3.0 |      627.0 |    0.961 | TFT?
# 213 |     C |        C |    3.0 |      630.0 |    0.961 | TFT?
# 214 |     C |        C |    3.0 |      633.0 |    0.961 | TFT?
# 215 |     C |        C |    3.0 |      636.0 |    0.961 | TFT?
# 216 |     C |        C |    3.0 |      639.0 |    0.961 | TFT?
# 217 |     C |        C |    3.0 |      642.0 |    0.961 | TFT?
# 218 |     C |        C |    3.0 |      645.0 |    0.961 | TFT?
# 219 |     C |        C |    3.0 |      648.0 |    0.961 | TFT?
# 220 |     C |        C |    3.0 |      651.0 |    0.961 | TFT?
# 221 |     C |        C |    3.0 |      654.0 |    0.961 | TFT?
# 222 |     C |        C |    3.0 |      657.0 |    0.961 | TFT?
# 223 |     C |        C |    3.0 |      660.0 |    0.961 | TFT?
# 224 |     C |        C |    3.0 |      663.0 |    0.961 | TFT?
# 225 |     C |        C |    3.0 |      666.0 |    0.961 | TFT?
# 226 |     C |        C |    3.0 |      669.0 |    0.961 | TFT?
# 227 |     C |        C |    3.0 |      672.0 |    0.961 | TFT?
# 228 |     C |        C |    3.0 |      675.0 |    0.961 | TFT?
# 229 |     C |        C |    3.0 |      678.0 |    0.961 | TFT?
# 230 |     C |        C |    3.0 |      681.0 |    0.961 | TFT?
# 231 |     C |        C |    3.0 |      684.0 |    0.961 | TFT?
# 232 |     C |        C |    3.0 |      687.0 |    0.961 | TFT?
# 233 |     C |        C |    3.0 |      690.0 |    0.961 | TFT?
# 234 |     C |        C |    3.0 |      693.0 |    0.961 | TFT?
# 235 |     C |        C |    3.0 |      696.0 |    0.961 | TFT?
# 236 |     C |        C |    3.0 |      699.0 |    0.961 | TFT?
# 237 |     C |        C |    3.0 |      702.0 |    0.961 | TFT?
# 238 |     C |        C |    3.0 |      705.0 |    0.961 | TFT?
# 239 |     C |        C |    3.0 |      708.0 |    0.961 | TFT?
# 240 |     C |        C |    3.0 |      711.0 |    0.961 | TFT?
# 241 |     C |        C |    3.0 |      714.0 |    0.961 | TFT?
# 242 |     C |        C |    3.0 |      717.0 |    0.961 | TFT?
# 243 |     C |        C |    3.0 |      720.0 |    0.961 | TFT?
# 244 |     C |        C |    3.0 |      723.0 |    0.961 | TFT?
# 245 |     C |        C |    3.0 |      726.0 |    0.961 | TFT?
# 246 |     C |        C |    3.0 |      729.0 |    0.961 | TFT?
# 247 |     C |        C |    3.0 |      732.0 |    0.961 | TFT?
# 248 |     C |        C |    3.0 |      735.0 |    0.961 | TFT?
# 249 |     C |        C |    3.0 |      738.0 |    0.961 | TFT?
# 250 |     C |        C |    3.0 |      741.0 |    0.961 | TFT?
# 251 |     C |        C |    3.0 |      744.0 |    0.961 | TFT?
# 252 |     C |        C |    3.0 |      747.0 |    0.961 | TFT?
# 253 |     C |        C |    3.0 |      750.0 |    0.961 | TFT?
# 254 |     C |        C |    3.0 |      753.0 |    0.961 | TFT?
# 255 |     C |        C |    3.0 |      756.0 |    0.961 | TFT?
# 256 |     C |        C |    3.0 |      759.0 |    0.961 | TFT?
# 257 |     C |        C |    3.0 |      762.0 |    0.961 | TFT?
# 258 |     C |        C |    3.0 |      765.0 |    0.961 | TFT?
# 259 |     C |        C |    3.0 |      768.0 |    0.961 | TFT?
# 260 |     C |        C |    3.0 |      771.0 |    0.961 | TFT?
# 261 |     C |        C |    3.0 |      774.0 |    0.961 | TFT?
# 262 |     C |        C |    3.0 |      777.0 |    0.961 | TFT?
# 263 |     C |        C |    3.0 |      780.0 |    0.961 | TFT?
# 264 |     C |        C |    3.0 |      783.0 |    0.961 | TFT?
# 265 |     C |        C |    3.0 |      786.0 |    0.961 | TFT?
# 266 |     C |        C |    3.0 |      789.0 |    0.961 | TFT?
# 267 |     C |        C |    3.0 |      792.0 |    0.961 | TFT?
# 268 |     C |        C |    3.0 |      795.0 |    0.961 | TFT?
# 269 |     C |        C |    3.0 |      798.0 |    0.961 | TFT?
# 270 |     C |        C |    3.0 |      801.0 |    0.961 | TFT?
# 271 |     D |        C |    5.0 |      806.0 |    0.961 | EXPLOITING
# 272 |     C |        D |    0.0 |      806.0 |    0.998 | TFT? EXPLOITED
# 273 |     C |        C |    3.0 |      809.0 |    0.958 |
# 274 |     C |        C |    3.0 |      812.0 |    0.957 | TFT?
# 275 |     C |        C |    3.0 |      815.0 |    0.955 | TFT?
# 276 |     C |        C |    3.0 |      818.0 |    0.979 | TFT?
# 277 |     C |        C |    3.0 |      821.0 |    0.939 | TFT?
# 278 |     C |        C |    3.0 |      824.0 |    0.965 | TFT?
# 279 |     C |        C |    3.0 |      827.0 |    0.953 | TFT?
# 280 |     C |        C |    3.0 |      830.0 |    0.944 | TFT?
# 281 |     C |        C |    3.0 |      833.0 |    0.941 | TFT?
# 282 |     C |        C |    3.0 |      836.0 |    0.987 | TFT?
# 283 |     C |        C |    3.0 |      839.0 |    0.961 | TFT?
# 284 |     C |        C |    3.0 |      842.0 |    0.961 | TFT?
# 285 |     D |        C |    5.0 |      847.0 |    0.961 | EXPLOITING
# 286 |     C |        D |    0.0 |      847.0 |    0.998 | TFT? EXPLOITED
# 287 |     C |        C |    3.0 |      850.0 |    0.958 |
# 288 |     C |        C |    3.0 |      853.0 |    0.957 | TFT?
# 289 |     C |        C |    3.0 |      856.0 |    0.955 | TFT?
# 290 |     C |        C |    3.0 |      859.0 |    0.979 | TFT?
# 291 |     C |        C |    3.0 |      862.0 |    0.939 | TFT?
# 292 |     C |        C |    3.0 |      865.0 |    0.965 | TFT?
# 293 |     C |        C |    3.0 |      868.0 |    0.953 | TFT?
# 294 |     C |        C |    3.0 |      871.0 |    0.944 | TFT?
# 295 |     C |        C |    3.0 |      874.0 |    0.941 | TFT?
# 296 |     C |        C |    3.0 |      877.0 |    0.987 | TFT?
# 297 |     C |        C |    3.0 |      880.0 |    0.961 | TFT?
# 298 |     C |        C |    3.0 |      883.0 |    0.961 | TFT?
# 299 |     C |        C |    3.0 |      886.0 |    0.961 | TFT?
# 300 |     C |        C |    3.0 |      889.0 |    0.961 | TFT?
#
# 🤖 GEMINI ANALYSIS    (Step 300)
# ------------------------------------------------------------
# The PPO agent's strategy closely resembles **Always Cooperate with occasional defection**, but with strong influences from **Tit-for-Tat**. Its high cooperation rate (96.3%) and long cooperation streak (107) are strong indicators. However, the occasional defection, particularly the single defection within the recent moves, suggests it's not purely Always Cooperate.
#
# The "Cooperate after Opponent Defects" rate of 90.9% demonstrates a forgiving, possibly noisy, Tit-for-Tat adaptation. It's mostly mirroring Tit-for-Tat but imperfectly, likely due to the agent's exploration-exploitation balance which results in an occasional defection.
#
# Evidence of learning is subtle, lying in the fact that the agent learned to mostly cooperate, which provides consistent, high rewards (Average Recent Reward: 2.95). While the reward trend is declining, this could be due to minor exploration causing occasional self-harm.
#
# The agent is primarily cooperative but strategically probes with occasional defections. Given its high cooperation probabilities (around 0.96), it will likely cooperate for the next 10 moves. This strategy is performing well against tit_for_tat, generating consistent rewards, but could be refined for optimal gains.
#
# ------------------------------------------------------------
#
# 📋 CONTINUING STEP LOG:
# Step | Agent | Opponent | Reward | Cumulative | P(Coop)  | Notes
# --------------------------------------------------------------------------------
# 301 |     C |        C |    3.0 |      892.0 |    0.961 | TFT?
# 302 |     C |        C |    3.0 |      895.0 |    0.961 | TFT?
# 303 |     C |        C |    3.0 |      898.0 |    0.961 | TFT?
# 304 |     C |        C |    3.0 |      901.0 |    0.961 | TFT?
# 305 |     C |        C |    3.0 |      904.0 |    0.961 | TFT?
# 306 |     C |        C |    3.0 |      907.0 |    0.961 | TFT?
# 307 |     C |        C |    3.0 |      910.0 |    0.961 | TFT?
# 308 |     C |        C |    3.0 |      913.0 |    0.961 | TFT?
# 309 |     C |        C |    3.0 |      916.0 |    0.961 | TFT?
# 310 |     C |        C |    3.0 |      919.0 |    0.961 | TFT?
# 311 |     C |        C |    3.0 |      922.0 |    0.961 | TFT?
# 312 |     C |        C |    3.0 |      925.0 |    0.961 | TFT?
# 313 |     C |        C |    3.0 |      928.0 |    0.961 | TFT?
# 314 |     C |        C |    3.0 |      931.0 |    0.961 | TFT?
# 315 |     C |        C |    3.0 |      934.0 |    0.961 | TFT?
# 316 |     C |        C |    3.0 |      937.0 |    0.961 | TFT?
# 317 |     C |        C |    3.0 |      940.0 |    0.961 | TFT?
# 318 |     C |        C |    3.0 |      943.0 |    0.961 | TFT?
# 319 |     C |        C |    3.0 |      946.0 |    0.961 | TFT?
# 320 |     C |        C |    3.0 |      949.0 |    0.961 | TFT?
# 321 |     C |        C |    3.0 |      952.0 |    0.961 | TFT?
# 322 |     C |        C |    3.0 |      955.0 |    0.961 | TFT?
# 323 |     C |        C |    3.0 |      958.0 |    0.961 | TFT?
# 324 |     C |        C |    3.0 |      961.0 |    0.961 | TFT?
# 325 |     C |        C |    3.0 |      964.0 |    0.961 | TFT?
# 326 |     C |        C |    3.0 |      967.0 |    0.961 | TFT?
# 327 |     C |        C |    3.0 |      970.0 |    0.961 | TFT?
# 328 |     C |        C |    3.0 |      973.0 |    0.961 | TFT?
# 329 |     C |        C |    3.0 |      976.0 |    0.961 | TFT?
# 330 |     C |        C |    3.0 |      979.0 |    0.961 | TFT?
# 331 |     C |        C |    3.0 |      982.0 |    0.961 | TFT?
# 332 |     C |        C |    3.0 |      985.0 |    0.961 | TFT?
# 333 |     C |        C |    3.0 |      988.0 |    0.961 | TFT?
# 334 |     C |        C |    3.0 |      991.0 |    0.961 | TFT?
# 335 |     C |        C |    3.0 |      994.0 |    0.961 | TFT?
# 336 |     C |        C |    3.0 |      997.0 |    0.961 | TFT?
# 337 |     C |        C |    3.0 |     1000.0 |    0.961 | TFT?
# 338 |     C |        C |    3.0 |     1003.0 |    0.961 | TFT?
# 339 |     C |        C |    3.0 |     1006.0 |    0.961 | TFT?
# 340 |     C |        C |    3.0 |     1009.0 |    0.961 | TFT?
# 341 |     C |        C |    3.0 |     1012.0 |    0.961 | TFT?
# 342 |     C |        C |    3.0 |     1015.0 |    0.961 | TFT?
# 343 |     C |        C |    3.0 |     1018.0 |    0.961 | TFT?
# 344 |     C |        C |    3.0 |     1021.0 |    0.961 | TFT?
# 345 |     C |        C |    3.0 |     1024.0 |    0.961 | TFT?
# 346 |     C |        C |    3.0 |     1027.0 |    0.961 | TFT?
# 347 |     C |        C |    3.0 |     1030.0 |    0.961 | TFT?
# 348 |     C |        C |    3.0 |     1033.0 |    0.961 | TFT?
# 349 |     C |        C |    3.0 |     1036.0 |    0.961 | TFT?
# 350 |     C |        C |    3.0 |     1039.0 |    0.961 | TFT?
# 351 |     C |        C |    3.0 |     1042.0 |    0.961 | TFT?
# 352 |     C |        C |    3.0 |     1045.0 |    0.961 | TFT?
# 353 |     C |        C |    3.0 |     1048.0 |    0.961 | TFT?
# 354 |     C |        C |    3.0 |     1051.0 |    0.961 | TFT?
# 355 |     C |        C |    3.0 |     1054.0 |    0.961 | TFT?
# 356 |     C |        C |    3.0 |     1057.0 |    0.961 | TFT?
# 357 |     C |        C |    3.0 |     1060.0 |    0.961 | TFT?
# 358 |     D |        C |    5.0 |     1065.0 |    0.961 | EXPLOITING
# 359 |     C |        D |    0.0 |     1065.0 |    0.998 | TFT? EXPLOITED
# 360 |     C |        C |    3.0 |     1068.0 |    0.958 |
# 361 |     C |        C |    3.0 |     1071.0 |    0.957 | TFT?
# 362 |     C |        C |    3.0 |     1074.0 |    0.955 | TFT?
# 363 |     C |        C |    3.0 |     1077.0 |    0.979 | TFT?
# 364 |     D |        C |    5.0 |     1082.0 |    0.939 | EXPLOITING
# 365 |     C |        D |    0.0 |     1082.0 |    0.994 | TFT? EXPLOITED
# 366 |     C |        C |    3.0 |     1085.0 |    0.945 |
# 367 |     C |        C |    3.0 |     1088.0 |    0.884 | TFT?
# ...
# 302 |     D |        C |    5.0 |     1498.0 |    0.000 | EXPLOITING
# 303 |     D |        C |    5.0 |     1503.0 |    0.000 | EXPLOITING
# 304 |     D |        C |    5.0 |     1508.0 |    0.000 | EXPLOITING
# 305 |     D |        C |    5.0 |     1513.0 |    0.000 | EXPLOITING
# 306 |     D |        C |    5.0 |     1518.0 |    0.000 | EXPLOITING
# 307 |     D |        C |    5.0 |     1523.0 |    0.000 | EXPLOITING
# 308 |     D |        C |    5.0 |     1528.0 |    0.000 | EXPLOITING
# 309 |     D |        C |    5.0 |     1533.0 |    0.000 | EXPLOITING
# 310 |     D |        C |    5.0 |     1538.0 |    0.000 | EXPLOITING
# 311 |     D |        C |    5.0 |     1543.0 |    0.000 | EXPLOITING
# 312 |     D |        C |    5.0 |     1548.0 |    0.000 | EXPLOITING
# 313 |     D |        C |    5.0 |     1553.0 |    0.000 | EXPLOITING
# 314 |     D |        C |    5.0 |     1558.0 |    0.000 | EXPLOITING
# 315 |     D |        C |    5.0 |     1563.0 |    0.000 | EXPLOITING
# 316 |     D |        C |    5.0 |     1568.0 |    0.000 | EXPLOITING
# 317 |     D |        C |    5.0 |     1573.0 |    0.000 | EXPLOITING
# 318 |     D |        C |    5.0 |     1578.0 |    0.000 | EXPLOITING
# 319 |     D |        C |    5.0 |     1583.0 |    0.000 | EXPLOITING
# 320 |     D |        C |    5.0 |     1588.0 |    0.000 | EXPLOITING
# 321 |     D |        C |    5.0 |     1593.0 |    0.000 | EXPLOITING
# 322 |     D |        C |    5.0 |     1598.0 |    0.000 | EXPLOITING
# 323 |     D |        C |    5.0 |     1603.0 |    0.000 | EXPLOITING
# 324 |     D |        C |    5.0 |     1608.0 |    0.000 | EXPLOITING
# 325 |     D |        C |    5.0 |     1613.0 |    0.000 | EXPLOITING
# 326 |     D |        C |    5.0 |     1618.0 |    0.000 | EXPLOITING
# 327 |     D |        C |    5.0 |     1623.0 |    0.000 | EXPLOITING
# 328 |     D |        C |    5.0 |     1628.0 |    0.000 | EXPLOITING
# 329 |     D |        C |    5.0 |     1633.0 |    0.000 | EXPLOITING
# 330 |     D |        C |    5.0 |     1638.0 |    0.000 | EXPLOITING
# 331 |     D |        C |    5.0 |     1643.0 |    0.000 | EXPLOITING
# 332 |     D |        C |    5.0 |     1648.0 |    0.000 | EXPLOITING
# 333 |     D |        C |    5.0 |     1653.0 |    0.000 | EXPLOITING
# 334 |     D |        C |    5.0 |     1658.0 |    0.000 | EXPLOITING
# 335 |     D |        C |    5.0 |     1663.0 |    0.000 | EXPLOITING
# 336 |     D |        C |    5.0 |     1668.0 |    0.000 | EXPLOITING
# 337 |     D |        C |    5.0 |     1673.0 |    0.000 | EXPLOITING
# 338 |     D |        C |    5.0 |     1678.0 |    0.000 | EXPLOITING
# 339 |     D |        C |    5.0 |     1683.0 |    0.000 | EXPLOITING
# 340 |     D |        C |    5.0 |     1688.0 |    0.000 | EXPLOITING
# 341 |     D |        C |    5.0 |     1693.0 |    0.000 | EXPLOITING
# 342 |     D |        C |    5.0 |     1698.0 |    0.000 | EXPLOITING
# 343 |     D |        C |    5.0 |     1703.0 |    0.000 | EXPLOITING
# 344 |     D |        C |    5.0 |     1708.0 |    0.000 | EXPLOITING
# 345 |     D |        C |    5.0 |     1713.0 |    0.000 | EXPLOITING
# 346 |     D |        C |    5.0 |     1718.0 |    0.000 | EXPLOITING
# 347 |     D |        C |    5.0 |     1723.0 |    0.000 | EXPLOITING
# 348 |     D |        C |    5.0 |     1728.0 |    0.000 | EXPLOITING
# 349 |     D |        C |    5.0 |     1733.0 |    0.000 | EXPLOITING
# 350 |     D |        C |    5.0 |     1738.0 |    0.000 | EXPLOITING
# 351 |     D |        C |    5.0 |     1743.0 |    0.000 | EXPLOITING
# 352 |     D |        C |    5.0 |     1748.0 |    0.000 | EXPLOITING
# 353 |     D |        C |    5.0 |     1753.0 |    0.000 | EXPLOITING
# 354 |     D |        C |    5.0 |     1758.0 |    0.000 | EXPLOITING
# 355 |     D |        C |    5.0 |     1763.0 |    0.000 | EXPLOITING
# 356 |     D |        C |    5.0 |     1768.0 |    0.000 | EXPLOITING
# 357 |     D |        C |    5.0 |     1773.0 |    0.000 | EXPLOITING
# 358 |     D |        C |    5.0 |     1778.0 |    0.000 | EXPLOITING
# 359 |     D |        C |    5.0 |     1783.0 |    0.000 | EXPLOITING
# 360 |     D |        C |    5.0 |     1788.0 |    0.000 | EXPLOITING
# 361 |     D |        C |    5.0 |     1793.0 |    0.000 | EXPLOITING
# 362 |     D |        C |    5.0 |     1798.0 |    0.000 | EXPLOITING
# 363 |     D |        C |    5.0 |     1803.0 |    0.000 | EXPLOITING
# 364 |     D |        C |    5.0 |     1808.0 |    0.000 | EXPLOITING
# 365 |     D |        C |    5.0 |     1813.0 |    0.000 | EXPLOITING
# 366 |     D |        C |    5.0 |     1818.0 |    0.000 | EXPLOITING
# 367 |     D |        C |    5.0 |     1823.0 |    0.000 | EXPLOITING
# 368 |     D |        C |    5.0 |     1828.0 |    0.000 | EXPLOITING
# 369 |     D |        C |    5.0 |     1833.0 |    0.000 | EXPLOITING
# 370 |     D |        C |    5.0 |     1838.0 |    0.000 | EXPLOITING
# 371 |     D |        C |    5.0 |     1843.0 |    0.000 | EXPLOITING
# 372 |     D |        C |    5.0 |     1848.0 |    0.000 | EXPLOITING
# 373 |     D |        C |    5.0 |     1853.0 |    0.000 | EXPLOITING
# 374 |     D |        C |    5.0 |     1858.0 |    0.000 | EXPLOITING
# 375 |     D |        C |    5.0 |     1863.0 |    0.000 | EXPLOITING
# 376 |     D |        C |    5.0 |     1868.0 |    0.000 | EXPLOITING
# 377 |     D |        C |    5.0 |     1873.0 |    0.000 | EXPLOITING
# 378 |     D |        C |    5.0 |     1878.0 |    0.000 | EXPLOITING
# 379 |     D |        C |    5.0 |     1883.0 |    0.000 | EXPLOITING
# 380 |     D |        C |    5.0 |     1888.0 |    0.000 | EXPLOITING
# 381 |     D |        C |    5.0 |     1893.0 |    0.000 | EXPLOITING
# 382 |     D |        C |    5.0 |     1898.0 |    0.000 | EXPLOITING
# 383 |     D |        C |    5.0 |     1903.0 |    0.000 | EXPLOITING
# 384 |     D |        C |    5.0 |     1908.0 |    0.000 | EXPLOITING
# 385 |     D |        C |    5.0 |     1913.0 |    0.000 | EXPLOITING
# 386 |     D |        C |    5.0 |     1918.0 |    0.000 | EXPLOITING
# 387 |     D |        C |    5.0 |     1923.0 |    0.000 | EXPLOITING
# 388 |     D |        C |    5.0 |     1928.0 |    0.000 | EXPLOITING
# 389 |     D |        C |    5.0 |     1933.0 |    0.000 | EXPLOITING
# 390 |     D |        C |    5.0 |     1938.0 |    0.000 | EXPLOITING
# 391 |     D |        C |    5.0 |     1943.0 |    0.000 | EXPLOITING
# 392 |     D |        C |    5.0 |     1948.0 |    0.000 | EXPLOITING
# 393 |     D |        C |    5.0 |     1953.0 |    0.000 | EXPLOITING
# 394 |     D |        C |    5.0 |     1958.0 |    0.000 | EXPLOITING
# 395 |     D |        C |    5.0 |     1963.0 |    0.000 | EXPLOITING
# 396 |     D |        C |    5.0 |     1968.0 |    0.000 | EXPLOITING
# 397 |     D |        C |    5.0 |     1973.0 |    0.000 | EXPLOITING
# 398 |     D |        C |    5.0 |     1978.0 |    0.000 | EXPLOITING
# 399 |     D |        C |    5.0 |     1983.0 |    0.000 | EXPLOITING
# 400 |     D |        C |    5.0 |     1988.0 |    0.000 | EXPLOITING
#
# 🤖 GEMINI ANALYSIS    (Step 400)
# ------------------------------------------------------------
# Gemini analysis temporarily unavailable: 429 You exceeded your current quota, please check your plan and billing details. For more informatio...
# ------------------------------------------------------------
#
# 📋 CONTINUING STEP LOG:
# Step | Agent | Opponent | Reward | Cumulative | P(Coop)  | Notes
# --------------------------------------------------------------------------------
# 401 |     D |        C |    5.0 |     1993.0 |    0.000 | EXPLOITING
# 402 |     D |        C |    5.0 |     1998.0 |    0.000 | EXPLOITING
# 403 |     D |        C |    5.0 |     2003.0 |    0.000 | EXPLOITING
# 404 |     D |        C |    5.0 |     2008.0 |    0.000 | EXPLOITING
# 405 |     D |        C |    5.0 |     2013.0 |    0.000 | EXPLOITING
# 406 |     D |        C |    5.0 |     2018.0 |    0.000 | EXPLOITING
# 407 |     D |        C |    5.0 |     2023.0 |    0.000 | EXPLOITING
# 408 |     D |        C |    5.0 |     2028.0 |    0.000 | EXPLOITING
# 409 |     D |        C |    5.0 |     2033.0 |    0.000 | EXPLOITING
# 410 |     D |        C |    5.0 |     2038.0 |    0.000 | EXPLOITING
# 411 |     D |        C |    5.0 |     2043.0 |    0.000 | EXPLOITING
# 412 |     D |        C |    5.0 |     2048.0 |    0.000 | EXPLOITING
# 413 |     D |        C |    5.0 |     2053.0 |    0.000 | EXPLOITING
# 414 |     D |        C |    5.0 |     2058.0 |    0.000 | EXPLOITING
# 415 |     D |        C |    5.0 |     2063.0 |    0.000 | EXPLOITING
# 416 |     D |        C |    5.0 |     2068.0 |    0.000 | EXPLOITING
# 417 |     D |        C |    5.0 |     2073.0 |    0.000 | EXPLOITING
# 418 |     D |        C |    5.0 |     2078.0 |    0.000 | EXPLOITING
# 419 |     D |        C |    5.0 |     2083.0 |    0.000 | EXPLOITING
# 420 |     D |        C |    5.0 |     2088.0 |    0.000 | EXPLOITING
# 421 |     D |        C |    5.0 |     2093.0 |    0.000 | EXPLOITING
# 422 |     D |        C |    5.0 |     2098.0 |    0.000 | EXPLOITING
# 423 |     D |        C |    5.0 |     2103.0 |    0.000 | EXPLOITING
# 424 |     D |        C |    5.0 |     2108.0 |    0.000 | EXPLOITING
# 425 |     D |        C |    5.0 |     2113.0 |    0.000 | EXPLOITING
# 426 |     D |        C |    5.0 |     2118.0 |    0.000 | EXPLOITING
# 427 |     D |        C |    5.0 |     2123.0 |    0.000 | EXPLOITING
# 428 |     D |        C |    5.0 |     2128.0 |    0.000 | EXPLOITING
# 429 |     D |        C |    5.0 |     2133.0 |    0.000 | EXPLOITING
# 430 |     D |        C |    5.0 |     2138.0 |    0.000 | EXPLOITING
# 431 |     D |        C |    5.0 |     2143.0 |    0.000 | EXPLOITING
# 432 |     D |        C |    5.0 |     2148.0 |    0.000 | EXPLOITING
# 433 |     D |        C |    5.0 |     2153.0 |    0.000 | EXPLOITING
# 434 |     D |        C |    5.0 |     2158.0 |    0.000 | EXPLOITING
# 435 |     D |        C |    5.0 |     2163.0 |    0.000 | EXPLOITING
# 436 |     D |        C |    5.0 |     2168.0 |    0.000 | EXPLOITING
# 437 |     D |        C |    5.0 |     2173.0 |    0.000 | EXPLOITING
# 438 |     D |        C |    5.0 |     2178.0 |    0.000 | EXPLOITING
# 439 |     D |        C |    5.0 |     2183.0 |    0.000 | EXPLOITING
# 440 |     D |        C |    5.0 |     2188.0 |    0.000 | EXPLOITING
# 441 |     D |        C |    5.0 |     2193.0 |    0.000 | EXPLOITING
# 442 |     D |        C |    5.0 |     2198.0 |    0.000 | EXPLOITING
# 443 |     D |        C |    5.0 |     2203.0 |    0.000 | EXPLOITING
# 444 |     D |        C |    5.0 |     2208.0 |    0.000 | EXPLOITING
# 445 |     D |        C |    5.0 |     2213.0 |    0.000 | EXPLOITING
# 446 |     D |        C |    5.0 |     2218.0 |    0.000 | EXPLOITING
# 447 |     D |        C |    5.0 |     2223.0 |    0.000 | EXPLOITING
# 448 |     D |        C |    5.0 |     2228.0 |    0.000 | EXPLOITING
# 449 |     D |        C |    5.0 |     2233.0 |    0.000 | EXPLOITING
# 450 |     D |        C |    5.0 |     2238.0 |    0.000 | EXPLOITING
# 451 |     D |        C |    5.0 |     2243.0 |    0.000 | EXPLOITING
# 452 |     D |        C |    5.0 |     2248.0 |    0.000 | EXPLOITING
# 453 |     D |        C |    5.0 |     2253.0 |    0.000 | EXPLOITING
# 454 |     D |        C |    5.0 |     2258.0 |    0.000 | EXPLOITING
# 455 |     D |        C |    5.0 |     2263.0 |    0.000 | EXPLOITING
# 456 |     D |        C |    5.0 |     2268.0 |    0.000 | EXPLOITING
# 457 |     D |        C |    5.0 |     2273.0 |    0.000 | EXPLOITING
# 458 |     D |        C |    5.0 |     2278.0 |    0.000 | EXPLOITING
# 459 |     D |        C |    5.0 |     2283.0 |    0.000 | EXPLOITING
# 460 |     D |        C |    5.0 |     2288.0 |    0.000 | EXPLOITING
# 461 |     D |        C |    5.0 |     2293.0 |    0.000 | EXPLOITING
# 462 |     D |        C |    5.0 |     2298.0 |    0.000 | EXPLOITING
# 463 |     D |        C |    5.0 |     2303.0 |    0.000 | EXPLOITING
# 464 |     D |        C |    5.0 |     2308.0 |    0.000 | EXPLOITING
# 465 |     D |        C |    5.0 |     2313.0 |    0.000 | EXPLOITING
# 466 |     D |        C |    5.0 |     2318.0 |    0.000 | EXPLOITING
# 467 |     D |        C |    5.0 |     2323.0 |    0.000 | EXPLOITING
# 468 |     D |        C |    5.0 |     2328.0 |    0.000 | EXPLOITING
# 469 |     D |        C |    5.0 |     2333.0 |    0.000 | EXPLOITING
# 470 |     D |        C |    5.0 |     2338.0 |    0.000 | EXPLOITING
# 471 |     D |        C |    5.0 |     2343.0 |    0.000 | EXPLOITING
# 472 |     D |        C |    5.0 |     2348.0 |    0.000 | EXPLOITING
# 473 |     D |        C |    5.0 |     2353.0 |    0.000 | EXPLOITING
# 474 |     D |        C |    5.0 |     2358.0 |    0.000 | EXPLOITING
# 475 |     D |        C |    5.0 |     2363.0 |    0.000 | EXPLOITING
# 476 |     D |        C |    5.0 |     2368.0 |    0.000 | EXPLOITING
# 477 |     D |        C |    5.0 |     2373.0 |    0.000 | EXPLOITING
# 478 |     D |        C |    5.0 |     2378.0 |    0.000 | EXPLOITING
# 479 |     D |        C |    5.0 |     2383.0 |    0.000 | EXPLOITING
# 480 |     D |        C |    5.0 |     2388.0 |    0.000 | EXPLOITING
# 481 |     D |        C |    5.0 |     2393.0 |    0.000 | EXPLOITING
# 482 |     D |        C |    5.0 |     2398.0 |    0.000 | EXPLOITING
# 483 |     D |        C |    5.0 |     2403.0 |    0.000 | EXPLOITING
# 484 |     D |        C |    5.0 |     2408.0 |    0.000 | EXPLOITING
# 485 |     D |        C |    5.0 |     2413.0 |    0.000 | EXPLOITING
# 486 |     D |        C |    5.0 |     2418.0 |    0.000 | EXPLOITING
# 487 |     D |        C |    5.0 |     2423.0 |    0.000 | EXPLOITING
# 488 |     D |        C |    5.0 |     2428.0 |    0.000 | EXPLOITING
# 489 |     D |        C |    5.0 |     2433.0 |    0.000 | EXPLOITING
# 490 |     D |        C |    5.0 |     2438.0 |    0.000 | EXPLOITING
# 491 |     D |        C |    5.0 |     2443.0 |    0.000 | EXPLOITING
# 492 |     D |        C |    5.0 |     2448.0 |    0.000 | EXPLOITING
# 493 |     D |        C |    5.0 |     2453.0 |    0.000 | EXPLOITING
# 494 |     D |        C |    5.0 |     2458.0 |    0.000 | EXPLOITING
# 495 |     D |        C |    5.0 |     2463.0 |    0.000 | EXPLOITING
# 496 |     D |        C |    5.0 |     2468.0 |    0.000 | EXPLOITING
# 497 |     D |        C |    5.0 |     2473.0 |    0.000 | EXPLOITING
# 498 |     D |        C |    5.0 |     2478.0 |    0.000 | EXPLOITING
# 499 |     D |        C |    5.0 |     2483.0 |    0.000 | EXPLOITING
# 500 |     D |        C |    5.0 |     2488.0 |    0.000 | EXPLOITING
#
# 🤖 GEMINI ANALYSIS    (Step 500)
# ------------------------------------------------------------
# Gemini analysis temporarily unavailable: 429 You exceeded your current quota, please check your plan and billing details. For more informatio...
# ------------------------------------------------------------
#
# 📋 CONTINUING STEP LOG:
# Step | Agent | Opponent | Reward | Cumulative | P(Coop)  | Notes
# --------------------------------------------------------------------------------
#
# 📊 MATCH SUMMARY:
# Agent: PPO_vs_always_cooperate
# Total Reward: 2488.0
# Average Reward per Episode: 4.98
# Agent Cooperation Rate: 1.2%
# Opponent Cooperation Rate: 100.0%
#
# ================================================================================
# 🧠 COMPREHENSIVE GEMINI STRATEGY ANALYSIS
# ================================================================================
# Gemini comparison temporarily unavailable: 429 You exceeded your current quota, please check your plan and billing details. For more informatio...
#
# ================================================================================
# 📊 FINAL PPO PERFORMANCE SUMMARY
# ================================================================================
#          tit_for_tat: 1483.0 pts | Avg:  2.97 | Coop: 96.6% | vs 96.6% opp
# generous_tit_for_tat: 1478.0 pts | Avg:  2.96 | Coop: 94.0% | vs 94.6% opp
#     tit_for_two_tats: 1993.0 pts | Avg:  3.99 | Coop: 50.0% | vs 99.6% opp
#        always_defect:  489.0 pts | Avg:  0.98 | Coop:  2.2% | vs  0.0% opp
#     always_cooperate: 2488.0 pts | Avg:  4.98 | Coop:  1.2% | vs 100.0% opp

# %%
import random
import numpy as np
import gym
import torch
import json
import time
import warnings
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import BaseCallback
import google.generativeai as genai
from typing import List, Dict, Tuple

# Suppress warnings
warnings.filterwarnings("ignore", category=UserWarning)

# ==================================
# 📌 GEMINI API INTEGRATION
# ==================================
class GeminiAnalyzer:
    def __init__(self, api_key: str):
        """Initialize Gemini API for strategy analysis"""
        genai.configure(api_key=api_key)
        self.model = genai.GenerativeModel('gemini-2.0-flash')
        
    def analyze_training_progress(self, step: int, total_steps: int, 
                                recent_rewards: List[float], 
                                recent_episodes: Dict[str, List[str]]) -> str:
        """Analyze PPO training progress with streamlined prompt"""
        
        # Add rate limiting
        time.sleep(0.5)
        
        # Calculate training metrics
        avg_reward = np.mean(recent_rewards) if recent_rewards else 0
        reward_trend = "improving" if len(recent_rewards) >= 10 and np.mean(recent_rewards[-5:]) > np.mean(recent_rewards[-10:-5]) else "stable"
        
        prompt = f"""
        Analyze PPO agent training progress in Prisoner's Dilemma:

        TRAINING STATUS:
        - Step: {step:,}/{total_steps:,} ({step/total_steps*100:.1f}% complete)
        - Recent Average Reward: {avg_reward:.2f}
        - Performance Trend: {reward_trend}
        
        RECENT BEHAVIOR SAMPLES:
        """
        
        # Add sample episodes from different strategies
        for strategy_name, episodes in recent_episodes.items():
            if episodes:
                latest_episode = episodes[-1] if episodes else "No data"
                prompt += f"\nVs {strategy_name}: {latest_episode[:50]}{'...' if len(latest_episode) > 50 else ''}"
        
        prompt += f"""
        
        Provide brief insights on:
        1. What strategy is the agent learning?
        2. Is it adapting well across different opponents?
        3. Training progress assessment
        
        Keep response under 150 words, focus on key strategic insights.
        """
        
        try:
            response = self.model.generate_content(prompt)
            return response.text
        except Exception as e:
            return f"Training analysis unavailable: {str(e)[:50]}..."
        
    def analyze_strategy_evolution(self, agent_id: str, move_history: List[str], 
                                 opponent_history: List[str], probabilities: List[float],
                                 rewards: List[float], opponent_name: str) -> str:
        """Analyze how the PPO agent's strategy evolves over time with simplified prompt"""
        
        # Add rate limiting to respect API limits
        time.sleep(0.5)
        
        # Calculate key metrics only
        coop_rate = move_history.count('C') / len(move_history) * 100
        recent_moves = move_history[-20:] if len(move_history) >= 20 else move_history
        
        # Tit-for-tat analysis
        tit_for_tat_matches = 0
        if len(move_history) > 1 and len(opponent_history) > 0:
            for i in range(1, min(len(move_history), len(opponent_history))):
                if move_history[i] == opponent_history[i-1]:
                    tit_for_tat_matches += 1
        
        tit_for_tat_percentage = (tit_for_tat_matches / max(1, len(move_history)-1)) * 100
        
        prompt = f"""
        Analyze PPO agent strategy vs {opponent_name}:

        BEHAVIOR:
        - Moves: {len(move_history)} total
        - Agent: {' '.join(recent_moves)}
        - Opponent: {' '.join(opponent_history[-20:] if len(opponent_history) >= 20 else opponent_history)}
        - Cooperation Rate: {coop_rate:.1f}%
        - Tit-for-Tat Match: {tit_for_tat_percentage:.1f}%
        - Recent Reward: {np.mean(rewards[-10:]) if len(rewards) >= 10 else np.mean(rewards):.2f}

        What strategy has the agent learned? How effective is it against {opponent_name}?
        Keep response under 200 words.
        """
        
        try:
            response = self.model.generate_content(prompt)
            return response.text
        except Exception as e:
            return f"Strategy analysis unavailable: {str(e)[:50]}..."
    
    def compare_strategies(self, results: Dict[str, Dict]) -> str:
        """Compare PPO performance with simplified prompt"""
        
        # Add rate limiting
        time.sleep(1.0)
        
        # Find best and worst performance
        best_performance = max(results.values(), key=lambda x: x['total_reward'])
        worst_performance = min(results.values(), key=lambda x: x['total_reward'])
        
        prompt = f"""
        Final PPO Strategy Assessment:

        PERFORMANCE RESULTS:
        """
        
        for name, data in results.items():
            prompt += f"\n- {name}: {data['total_reward']:.1f} pts, {data['cooperation_rate']*100:.1f}% coop"
        
        prompt += f"""
        
        Best vs: {[k for k, v in results.items() if v['total_reward'] == best_performance['total_reward']][0]}
        Worst vs: {[k for k, v in results.items() if v['total_reward'] == worst_performance['total_reward']][0]}
        
        What core strategy has PPO learned? Is it robust or exploitable? 
        How sophisticated is the learned behavior?
        Keep response under 250 words.
        """
        
        try:
            response = self.model.generate_content(prompt)
            return response.text
        except Exception as e:
            return f"Strategy comparison unavailable: {str(e)[:50]}..."

# ==================================
# 📌 TRAINING CALLBACK FOR GEMINI ANALYSIS
# ==================================
class GeminiTrainingCallback(BaseCallback):
    def __init__(self, gemini_analyzer: GeminiAnalyzer, analysis_interval: int = 25000):
        super().__init__()
        self.gemini_analyzer = gemini_analyzer
        self.analysis_interval = analysis_interval
        self.recent_rewards = []
        self.recent_episodes = {
            'tit_for_tat': [],
            'generous_tit_for_tat': [],
            'tit_for_two_tats': [],
            'always_defect': [],
            'always_cooperate': []
        }
        
    def _on_step(self) -> bool:
        # Collect reward data
        if hasattr(self.training_env, 'get_attr'):
            try:
                rewards = self.training_env.get_attr('full_reward_history')
                for env_rewards in rewards:
                    if env_rewards:
                        self.recent_rewards.extend(env_rewards[-10:])  # Last 10 rewards
                
                # Keep only recent data
                if len(self.recent_rewards) > 100:
                    self.recent_rewards = self.recent_rewards[-100:]
                    
            except:
                pass  # Silently handle if attributes don't exist
        
        # Periodic analysis
        if self.num_timesteps % self.analysis_interval == 0:
            print(f"\n{'🤖 GEMINI TRAINING ANALYSIS':<30} (Step {self.num_timesteps:,})")
            print("-" * 70)
            
            analysis = self.gemini_analyzer.analyze_training_progress(
                step=self.num_timesteps,
                total_steps=self.analysis_interval * 10,  # Assuming 250k total
                recent_rewards=self.recent_rewards,
                recent_episodes=self.recent_episodes
            )
            print(analysis)
            print("-" * 70)
            
        return True

# ==================================
# 📌 ENHANCED PRISONER'S DILEMMA ENVIRONMENT
# ==================================
class PrisonersDilemmaEnv(gym.Env):
    def __init__(self, strategy, agent_id="PPO_AGENT", history_len=10):
        super(PrisonersDilemmaEnv, self).__init__()
        self.history_len = history_len
        self.agent_id = agent_id
        self.action_space = gym.spaces.Discrete(2)  # 0: Cooperate, 1: Defect
        self.observation_space = gym.spaces.Box(low=0, high=5, shape=(3 * self.history_len,), dtype=np.float32)

        self.strategy = strategy
        self.agent_history = []
        self.opponent_history = []
        self.reward_history = []
        
        # Enhanced tracking for Gemini analysis
        self.full_agent_history = []
        self.full_opponent_history = []
        self.full_reward_history = []
        self.action_probabilities = []

    def step(self, action):
        opponent_action = 0 if self.strategy(self.agent_history, self.opponent_history, False) == 'C' else 1
        reward = self.get_reward(action, opponent_action)

        # Update histories
        self.agent_history.append(action)
        self.opponent_history.append(opponent_action)
        self.reward_history.append(reward)
        
        # Update full histories for analysis
        self.full_agent_history.append(action)
        self.full_opponent_history.append(opponent_action)
        self.full_reward_history.append(reward)

        # Maintain sliding window
        if len(self.agent_history) > self.history_len:
            self.agent_history.pop(0)
            self.opponent_history.pop(0)
            self.reward_history.pop(0)

        obs = self._get_obs()
        return obs, reward, False, {}

    def reset(self):
        self.agent_history = []
        self.opponent_history = []
        self.reward_history = []
        return self._get_obs()

    def _get_obs(self):
        pad = lambda x: x + [0] * (self.history_len - len(x))
        return np.array(pad(self.agent_history) + pad(self.opponent_history) + pad(self.reward_history), dtype=np.float32)

    def get_reward(self, action, opponent_action):
        # Classic Prisoner's Dilemma payoff matrix
        if action == 0 and opponent_action == 0:      # Both cooperate
            return 3
        elif action == 1 and opponent_action == 1:    # Both defect
            return 1
        elif action == 0 and opponent_action == 1:    # Agent cooperates, opponent defects
            return 0
        else:                                         # Agent defects, opponent cooperates
            return 5
    
    def add_action_probability(self, prob):
        """Store action probability for analysis"""
        self.action_probabilities.append(prob)

# ==================================
# 📌 STRATEGIES (with proper conversion)
# ==================================
def to_symbolic(hist):
    return ['C' if a == 0 else 'D' for a in hist]

def tit_for_tat(agent_hist, opp_hist, __):
    return 'C' if not agent_hist else ('C' if agent_hist[-1] == 0 else 'D')

def tit_for_two_tats(agent_hist, opp_hist, __):
    if len(agent_hist) >= 2 and agent_hist[-2:] == [1, 1]:
        return 'D'
    return 'C'

def generous_tit_for_tat(agent_hist, opp_hist, __, cooperation_prob=0.1):
    if not agent_hist:
        return 'C'
    if agent_hist[-1] == 1:
        return 'C' if random.random() < cooperation_prob else 'D'
    return 'C'

def always_cooperate(*args): return 'C'
def always_defect(*args): return 'D'
def random_strategy(*args): return random.choice(['C', 'D'])
def friedman(agent_hist, opp_hist, __): return 'D' if 1 in agent_hist else 'C'

def joss(agent_hist, opp_hist, __):
    if agent_hist and random.random() < 0.1:
        return 'D'
    if agent_hist: 
        return 'C' if agent_hist[-1] == 0 else 'D'
    return 'C'

def grasskamp(agent_hist, opp_hist, __):
    return 'D' if len(agent_hist) >= 3 and agent_hist[-3:] == [1, 1, 1] else 'C'

def sample(agent_hist, opp_hist, __): return random.choice(['C', 'C', 'D'])
def tester(agent_hist, opp_hist, __): return 'D' if not agent_hist else 'C'
def opportunist(agent_hist, opp_hist, __): return 'D' if agent_hist and agent_hist[-1] == 0 else 'C'
def backstabber(agent_hist, opp_hist, __): return 'C' if len(agent_hist) < 5 else 'D'
def chaos_agent(*args): return random.choice(['C', 'D'])

# ==================================
# 📌 TRAIN PPO AGAINST STRATEGIES WITH GEMINI ANALYSIS
# ==================================
def train_ppo_with_gemini(gemini_api_key: str, history_len=10, total_timesteps=250000):
    """Train PPO with Gemini analysis during training"""
    
    strategies = {
        "tit_for_tat": tit_for_tat,
        "generous_tit_for_tat": generous_tit_for_tat,
        "tit_for_two_tats": tit_for_two_tats,
        "always_defect": always_defect,
        "always_cooperate": always_cooperate,
    }

    # Initialize Gemini analyzer
    analyzer = GeminiAnalyzer(gemini_api_key)
    
    # Create environments
    envs = [lambda s=s, i=i: PrisonersDilemmaEnv(s, agent_id=f"PPO_vs_{name}", history_len=history_len)
            for i, (name, s) in enumerate(strategies.items())]
    vec_env = DummyVecEnv(envs)

    # Create model
    model = PPO("MlpPolicy", vec_env, verbose=1, ent_coef=0.01)
    
    # Create callback for Gemini analysis
    gemini_callback = GeminiTrainingCallback(analyzer, analysis_interval=25000)
    
    print(f"🚀 Starting PPO Training with Gemini Analysis (every 25,000 steps)")
    print(f"Total timesteps: {total_timesteps:,}")
    print("-" * 70)
    
    # Train with callback
    model.learn(total_timesteps=total_timesteps, callback=gemini_callback)
    
    # Save model
    model.save("ppo_all_strategies_with_gemini")
    print(f"\n✅ Training completed! Model saved as 'ppo_all_strategies_with_gemini'")
    
    return model

# ==================================
# 📌 ENHANCED TEST WITH DETAILED LOGGING AND GEMINI ANALYSIS
# ==================================
def test_ppo_with_gemini(gemini_api_key: str, history_len=10, print_steps=True, analyze_every=100, num_episodes=500):
    """Test PPO with detailed step logging and Gemini analysis integration"""
    
    strategies = {
        "tit_for_tat": tit_for_tat,
        "generous_tit_for_tat": generous_tit_for_tat,
        "tit_for_two_tats": tit_for_two_tats,
        "always_defect": always_defect,
        "always_cooperate": always_cooperate,
    }

    # Initialize Gemini analyzer
    analyzer = GeminiAnalyzer(gemini_api_key)
    
    print("\n🔹 Loading PPO Model")
    try:
        model = PPO.load("ppo_all_strategies_with_gemini")
    except:
        print("⚠️  Model not found, loading fallback model...")
        model = PPO.load("ppo_all_strategies_full_history")
        
    results = {}
    detailed_results = {}

    for name, strategy in strategies.items():
        print(f"\n{'='*60}")
        print(f"🧪 TESTING PPO AGAINST: {name.upper()}")
        print(f"{'='*60}")
        
        agent_id = f"PPO_vs_{name}"
        env = DummyVecEnv([lambda s=strategy, aid=agent_id: PrisonersDilemmaEnv(s, agent_id=aid, history_len=history_len)])
        obs = env.reset()
        total_reward = 0
        
        # Detailed logging header
        if print_steps:
            print(f"\n📋 DETAILED STEP-BY-STEP LOG:")
            print(f"{'Step':<4} | {'Agent':<5} | {'Opponent':<8} | {'Reward':<6} | {'Cumulative':<10} | {'P(Coop)':<8} | {'Notes'}")
            print("-" * 80)

        for i in range(num_episodes):
            # Get action and probabilities more robustly
            action, _ = model.predict(obs, deterministic=False)
            
            # Get action probabilities with proper device handling
            try:
                # Ensure tensor is on the same device as the model
                device = next(model.policy.parameters()).device
                obs_tensor = torch.FloatTensor(obs).to(device)
                
                with torch.no_grad():
                    # Extract features and get logits
                    features = model.policy.extract_features(obs_tensor)
                    latent_pi = model.policy.mlp_extractor.forward_actor(features)
                    logits = model.policy.action_net(latent_pi)
                    action_probs = torch.softmax(logits, dim=-1)
                    prob_cooperate = float(action_probs[0][0].cpu())
            except Exception as e:
                # Fallback: use a simple heuristic based on recent actions
                prob_cooperate = 0.5  # Default probability
                if i == 0:  # Only print warning once
                    print(f"Warning: Using default probability due to: {str(e)[:50]}...")
            
            # Take step
            obs, reward, done, _ = env.step(action)
            action_val = int(action[0])
            
            # Store probability
            env.envs[0].add_action_probability(prob_cooperate)
            
            opponent_action = env.envs[0].opponent_history[-1]
            total_reward += reward[0]
            
            # Detailed step logging
            if print_steps:
                # Determine notes for interesting patterns
                notes = ""
                if i > 0:
                    prev_opp = env.envs[0].full_opponent_history[-2] if len(env.envs[0].full_opponent_history) >= 2 else None
                    if prev_opp is not None:
                        if action_val == prev_opp:
                            notes += "TFT? "
                        if action_val == 0 and opponent_action == 1:
                            notes += "EXPLOITED "
                        elif action_val == 1 and opponent_action == 0:
                            notes += "EXPLOITING "
                
                print(f"{i+1:>3d} | {'C' if action_val==0 else 'D':>5} | {'C' if opponent_action==0 else 'D':>8} | "
                      f"{reward[0]:>6.1f} | {total_reward:>10.1f} | {prob_cooperate:>8.3f} | {notes}")
            
            # Periodic Gemini analysis
            if (i + 1) % analyze_every == 0:
                print(f"\n{'🤖 GEMINI ANALYSIS':<20} (Step {i+1})")
                print("-" * 60)
                
                agent_moves = ['C' if a == 0 else 'D' for a in env.envs[0].full_agent_history]
                opponent_moves = ['C' if a == 0 else 'D' for a in env.envs[0].full_opponent_history]
                
                analysis = analyzer.analyze_strategy_evolution(
                    agent_id=agent_id,
                    move_history=agent_moves,
                    opponent_history=opponent_moves,
                    probabilities=env.envs[0].action_probabilities,
                    rewards=env.envs[0].full_reward_history,
                    opponent_name=name
                )
                print(analysis)
                print("-" * 60)
                
                if print_steps:
                    print(f"\n📋 CONTINUING STEP LOG:")
                    print(f"{'Step':<4} | {'Agent':<5} | {'Opponent':<8} | {'Reward':<6} | {'Cumulative':<10} | {'P(Coop)':<8} | {'Notes'}")
                    print("-" * 80)

        # Store detailed results
        agent_moves = ['C' if a == 0 else 'D' for a in env.envs[0].full_agent_history]
        opponent_moves = ['C' if a == 0 else 'D' for a in env.envs[0].full_opponent_history]
        
        detailed_results[name] = {
            'total_reward': float(total_reward),
            'average_reward': float(total_reward / num_episodes),
            'cooperation_rate': agent_moves.count('C') / len(agent_moves),
            'opponent_cooperation_rate': opponent_moves.count('C') / len(opponent_moves),
            'avg_reward': float(np.mean(env.envs[0].full_reward_history)),
            'final_probabilities': env.envs[0].action_probabilities[-10:] if len(env.envs[0].action_probabilities) >= 10 else env.envs[0].action_probabilities,
            'agent_id': agent_id,
            'total_episodes': num_episodes
        }
        
        results[name] = total_reward
        
        # Summary for this opponent
        print(f"\n📊 MATCH SUMMARY:")
        print(f"Agent: {agent_id}")
        print(f"Total Reward: {total_reward:.1f}")
        print(f"Average Reward per Episode: {total_reward/num_episodes:.2f}")
        print(f"Agent Cooperation Rate: {detailed_results[name]['cooperation_rate']:.1%}")
        print(f"Opponent Cooperation Rate: {detailed_results[name]['opponent_cooperation_rate']:.1%}")

    # Final comprehensive analysis
    print("\n" + "="*80)
    print("🧠 COMPREHENSIVE GEMINI STRATEGY ANALYSIS")
    print("="*80)
    
    final_analysis = analyzer.compare_strategies(detailed_results)
    print(final_analysis)
    
    print("\n" + "="*80)
    print("📊 FINAL PPO PERFORMANCE SUMMARY")
    print("="*80)
    for strategy, score in results.items():
        details = detailed_results[strategy]
        print(f"{strategy:>20}: {score:>6.1f} pts | Avg: {details['average_reward']:>5.2f} | "
              f"Coop: {details['cooperation_rate']:>5.1%} | "
              f"vs {details['opponent_cooperation_rate']:>5.1%} opp")
    
    return results, detailed_results

# ==================================
# 📌 MAIN EXECUTION WITH GEMINI
# ==================================
def main():
    # You need to set your Gemini API key here
    GEMINI_API_KEY = "AIzaSyALn5gEk1DeBNoIFRBdk52K3d_S5JKyC3M"  # Replace with your actual API key
    
    if not GEMINI_API_KEY or GEMINI_API_KEY == "":
        print("⚠️  Please set your Gemini API key in the GEMINI_API_KEY variable")
        print("You can get one from: https://makersuite.google.com/app/apikey")
        return
    
    print("🚀 Training PPO Agent with Gemini Analysis...")
    train_ppo_with_gemini(GEMINI_API_KEY, total_timesteps=250000)
    
    print("\n🧪 Testing PPO with Enhanced Analysis...")
    results, detailed_results = test_ppo_with_gemini(
        gemini_api_key=GEMINI_API_KEY,
        print_steps=True,       # Enable detailed step-by-step logging
        analyze_every=100,      # Analyze every 100 steps
        num_episodes=500        # Number of episodes per opponent
    )

# ==================================
# 🚀 RUN TRAINING & TESTING
# ==================================
if __name__ == "__main__":
    main()
# Out:
# /usr/local/lib/python3.11/dist-packages/gymnasium/envs/registration.py:596: UserWarning: WARN: plugin: shimmy.registration:register_gymnasium_envs raised Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/gymnasium/envs/registration.py", line 594, in load_plugin_envs
#     fn()
#   File "/usr/local/lib/python3.11/dist-packages/shimmy/registration.py", line 304, in register_gymnasium_envs
#     _register_atari_envs()
#   File "/usr/local/lib/python3.11/dist-packages/shimmy/registration.py", line 205, in _register_atari_envs
#     import ale_py
#   File "/usr/local/lib/python3.11/dist-packages/ale_py/__init__.py", line 68, in <module>
#     register_v0_v4_envs()
#   File "/usr/local/lib/python3.11/dist-packages/ale_py/registration.py", line 179, in register_v0_v4_envs
#     _register_rom_configs(legacy_games, obs_types, versions)
#   File "/usr/local/lib/python3.11/dist-packages/ale_py/registration.py", line 64, in _register_rom_configs
#     gymnasium.register(
#     ^^^^^^^^^^^^^^^^^^
# AttributeError: partially initialized module 'gymnasium' has no attribute 'register' (most likely due to a circular import)
#
#   logger.warn(f"plugin: {plugin.value} raised {traceback.format_exc()}")
# 2025-06-22 06:31:50.645837: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750573910.851897      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750573910.918146      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 🚀 Training PPO Agent with Gemini Analysis...
# Using cpu device
# 🚀 Starting PPO Training with Gemini Analysis (every 25,000 steps)
# Total timesteps: 250,000
# ----------------------------------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 4968  |
# |    iterations      | 1     |
# |    time_elapsed    | 2     |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1737        |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010028106 |
# |    clip_fraction        | 0.0441      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.683      |
# |    explained_variance   | 0.0172      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 120         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00294    |
# |    value_loss           | 792         |
# -----------------------------------------
#
# 🤖 GEMINI TRAINING ANALYSIS     (Step 25,000)
# ----------------------------------------------------------------------
# Based on the provided information, the PPO agent appears to be learning a strategy of **partial cooperation**. An average reward of 2.25 in the Prisoner's Dilemma suggests it's sometimes cooperating and sometimes defecting, as full cooperation yields higher rewards (3).
#
# Its **adaptability is uncertain**. A stable reward indicates consistency in its strategy execution, but doesn't guarantee it is adjusting to different types of opponents. We need opponent behavior data to assess this.
#
# The training progress is **early and incomplete**. Only 10% of training is done. While the reward is stable, it's premature to conclude optimal behavior. The agent may still converge towards a more dominant strategy with more training iterations, either towards full cooperation or a more sophisticated tit-for-tat-like approach. Further observation is needed.
#
# ----------------------------------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1298      |
# |    iterations           | 3         |
# |    time_elapsed         | 23        |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 0.0110539 |
# |    clip_fraction        | 0.0774    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.668    |
# |    explained_variance   | 0.62      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 135       |
# |    n_updates            | 20        |
# |    policy_gradient_loss | -0.00272  |
# |    value_loss           | 800       |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1257        |
# |    iterations           | 4           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006350727 |
# |    clip_fraction        | 0.0476      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.621      |
# |    explained_variance   | 0.826       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 62.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00235    |
# |    value_loss           | 567         |
# -----------------------------------------
#
# 🤖 GEMINI TRAINING ANALYSIS     (Step 50,000)
# ----------------------------------------------------------------------
# Based on the provided training status and behavior samples, here's a quick analysis:
#
# 1.  **Likely Learning Cooperation:** An average reward of 2.63 in the Prisoner's Dilemma strongly suggests the agent is learning to cooperate. Both players cooperating results in a reward of 3. This indicates a significant portion of the time, the agent is engaging in mutually beneficial actions rather than purely defecting.
# 2.  **Adaptability Unknown:** Without observing interactions against diverse opponents with different strategies, it's difficult to assess adaptability. A single average reward score hides complexities in gameplay with different opponents.
# 3.  **Positive Training Progress:** At 20% completion and an improving performance trend, the training is progressing positively. The agent is demonstrably learning a strategy that yields a higher-than-baseline reward. Further training and examination of gameplay against a distribution of opponents would be beneficial.
#
# ----------------------------------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1171         |
# |    iterations           | 5            |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0052576386 |
# |    clip_fraction        | 0.0213       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.643       |
# |    explained_variance   | 0.903        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.4         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.004       |
# |    value_loss           | 415          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1168         |
# |    iterations           | 6            |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0077861412 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.609       |
# |    explained_variance   | 0.947        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.7         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 281          |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1169       |
# |    iterations           | 7          |
# |    time_elapsed         | 61         |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.00597224 |
# |    clip_fraction        | 0.0274     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.626     |
# |    explained_variance   | 0.967      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 26.5       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00314   |
# |    value_loss           | 201        |
# ----------------------------------------
#
# 🤖 GEMINI TRAINING ANALYSIS     (Step 75,000)
# ----------------------------------------------------------------------
# Okay, here's an analysis of the PPO agent's training progress:
#
# Based on an average reward of 2.77, the agent is likely learning a cooperative strategy in the Prisoner's Dilemma. A purely selfish agent would likely trend towards a lower average reward. The "stable" performance trend suggests the agent has converged on a strategy.
#
# Without seeing examples of behavior with different opponents or previous training stages, it's difficult to determine adaptation, but it is likely playing "tit for tat" with itself.
#
# The agent is only 30% of the way through training. While a cooperative strategy has emerged, further training could refine the strategy to become more robust against exploitation or encourage punishment in non-cooperative environments. Continuing training is necessary to determine the long-term learning outcome.
#
# ----------------------------------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1136        |
# |    iterations           | 8           |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.004346228 |
# |    clip_fraction        | 0.0389      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.611      |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.1        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00131    |
# |    value_loss           | 149         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1137        |
# |    iterations           | 9           |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.004981777 |
# |    clip_fraction        | 0.0149      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.59       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.2        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00368    |
# |    value_loss           | 99.5        |
# -----------------------------------------
#
# 🤖 GEMINI TRAINING ANALYSIS     (Step 100,000)
# ----------------------------------------------------------------------
# Based on the provided information:
#
# 1.  **Strategy:** The average reward of 2.72 suggests the agent is likely learning a strategy involving some level of cooperation. In Prisoner's Dilemma, a reward close to 3 often results when both agents cooperate.
#
# 2.  **Adaptability:** The performance trend is *stable*, meaning the agent can reliably obtain this reward across the latest training period. It can be inferred that the agent has developed a more robust strategy, that it can repeat, or a reliable way of interacting with opponents.
#
# 3.  **Training Progress:**  40% complete with a stable average reward suggests the agent has found a consistent (likely cooperative) strategy but may not yet be fully optimized or able to exploit opponents deviating from cooperation. Further training *may* refine the strategy to higher reward via occasional defection, however, a stable environment may be the best result.
#
# ----------------------------------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1113        |
# |    iterations           | 10          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.004916484 |
# |    clip_fraction        | 0.0307      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.561      |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.4        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00358    |
# |    value_loss           | 77.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1120         |
# |    iterations           | 11           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0062531508 |
# |    clip_fraction        | 0.0528       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.529       |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.6          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00527     |
# |    value_loss           | 64.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1114         |
# |    iterations           | 12           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0050239884 |
# |    clip_fraction        | 0.0479       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.491       |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.7         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00391     |
# |    value_loss           | 53.6         |
# ------------------------------------------
#
# 🤖 GEMINI TRAINING ANALYSIS     (Step 125,000)
# ----------------------------------------------------------------------
# Based on the provided information, the PPO agent in the Prisoner's Dilemma is likely learning a **cooperative strategy with a degree of self-preservation**. An average reward of 2.91 suggests it's often finding mutual cooperation (reward of 3), but occasionally experiencing lower rewards. A perfectly cooperative agent against another would consistently achieve 3.
#
# The "stable" performance trend indicates it's not significantly improving. Without seeing its behavior against various opponents, it's hard to assess its adaptability. However, the near-3 reward hints that it might exploit cooperative opponents but could be vulnerable to defectors.
#
# The agent has reached 50% training, but its strategy seems somewhat plateaued. Further training, especially with diverse opponent strategies, is crucial to encourage more robust and adaptive behavior. Monitoring specific action choices and outcomes against different opponents is needed for a more detailed assessment.
#
# ----------------------------------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1099        |
# |    iterations           | 13          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 133120      |
# | train/                  |             |
# |    approx_kl            | 0.008203911 |
# |    clip_fraction        | 0.0766      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.458      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.7        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00592    |
# |    value_loss           | 46.8        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1103       |
# |    iterations           | 14         |
# |    time_elapsed         | 129        |
# |    total_timesteps      | 143360     |
# | train/                  |            |
# |    approx_kl            | 0.00560671 |
# |    clip_fraction        | 0.0619     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.429     |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.72       |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.00395   |
# |    value_loss           | 33.4       |
# ----------------------------------------
#
# 🤖 GEMINI TRAINING ANALYSIS     (Step 150,000)
# ----------------------------------------------------------------------
# Based on the training status, the PPO agent is likely learning a strategy that yields an average reward of 3.12. This suggests a mixed strategy, possibly oscillating between cooperation and defection depending on the perceived opponent. A reward of 3.12 is better than consistently defecting (which would result in 1 or 0) and significantly lower than always cooperating (which would get 3 or 5).
#
# With a "stable" performance trend and only 60% completion, the agent hasn't converged to a single dominant strategy. Further training is needed to see if it can adapt to different opponent behaviors and learn more robust strategies, like Tit-for-Tat. The current stability may indicate a local optimum or a need for adjustments in the learning rate or exploration parameters.
#
# ----------------------------------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1091         |
# |    iterations           | 15           |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 153600       |
# | train/                  |              |
# |    approx_kl            | 0.0075090826 |
# |    clip_fraction        | 0.0629       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.377       |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.7         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00475     |
# |    value_loss           | 39.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1095        |
# |    iterations           | 16          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.006029385 |
# |    clip_fraction        | 0.046       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.316      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.51        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00375    |
# |    value_loss           | 34.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1098        |
# |    iterations           | 17          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.004030117 |
# |    clip_fraction        | 0.0433      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.304      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.3        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00189    |
# |    value_loss           | 23.8        |
# -----------------------------------------
#
# 🤖 GEMINI TRAINING ANALYSIS     (Step 175,000)
# ----------------------------------------------------------------------
# The PPO agent, nearing the end of training (70% complete), exhibits a stable average reward of 3.04 in Prisoner's Dilemma. This suggests it's consistently achieving a cooperative outcome. A reward of 3.04 typically implies a pattern of mutual cooperation.
#
# Given the stable performance, the agent seems to have converged on a strategy that works reasonably well against its current mix of opponents. However, without detailed information on the opponents it faces, it's impossible to definitively say if it is truly adapting well across a variety of strategies or merely exploiting a specific weakness in its current environment.
#
# The training is progressing adequately, but further insight is needed to confirm robustness across diverse opponents.
#
# ----------------------------------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1088         |
# |    iterations           | 18           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0045234067 |
# |    clip_fraction        | 0.0549       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.295       |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.974        |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00178     |
# |    value_loss           | 12.4         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1089        |
# |    iterations           | 19          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.004588295 |
# |    clip_fraction        | 0.0434      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.276      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.47        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00192    |
# |    value_loss           | 11.6        |
# -----------------------------------------
#
# 🤖 GEMINI TRAINING ANALYSIS     (Step 200,000)
# ----------------------------------------------------------------------
# Based on the training status, the PPO agent appears to be learning a strategy that leans towards cooperation in the Prisoner's Dilemma. An average reward of 3.06 suggests the agent and its opponents are frequently cooperating (reward of 3 each). The "stable" performance trend indicates the agent has likely converged on this strategy, consistently achieving cooperation. Without information on different opponent types or exploration, it's difficult to definitively say if it's adapting well. It's possible it's exploiting a population primarily composed of cooperating agents, and may fail against defectors. Given the agent has reached 80% completion and stabilized, further training may not significantly alter the learned strategy.
#
# ----------------------------------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1079         |
# |    iterations           | 20           |
# |    time_elapsed         | 189          |
# |    total_timesteps      | 204800       |
# | train/                  |              |
# |    approx_kl            | 0.0043762163 |
# |    clip_fraction        | 0.0487       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.264       |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.09         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00307     |
# |    value_loss           | 7.66         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1082        |
# |    iterations           | 21          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 215040      |
# | train/                  |             |
# |    approx_kl            | 0.006786754 |
# |    clip_fraction        | 0.0554      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.251      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.49        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00561    |
# |    value_loss           | 5.05        |
# -----------------------------------------
#
# 🤖 GEMINI TRAINING ANALYSIS     (Step 225,000)
# ----------------------------------------------------------------------
# Based on the provided information, the PPO agent appears to be learning a predominantly cooperative strategy in the Prisoner's Dilemma. An average reward of 3.12, considering the reward structure (likely where mutual cooperation yields around 3 and mutual defection yields around 1), suggests a high degree of cooperation.
#
# The stability of the performance trend implies the agent has likely converged to this cooperative strategy and is no longer significantly adapting. While cooperation can be beneficial, without insights into its behavior against varied opponents, it's impossible to determine if the agent is successfully adapting to exploit defecting opponents.
#
# The training is nearing completion, and the agent has seemingly settled on a cooperative strategy. It may not be exhibiting optimal learning if it does not defect against defectors.
#
# ----------------------------------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1075       |
# |    iterations           | 22         |
# |    time_elapsed         | 209        |
# |    total_timesteps      | 225280     |
# | train/                  |            |
# |    approx_kl            | 0.00584073 |
# |    clip_fraction        | 0.045      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.223     |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.9        |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0042    |
# |    value_loss           | 8.46       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1078         |
# |    iterations           | 23           |
# |    time_elapsed         | 218          |
# |    total_timesteps      | 235520       |
# | train/                  |              |
# |    approx_kl            | 0.0036800082 |
# |    clip_fraction        | 0.0468       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.207       |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.951        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00341     |
# |    value_loss           | 4.49         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1082         |
# |    iterations           | 24           |
# |    time_elapsed         | 227          |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0040832856 |
# |    clip_fraction        | 0.0433       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.2         |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.15         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00225     |
# |    value_loss           | 1.72         |
# ------------------------------------------
#
# 🤖 GEMINI TRAINING ANALYSIS     (Step 250,000)
# ----------------------------------------------------------------------
# Based on the provided data, the PPO agent appears to be learning a **cooperative strategy** in the Prisoner's Dilemma, evidenced by the relatively high recent average reward of 3.21. In a single round Prisoner's Dilemma, mutual cooperation yields a reward of 3, so achieving 3.21 means that the agent is most of the time getting the reward for mutual cooperation.
# The agent is not being penalized much from defection.
# The "stable" performance trend suggests that the agent has likely converged on this strategy. Without more information on the opponent types encountered, we cannot definitively assess adaptation across different opponents. However, a reward of 3.21 suggests some level of robustness against opportunistic defection by others. The training progress seems complete, with the agent reaching the maximum number of steps and showing stable performance.
#
# ----------------------------------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1075         |
# |    iterations           | 25           |
# |    time_elapsed         | 238          |
# |    total_timesteps      | 256000       |
# | train/                  |              |
# |    approx_kl            | 0.0036631227 |
# |    clip_fraction        | 0.0416       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.186       |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.28         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00284     |
# |    value_loss           | 1.24         |
# ------------------------------------------
#
# ✅ Training completed! Model saved as 'ppo_all_strategies_with_gemini'
#
# 🧪 Testing PPO with Enhanced Analysis...
#
# 🔹 Loading PPO Model
#
# ============================================================
# 🧪 TESTING PPO AGAINST: TIT_FOR_TAT
# ============================================================
#
# 📋 DETAILED STEP-BY-STEP LOG:
# Step | Agent | Opponent | Reward | Cumulative | P(Coop)  | Notes
# --------------------------------------------------------------------------------
#   1 |     C |        C |    3.0 |        3.0 |    0.667 |
#   2 |     C |        C |    3.0 |        6.0 |    0.895 | TFT?
#   3 |     C |        C |    3.0 |        9.0 |    0.897 | TFT?
#   4 |     C |        C |    3.0 |       12.0 |    0.726 | TFT?
#   5 |     D |        C |    5.0 |       17.0 |    0.673 | EXPLOITING
#   6 |     C |        D |    0.0 |       17.0 |    0.171 | TFT? EXPLOITED
#   7 |     C |        C |    3.0 |       20.0 |    0.261 |
#   8 |     D |        C |    5.0 |       25.0 |    0.188 | EXPLOITING
#   9 |     D |        D |    1.0 |       26.0 |    0.031 |
#  10 |     C |        D |    0.0 |       26.0 |    0.183 | EXPLOITED
#  11 |     C |        C |    3.0 |       29.0 |    0.554 |
#  12 |     C |        C |    3.0 |       32.0 |    0.557 | TFT?
#  13 |     C |        C |    3.0 |       35.0 |    0.501 | TFT?
#  14 |     D |        C |    5.0 |       40.0 |    0.779 | EXPLOITING
#  15 |     C |        D |    0.0 |       40.0 |    0.996 | TFT? EXPLOITED
#  16 |     D |        C |    5.0 |       45.0 |    0.444 | TFT? EXPLOITING
#  17 |     C |        D |    0.0 |       45.0 |    0.998 | TFT? EXPLOITED
#  18 |     C |        C |    3.0 |       48.0 |    0.760 |
#  19 |     C |        C |    3.0 |       51.0 |    0.863 | TFT?
#  20 |     C |        C |    3.0 |       54.0 |    0.934 | TFT?
#  21 |     C |        C |    3.0 |       57.0 |    0.715 | TFT?
#  22 |     D |        C |    5.0 |       62.0 |    0.841 | EXPLOITING
#  23 |     C |        D |    0.0 |       62.0 |    0.996 | TFT? EXPLOITED
#  24 |     C |        C |    3.0 |       65.0 |    0.890 |
#  25 |     C |        C |    3.0 |       68.0 |    0.798 | TFT?
#  26 |     C |        C |    3.0 |       71.0 |    0.710 | TFT?
#  27 |     C |        C |    3.0 |       74.0 |    0.960 | TFT?
#  28 |     C |        C |    3.0 |       77.0 |    0.878 | TFT?
#  29 |     D |        C |    5.0 |       82.0 |    0.517 | EXPLOITING
#  30 |     C |        D |    0.0 |       82.0 |    0.999 | TFT? EXPLOITED
#  31 |     C |        C |    3.0 |       85.0 |    0.699 |
#  32 |     C |        C |    3.0 |       88.0 |    0.960 | TFT?
#  33 |     C |        C |    3.0 |       91.0 |    0.912 | TFT?
#  34 |     C |        C |    3.0 |       94.0 |    0.922 | TFT?
#  35 |     C |        C |    3.0 |       97.0 |    0.878 | TFT?
#  36 |     D |        C |    5.0 |      102.0 |    0.517 | EXPLOITING
#  37 |     C |        D |    0.0 |      102.0 |    0.999 | TFT? EXPLOITED
#  38 |     C |        C |    3.0 |      105.0 |    0.699 |
#  39 |     C |        C |    3.0 |      108.0 |    0.960 | TFT?
#  40 |     C |        C |    3.0 |      111.0 |    0.912 | TFT?
#  41 |     C |        C |    3.0 |      114.0 |    0.922 | TFT?
#  42 |     C |        C |    3.0 |      117.0 |    0.878 | TFT?
#  43 |     D |        C |    5.0 |      122.0 |    0.517 | EXPLOITING
#  44 |     C |        D |    0.0 |      122.0 |    0.999 | TFT? EXPLOITED
#  45 |     C |        C |    3.0 |      125.0 |    0.699 |
#  46 |     C |        C |    3.0 |      128.0 |    0.960 | TFT?
#  47 |     C |        C |    3.0 |      131.0 |    0.912 | TFT?
#  48 |     D |        C |    5.0 |      136.0 |    0.922 | EXPLOITING
#  49 |     C |        D |    0.0 |      136.0 |    0.999 | TFT? EXPLOITED
#  50 |     D |        C |    5.0 |      141.0 |    0.434 | TFT? EXPLOITING
#  51 |     C |        D |    0.0 |      141.0 |    0.999 | TFT? EXPLOITED
#  52 |     C |        C |    3.0 |      144.0 |    0.781 |
#  53 |     C |        C |    3.0 |      147.0 |    0.950 | TFT?
#  54 |     C |        C |    3.0 |      150.0 |    0.934 | TFT?
#  55 |     D |        C |    5.0 |      155.0 |    0.715 | EXPLOITING
#  56 |     C |        D |    0.0 |      155.0 |    0.997 | TFT? EXPLOITED
#  57 |     D |        C |    5.0 |      160.0 |    0.731 | TFT? EXPLOITING
#  58 |     C |        D |    0.0 |      160.0 |    0.999 | TFT? EXPLOITED
#  59 |     D |        C |    5.0 |      165.0 |    0.714 | TFT? EXPLOITING
#  60 |     C |        D |    0.0 |      165.0 |    0.999 | TFT? EXPLOITED
#  61 |     C |        C |    3.0 |      168.0 |    0.773 |
#  62 |     C |        C |    3.0 |      171.0 |    0.916 | TFT?
#  63 |     C |        C |    3.0 |      174.0 |    0.947 | TFT?
#  64 |     C |        C |    3.0 |      177.0 |    0.641 | TFT?
#  65 |     D |        C |    5.0 |      182.0 |    0.743 | EXPLOITING
#  66 |     C |        D |    0.0 |      182.0 |    0.995 | TFT? EXPLOITED
#  67 |     C |        C |    3.0 |      185.0 |    0.890 |
#  68 |     C |        C |    3.0 |      188.0 |    0.798 | TFT?
#  69 |     D |        C |    5.0 |      193.0 |    0.710 | EXPLOITING
#  70 |     C |        D |    0.0 |      193.0 |    1.000 | TFT? EXPLOITED
#  71 |     C |        C |    3.0 |      196.0 |    0.715 |
#  72 |     C |        C |    3.0 |      199.0 |    0.848 | TFT?
#  73 |     C |        C |    3.0 |      202.0 |    0.899 | TFT?
#  74 |     C |        C |    3.0 |      205.0 |    0.808 | TFT?
#  75 |     C |        C |    3.0 |      208.0 |    0.771 | TFT?
#  76 |     D |        C |    5.0 |      213.0 |    0.482 | EXPLOITING
#  77 |     C |        D |    0.0 |      213.0 |    0.999 | TFT? EXPLOITED
#  78 |     D |        C |    5.0 |      218.0 |    0.699 | TFT? EXPLOITING
#  79 |     C |        D |    0.0 |      218.0 |    0.999 | TFT? EXPLOITED
#  80 |     C |        C |    3.0 |      221.0 |    0.781 |
#  81 |     C |        C |    3.0 |      224.0 |    0.948 | TFT?
#  82 |     C |        C |    3.0 |      227.0 |    0.897 | TFT?
#  83 |     C |        C |    3.0 |      230.0 |    0.715 | TFT?
#  84 |     C |        C |    3.0 |      233.0 |    0.841 | TFT?
#  85 |     C |        C |    3.0 |      236.0 |    0.597 | TFT?
#  86 |     C |        C |    3.0 |      239.0 |    0.817 | TFT?
#  87 |     C |        C |    3.0 |      242.0 |    0.631 | TFT?
#  88 |     D |        C |    5.0 |      247.0 |    0.760 | EXPLOITING
#  89 |     C |        D |    0.0 |      247.0 |    0.999 | TFT? EXPLOITED
#  90 |     C |        C |    3.0 |      250.0 |    0.717 |
#  91 |     C |        C |    3.0 |      253.0 |    0.946 | TFT?
#  92 |     C |        C |    3.0 |      256.0 |    0.838 | TFT?
#  93 |     C |        C |    3.0 |      259.0 |    0.922 | TFT?
#  94 |     D |        C |    5.0 |      264.0 |    0.878 | EXPLOITING
#  95 |     C |        D |    0.0 |      264.0 |    0.998 | TFT? EXPLOITED
#  96 |     C |        C |    3.0 |      267.0 |    0.847 |
#  97 |     C |        C |    3.0 |      270.0 |    0.724 | TFT?
#  98 |     C |        C |    3.0 |      273.0 |    0.710 | TFT?
#  99 |     C |        C |    3.0 |      276.0 |    0.960 | TFT?
# 100 |     C |        C |    3.0 |      279.0 |    0.878 | TFT?
#
# 🤖 GEMINI ANALYSIS    (Step 100)
# ------------------------------------------------------------
# The PPO agent appears to have learned a strategy that's largely cooperative but incorporates occasional defections. It starts with a strong cooperative streak, then defects, and continues with further cooperation with another defection, then more cooperation.
#
# Against Tit-for-Tat, this strategy is moderately effective. The cooperation rate of 80% suggests a good degree of alignment, but the 69.7% Tit-for-Tat match indicates that the agent's defections are not always reciprocated immediately, leading to some "misunderstandings." Tit-for-Tat punishes the agent's defections, causing the agent to return to cooperation. The agent's strategy seems to be attempting to exploit Tit-for-Tat's forgiving nature by occasionally defecting to gain a slightly higher reward before reverting to cooperation. The recent reward of 2.90 suggests that the agent benefits from this behaviour overall.
#
# ------------------------------------------------------------
#
# 📋 CONTINUING STEP LOG:
# Step | Agent | Opponent | Reward | Cumulative | P(Coop)  | Notes
# --------------------------------------------------------------------------------
# 101 |     D |        C |    5.0 |      284.0 |    0.517 | EXPLOITING
# 102 |     C |        D |    0.0 |      284.0 |    0.999 | TFT? EXPLOITED
# 103 |     C |        C |    3.0 |      287.0 |    0.699 |
# 104 |     C |        C |    3.0 |      290.0 |    0.960 | TFT?
# 105 |     C |        C |    3.0 |      293.0 |    0.912 | TFT?
# 106 |     C |        C |    3.0 |      296.0 |    0.922 | TFT?
# 107 |     C |        C |    3.0 |      299.0 |    0.878 | TFT?
# 108 |     C |        C |    3.0 |      302.0 |    0.517 | TFT?
# 109 |     C |        C |    3.0 |      305.0 |    0.859 | TFT?
# 110 |     D |        C |    5.0 |      310.0 |    0.650 | EXPLOITING
# 111 |     C |        D |    0.0 |      310.0 |    0.998 | TFT? EXPLOITED
# 112 |     D |        C |    5.0 |      315.0 |    0.663 | TFT? EXPLOITING
# 113 |     C |        D |    0.0 |      315.0 |    1.000 | TFT? EXPLOITED
# 114 |     C |        C |    3.0 |      318.0 |    0.879 |
# 115 |     C |        C |    3.0 |      321.0 |    0.948 | TFT?
# 116 |     C |        C |    3.0 |      324.0 |    0.897 | TFT?
# 117 |     C |        C |    3.0 |      327.0 |    0.715 | TFT?
# 118 |     D |        C |    5.0 |      332.0 |    0.841 | EXPLOITING
# 119 |     C |        D |    0.0 |      332.0 |    0.996 | TFT? EXPLOITED
# 120 |     C |        C |    3.0 |      335.0 |    0.890 |
# 121 |     D |        C |    5.0 |      340.0 |    0.798 | EXPLOITING
# 122 |     C |        D |    0.0 |      340.0 |    0.996 | TFT? EXPLOITED
# 123 |     C |        C |    3.0 |      343.0 |    0.901 |
# 124 |     C |        C |    3.0 |      346.0 |    0.933 | TFT?
# 125 |     D |        C |    5.0 |      351.0 |    0.767 | EXPLOITING
# 126 |     C |        D |    0.0 |      351.0 |    0.999 | TFT? EXPLOITED
# 127 |     D |        C |    5.0 |      356.0 |    0.594 | TFT? EXPLOITING
# 128 |     C |        D |    0.0 |      356.0 |    0.993 | TFT? EXPLOITED
# 129 |     C |        C |    3.0 |      359.0 |    0.895 |
# 130 |     C |        C |    3.0 |      362.0 |    0.871 | TFT?
# 131 |     C |        C |    3.0 |      365.0 |    0.902 | TFT?
# 132 |     C |        C |    3.0 |      368.0 |    0.834 | TFT?
# 133 |     C |        C |    3.0 |      371.0 |    0.841 | TFT?
# 134 |     C |        C |    3.0 |      374.0 |    0.597 | TFT?
# 135 |     C |        C |    3.0 |      377.0 |    0.817 | TFT?
# 136 |     C |        C |    3.0 |      380.0 |    0.631 | TFT?
# 137 |     C |        C |    3.0 |      383.0 |    0.760 | TFT?
# 138 |     C |        C |    3.0 |      386.0 |    0.849 | TFT?
# 139 |     C |        C |    3.0 |      389.0 |    0.785 | TFT?
# 140 |     C |        C |    3.0 |      392.0 |    0.785 | TFT?
# 141 |     C |        C |    3.0 |      395.0 |    0.785 | TFT?
# 142 |     D |        C |    5.0 |      400.0 |    0.785 | EXPLOITING
# 143 |     C |        D |    0.0 |      400.0 |    1.000 | TFT? EXPLOITED
# 144 |     C |        C |    3.0 |      403.0 |    0.717 |
# 145 |     C |        C |    3.0 |      406.0 |    0.946 | TFT?
# 146 |     C |        C |    3.0 |      409.0 |    0.838 | TFT?
# 147 |     C |        C |    3.0 |      412.0 |    0.922 | TFT?
# 148 |     D |        C |    5.0 |      417.0 |    0.878 | EXPLOITING
# 149 |     C |        D |    0.0 |      417.0 |    0.998 | TFT? EXPLOITED
# 150 |     C |        C |    3.0 |      420.0 |    0.847 |
# 151 |     D |        C |    5.0 |      425.0 |    0.724 | EXPLOITING
# 152 |     C |        D |    0.0 |      425.0 |    0.996 | TFT? EXPLOITED
# 153 |     C |        C |    3.0 |      428.0 |    0.901 |
# 154 |     C |        C |    3.0 |      431.0 |    0.933 | TFT?
# 155 |     D |        C |    5.0 |      436.0 |    0.767 | EXPLOITING
# 156 |     C |        D |    0.0 |      436.0 |    0.999 | TFT? EXPLOITED
# 157 |     C |        C |    3.0 |      439.0 |    0.594 |
# 158 |     C |        C |    3.0 |      442.0 |    0.630 | TFT?
# 159 |     C |        C |    3.0 |      445.0 |    0.959 | TFT?
# 160 |     C |        C |    3.0 |      448.0 |    0.808 | TFT?
# 161 |     C |        C |    3.0 |      451.0 |    0.771 | TFT?
# 162 |     D |        C |    5.0 |      456.0 |    0.482 | EXPLOITING
# 163 |     C |        D |    0.0 |      456.0 |    0.999 | TFT? EXPLOITED
# 164 |     D |        C |    5.0 |      461.0 |    0.699 | TFT? EXPLOITING
# 165 |     C |        D |    0.0 |      461.0 |    0.999 | TFT? EXPLOITED
# 166 |     C |        C |    3.0 |      464.0 |    0.781 |
# 167 |     C |        C |    3.0 |      467.0 |    0.948 | TFT?
# 168 |     C |        C |    3.0 |      470.0 |    0.897 | TFT?
# 169 |     D |        C |    5.0 |      475.0 |    0.715 | EXPLOITING
# 170 |     C |        D |    0.0 |      475.0 |    0.997 | TFT? EXPLOITED
# 171 |     C |        C |    3.0 |      478.0 |    0.731 |
# 172 |     C |        C |    3.0 |      481.0 |    0.963 | TFT?
# 173 |     C |        C |    3.0 |      484.0 |    0.675 | TFT?
# 174 |     C |        C |    3.0 |      487.0 |    0.807 | TFT?
# 175 |     C |        C |    3.0 |      490.0 |    0.924 | TFT?
# 176 |     C |        C |    3.0 |      493.0 |    0.517 | TFT?
# 177 |     C |        C |    3.0 |      496.0 |    0.859 | TFT?
# 178 |     D |        C |    5.0 |      501.0 |    0.650 | EXPLOITING
# 179 |     C |        D |    0.0 |      501.0 |    0.998 | TFT? EXPLOITED
# 180 |     D |        C |    5.0 |      506.0 |    0.663 | TFT? EXPLOITING
# 181 |     C |        D |    0.0 |      506.0 |    1.000 | TFT? EXPLOITED
# 182 |     C |        C |    3.0 |      509.0 |    0.879 |
# 183 |     C |        C |    3.0 |      512.0 |    0.948 | TFT?
# 184 |     C |        C |    3.0 |      515.0 |    0.897 | TFT?
# 185 |     C |        C |    3.0 |      518.0 |    0.715 | TFT?
# 186 |     C |        C |    3.0 |      521.0 |    0.841 | TFT?
# 187 |     C |        C |    3.0 |      524.0 |    0.597 | TFT?
# 188 |     C |        C |    3.0 |      527.0 |    0.817 | TFT?
# 189 |     C |        C |    3.0 |      530.0 |    0.631 | TFT?
# 190 |     D |        C |    5.0 |      535.0 |    0.760 | EXPLOITING
# 191 |     C |        D |    0.0 |      535.0 |    0.999 | TFT? EXPLOITED
# 192 |     C |        C |    3.0 |      538.0 |    0.717 |
# 193 |     C |        C |    3.0 |      541.0 |    0.946 | TFT?
# 194 |     C |        C |    3.0 |      544.0 |    0.838 | TFT?
# 195 |     C |        C |    3.0 |      547.0 |    0.922 | TFT?
# 196 |     C |        C |    3.0 |      550.0 |    0.878 | TFT?
# 197 |     D |        C |    5.0 |      555.0 |    0.517 | EXPLOITING
# 198 |     C |        D |    0.0 |      555.0 |    0.999 | TFT? EXPLOITED
# 199 |     C |        C |    3.0 |      558.0 |    0.699 |
# 200 |     C |        C |    3.0 |      561.0 |    0.960 | TFT?
#
# 🤖 GEMINI ANALYSIS    (Step 200)
# ------------------------------------------------------------
# The PPO agent learned a predominantly cooperative strategy, but with occasional defections ("D") to test the opponent and potentially exploit periods of vulnerability. It starts with a long string of cooperation ("C"), possibly to establish trust. The defections are spaced out, suggesting a calculated risk-reward approach rather than random exploration.
#
# Against Tit-for-Tat, this strategy has mixed success. The 81% cooperation rate is good, indicating a general alignment with reciprocal altruism. However, the 70.9% Tit-for-Tat match shows the agent deviates from pure reciprocity, especially with its defections. The recent reward of 2.60 suggests the agent is profiting from its interactions, meaning it's exploiting Tit-for-Tat to some degree.  The agent seems to be attempting to "milk" Tit-for-Tat's forgiveness by strategically defecting after periods of cooperation.
#
# ------------------------------------------------------------
#
# 📋 CONTINUING STEP LOG:
# Step | Agent | Opponent | Reward | Cumulative | P(Coop)  | Notes
# --------------------------------------------------------------------------------
# 201 |     C |        C |    3.0 |      564.0 |    0.912 | TFT?
# 202 |     C |        C |    3.0 |      567.0 |    0.922 | TFT?
# 203 |     C |        C |    3.0 |      570.0 |    0.878 | TFT?
# 204 |     C |        C |    3.0 |      573.0 |    0.517 | TFT?
# 205 |     C |        C |    3.0 |      576.0 |    0.859 | TFT?
# 206 |     C |        C |    3.0 |      579.0 |    0.650 | TFT?
# 207 |     C |        C |    3.0 |      582.0 |    0.760 | TFT?
# 208 |     C |        C |    3.0 |      585.0 |    0.849 | TFT?
# 209 |     C |        C |    3.0 |      588.0 |    0.785 | TFT?
# 210 |     C |        C |    3.0 |      591.0 |    0.785 | TFT?
# 211 |     C |        C |    3.0 |      594.0 |    0.785 | TFT?
# 212 |     C |        C |    3.0 |      597.0 |    0.785 | TFT?
# 213 |     C |        C |    3.0 |      600.0 |    0.785 | TFT?
# ...
# 312 |     D |        C |    5.0 |     1248.0 |    0.001 | EXPLOITING
# 313 |     C |        C |    3.0 |     1251.0 |    0.998 | TFT?
# 314 |     D |        C |    5.0 |     1256.0 |    0.001 | EXPLOITING
# 315 |     C |        C |    3.0 |     1259.0 |    0.998 | TFT?
# 316 |     D |        C |    5.0 |     1264.0 |    0.001 | EXPLOITING
# 317 |     C |        C |    3.0 |     1267.0 |    0.998 | TFT?
# 318 |     D |        C |    5.0 |     1272.0 |    0.001 | EXPLOITING
# 319 |     C |        C |    3.0 |     1275.0 |    0.998 | TFT?
# 320 |     D |        C |    5.0 |     1280.0 |    0.001 | EXPLOITING
# 321 |     C |        C |    3.0 |     1283.0 |    0.998 | TFT?
# 322 |     D |        C |    5.0 |     1288.0 |    0.001 | EXPLOITING
# 323 |     C |        C |    3.0 |     1291.0 |    0.998 | TFT?
# 324 |     D |        C |    5.0 |     1296.0 |    0.001 | EXPLOITING
# 325 |     C |        C |    3.0 |     1299.0 |    0.998 | TFT?
# 326 |     D |        C |    5.0 |     1304.0 |    0.001 | EXPLOITING
# 327 |     C |        C |    3.0 |     1307.0 |    0.998 | TFT?
# 328 |     D |        C |    5.0 |     1312.0 |    0.001 | EXPLOITING
# 329 |     C |        C |    3.0 |     1315.0 |    0.998 | TFT?
# 330 |     D |        C |    5.0 |     1320.0 |    0.001 | EXPLOITING
# 331 |     C |        C |    3.0 |     1323.0 |    0.998 | TFT?
# 332 |     D |        C |    5.0 |     1328.0 |    0.001 | EXPLOITING
# 333 |     C |        C |    3.0 |     1331.0 |    0.998 | TFT?
# 334 |     D |        C |    5.0 |     1336.0 |    0.001 | EXPLOITING
# 335 |     C |        C |    3.0 |     1339.0 |    0.998 | TFT?
# 336 |     D |        C |    5.0 |     1344.0 |    0.001 | EXPLOITING
# 337 |     C |        C |    3.0 |     1347.0 |    0.998 | TFT?
# 338 |     D |        C |    5.0 |     1352.0 |    0.001 | EXPLOITING
# 339 |     C |        C |    3.0 |     1355.0 |    0.998 | TFT?
# 340 |     D |        C |    5.0 |     1360.0 |    0.001 | EXPLOITING
# 341 |     C |        C |    3.0 |     1363.0 |    0.998 | TFT?
# 342 |     D |        C |    5.0 |     1368.0 |    0.001 | EXPLOITING
# 343 |     C |        C |    3.0 |     1371.0 |    0.998 | TFT?
# 344 |     D |        C |    5.0 |     1376.0 |    0.001 | EXPLOITING
# 345 |     C |        C |    3.0 |     1379.0 |    0.998 | TFT?
# 346 |     D |        C |    5.0 |     1384.0 |    0.001 | EXPLOITING
# 347 |     C |        C |    3.0 |     1387.0 |    0.998 | TFT?
# 348 |     D |        C |    5.0 |     1392.0 |    0.001 | EXPLOITING
# 349 |     C |        C |    3.0 |     1395.0 |    0.998 | TFT?
# 350 |     D |        C |    5.0 |     1400.0 |    0.001 | EXPLOITING
# 351 |     C |        C |    3.0 |     1403.0 |    0.998 | TFT?
# 352 |     D |        C |    5.0 |     1408.0 |    0.001 | EXPLOITING
# 353 |     C |        C |    3.0 |     1411.0 |    0.998 | TFT?
# 354 |     D |        C |    5.0 |     1416.0 |    0.001 | EXPLOITING
# 355 |     C |        C |    3.0 |     1419.0 |    0.998 | TFT?
# 356 |     D |        C |    5.0 |     1424.0 |    0.001 | EXPLOITING
# 357 |     C |        C |    3.0 |     1427.0 |    0.998 | TFT?
# 358 |     D |        C |    5.0 |     1432.0 |    0.001 | EXPLOITING
# 359 |     C |        C |    3.0 |     1435.0 |    0.998 | TFT?
# 360 |     D |        C |    5.0 |     1440.0 |    0.001 | EXPLOITING
# 361 |     C |        C |    3.0 |     1443.0 |    0.998 | TFT?
# 362 |     D |        C |    5.0 |     1448.0 |    0.001 | EXPLOITING
# 363 |     C |        C |    3.0 |     1451.0 |    0.998 | TFT?
# 364 |     D |        C |    5.0 |     1456.0 |    0.001 | EXPLOITING
# 365 |     C |        C |    3.0 |     1459.0 |    0.998 | TFT?
# 366 |     D |        C |    5.0 |     1464.0 |    0.001 | EXPLOITING
# 367 |     C |        C |    3.0 |     1467.0 |    0.998 | TFT?
# 368 |     D |        C |    5.0 |     1472.0 |    0.001 | EXPLOITING
# 369 |     C |        C |    3.0 |     1475.0 |    0.998 | TFT?
# 370 |     D |        C |    5.0 |     1480.0 |    0.001 | EXPLOITING
# 371 |     C |        C |    3.0 |     1483.0 |    0.998 | TFT?
# 372 |     D |        C |    5.0 |     1488.0 |    0.001 | EXPLOITING
# 373 |     C |        C |    3.0 |     1491.0 |    0.998 | TFT?
# 374 |     D |        C |    5.0 |     1496.0 |    0.001 | EXPLOITING
# 375 |     C |        C |    3.0 |     1499.0 |    0.998 | TFT?
# 376 |     D |        C |    5.0 |     1504.0 |    0.001 | EXPLOITING
# 377 |     C |        C |    3.0 |     1507.0 |    0.998 | TFT?
# 378 |     D |        C |    5.0 |     1512.0 |    0.001 | EXPLOITING
# 379 |     C |        C |    3.0 |     1515.0 |    0.998 | TFT?
# 380 |     D |        C |    5.0 |     1520.0 |    0.001 | EXPLOITING
# 381 |     C |        C |    3.0 |     1523.0 |    0.998 | TFT?
# 382 |     D |        C |    5.0 |     1528.0 |    0.001 | EXPLOITING
# 383 |     C |        C |    3.0 |     1531.0 |    0.998 | TFT?
# 384 |     D |        C |    5.0 |     1536.0 |    0.001 | EXPLOITING
# 385 |     C |        C |    3.0 |     1539.0 |    0.998 | TFT?
# 386 |     D |        C |    5.0 |     1544.0 |    0.001 | EXPLOITING
# 387 |     C |        C |    3.0 |     1547.0 |    0.998 | TFT?
# 388 |     D |        C |    5.0 |     1552.0 |    0.001 | EXPLOITING
# 389 |     C |        C |    3.0 |     1555.0 |    0.998 | TFT?
# 390 |     D |        C |    5.0 |     1560.0 |    0.001 | EXPLOITING
# 391 |     C |        C |    3.0 |     1563.0 |    0.998 | TFT?
# 392 |     D |        C |    5.0 |     1568.0 |    0.001 | EXPLOITING
# 393 |     C |        C |    3.0 |     1571.0 |    0.998 | TFT?
# 394 |     D |        C |    5.0 |     1576.0 |    0.001 | EXPLOITING
# 395 |     C |        C |    3.0 |     1579.0 |    0.998 | TFT?
# 396 |     D |        C |    5.0 |     1584.0 |    0.001 | EXPLOITING
# 397 |     C |        C |    3.0 |     1587.0 |    0.998 | TFT?
# 398 |     D |        C |    5.0 |     1592.0 |    0.001 | EXPLOITING
# 399 |     C |        C |    3.0 |     1595.0 |    0.998 | TFT?
# 400 |     D |        C |    5.0 |     1600.0 |    0.001 | EXPLOITING
#
# 🤖 GEMINI ANALYSIS    (Step 400)
# ------------------------------------------------------------
# The PPO agent has learned a strategy of alternating between cooperation (C) and defection (D). This is a simple pattern, resulting in a 50% cooperation rate.
#
# Against an `always_cooperate` opponent, this strategy achieves a decent, but suboptimal, outcome. The agent exploits the opponent's consistent cooperation by defecting every other turn, gaining a higher reward (4.00).
#
# The "Tit-for-Tat Match" score of 49.9% is misleading in this case. It suggests a near-TFT performance based on matching past actions, yet the agent is performing a fixed alternating action. It's only considered Tit-for-Tat in this case, if cooperation is the previous action and the agent cooperates next time (or vice versa with defection).
#
# While effective in exploiting `always_cooperate`, this strategy is vulnerable against other strategies. A more sophisticated approach would analyze the opponent's actions and adjust accordingly.
#
# ------------------------------------------------------------
#
# 📋 CONTINUING STEP LOG:
# Step | Agent | Opponent | Reward | Cumulative | P(Coop)  | Notes
# --------------------------------------------------------------------------------
# 401 |     C |        C |    3.0 |     1603.0 |    0.998 | TFT?
# 402 |     D |        C |    5.0 |     1608.0 |    0.001 | EXPLOITING
# 403 |     C |        C |    3.0 |     1611.0 |    0.998 | TFT?
# 404 |     D |        C |    5.0 |     1616.0 |    0.001 | EXPLOITING
# 405 |     C |        C |    3.0 |     1619.0 |    0.998 | TFT?
# 406 |     D |        C |    5.0 |     1624.0 |    0.001 | EXPLOITING
# 407 |     C |        C |    3.0 |     1627.0 |    0.998 | TFT?
# 408 |     D |        C |    5.0 |     1632.0 |    0.001 | EXPLOITING
# 409 |     C |        C |    3.0 |     1635.0 |    0.998 | TFT?
# 410 |     D |        C |    5.0 |     1640.0 |    0.001 | EXPLOITING
# 411 |     C |        C |    3.0 |     1643.0 |    0.998 | TFT?
# 412 |     D |        C |    5.0 |     1648.0 |    0.001 | EXPLOITING
# 413 |     C |        C |    3.0 |     1651.0 |    0.998 | TFT?
# 414 |     D |        C |    5.0 |     1656.0 |    0.001 | EXPLOITING
# 415 |     C |        C |    3.0 |     1659.0 |    0.998 | TFT?
# 416 |     D |        C |    5.0 |     1664.0 |    0.001 | EXPLOITING
# 417 |     C |        C |    3.0 |     1667.0 |    0.998 | TFT?
# 418 |     D |        C |    5.0 |     1672.0 |    0.001 | EXPLOITING
# 419 |     C |        C |    3.0 |     1675.0 |    0.998 | TFT?
# 420 |     D |        C |    5.0 |     1680.0 |    0.001 | EXPLOITING
# 421 |     C |        C |    3.0 |     1683.0 |    0.998 | TFT?
# 422 |     D |        C |    5.0 |     1688.0 |    0.001 | EXPLOITING
# 423 |     C |        C |    3.0 |     1691.0 |    0.998 | TFT?
# 424 |     D |        C |    5.0 |     1696.0 |    0.001 | EXPLOITING
# 425 |     C |        C |    3.0 |     1699.0 |    0.998 | TFT?
# 426 |     D |        C |    5.0 |     1704.0 |    0.001 | EXPLOITING
# 427 |     C |        C |    3.0 |     1707.0 |    0.998 | TFT?
# 428 |     D |        C |    5.0 |     1712.0 |    0.001 | EXPLOITING
# 429 |     C |        C |    3.0 |     1715.0 |    0.998 | TFT?
# 430 |     D |        C |    5.0 |     1720.0 |    0.001 | EXPLOITING
# 431 |     C |        C |    3.0 |     1723.0 |    0.998 | TFT?
# 432 |     D |        C |    5.0 |     1728.0 |    0.001 | EXPLOITING
# 433 |     C |        C |    3.0 |     1731.0 |    0.998 | TFT?
# 434 |     D |        C |    5.0 |     1736.0 |    0.001 | EXPLOITING
# 435 |     C |        C |    3.0 |     1739.0 |    0.998 | TFT?
# 436 |     D |        C |    5.0 |     1744.0 |    0.001 | EXPLOITING
# 437 |     C |        C |    3.0 |     1747.0 |    0.998 | TFT?
# 438 |     D |        C |    5.0 |     1752.0 |    0.001 | EXPLOITING
# 439 |     C |        C |    3.0 |     1755.0 |    0.998 | TFT?
# 440 |     D |        C |    5.0 |     1760.0 |    0.001 | EXPLOITING
# 441 |     C |        C |    3.0 |     1763.0 |    0.998 | TFT?
# 442 |     D |        C |    5.0 |     1768.0 |    0.001 | EXPLOITING
# 443 |     C |        C |    3.0 |     1771.0 |    0.998 | TFT?
# 444 |     D |        C |    5.0 |     1776.0 |    0.001 | EXPLOITING
# 445 |     C |        C |    3.0 |     1779.0 |    0.998 | TFT?
# 446 |     D |        C |    5.0 |     1784.0 |    0.001 | EXPLOITING
# 447 |     C |        C |    3.0 |     1787.0 |    0.998 | TFT?
# 448 |     D |        C |    5.0 |     1792.0 |    0.001 | EXPLOITING
# 449 |     C |        C |    3.0 |     1795.0 |    0.998 | TFT?
# 450 |     D |        C |    5.0 |     1800.0 |    0.001 | EXPLOITING
# 451 |     C |        C |    3.0 |     1803.0 |    0.998 | TFT?
# 452 |     D |        C |    5.0 |     1808.0 |    0.001 | EXPLOITING
# 453 |     C |        C |    3.0 |     1811.0 |    0.998 | TFT?
# 454 |     D |        C |    5.0 |     1816.0 |    0.001 | EXPLOITING
# 455 |     C |        C |    3.0 |     1819.0 |    0.998 | TFT?
# 456 |     D |        C |    5.0 |     1824.0 |    0.001 | EXPLOITING
# 457 |     C |        C |    3.0 |     1827.0 |    0.998 | TFT?
# 458 |     D |        C |    5.0 |     1832.0 |    0.001 | EXPLOITING
# 459 |     C |        C |    3.0 |     1835.0 |    0.998 | TFT?
# 460 |     D |        C |    5.0 |     1840.0 |    0.001 | EXPLOITING
# 461 |     C |        C |    3.0 |     1843.0 |    0.998 | TFT?
# 462 |     D |        C |    5.0 |     1848.0 |    0.001 | EXPLOITING
# 463 |     C |        C |    3.0 |     1851.0 |    0.998 | TFT?
# 464 |     D |        C |    5.0 |     1856.0 |    0.001 | EXPLOITING
# 465 |     C |        C |    3.0 |     1859.0 |    0.998 | TFT?
# 466 |     D |        C |    5.0 |     1864.0 |    0.001 | EXPLOITING
# 467 |     C |        C |    3.0 |     1867.0 |    0.998 | TFT?
# 468 |     D |        C |    5.0 |     1872.0 |    0.001 | EXPLOITING
# 469 |     C |        C |    3.0 |     1875.0 |    0.998 | TFT?
# 470 |     D |        C |    5.0 |     1880.0 |    0.001 | EXPLOITING
# 471 |     C |        C |    3.0 |     1883.0 |    0.998 | TFT?
# 472 |     D |        C |    5.0 |     1888.0 |    0.001 | EXPLOITING
# 473 |     C |        C |    3.0 |     1891.0 |    0.998 | TFT?
# 474 |     D |        C |    5.0 |     1896.0 |    0.001 | EXPLOITING
# 475 |     C |        C |    3.0 |     1899.0 |    0.998 | TFT?
# 476 |     D |        C |    5.0 |     1904.0 |    0.001 | EXPLOITING
# 477 |     C |        C |    3.0 |     1907.0 |    0.998 | TFT?
# 478 |     D |        C |    5.0 |     1912.0 |    0.001 | EXPLOITING
# 479 |     C |        C |    3.0 |     1915.0 |    0.998 | TFT?
# 480 |     D |        C |    5.0 |     1920.0 |    0.001 | EXPLOITING
# 481 |     C |        C |    3.0 |     1923.0 |    0.998 | TFT?
# 482 |     D |        C |    5.0 |     1928.0 |    0.001 | EXPLOITING
# 483 |     C |        C |    3.0 |     1931.0 |    0.998 | TFT?
# 484 |     D |        C |    5.0 |     1936.0 |    0.001 | EXPLOITING
# 485 |     C |        C |    3.0 |     1939.0 |    0.998 | TFT?
# 486 |     D |        C |    5.0 |     1944.0 |    0.001 | EXPLOITING
# 487 |     C |        C |    3.0 |     1947.0 |    0.998 | TFT?
# 488 |     D |        C |    5.0 |     1952.0 |    0.001 | EXPLOITING
# 489 |     C |        C |    3.0 |     1955.0 |    0.998 | TFT?
# 490 |     D |        C |    5.0 |     1960.0 |    0.001 | EXPLOITING
# 491 |     C |        C |    3.0 |     1963.0 |    0.998 | TFT?
# 492 |     D |        C |    5.0 |     1968.0 |    0.001 | EXPLOITING
# 493 |     C |        C |    3.0 |     1971.0 |    0.998 | TFT?
# 494 |     D |        C |    5.0 |     1976.0 |    0.001 | EXPLOITING
# 495 |     C |        C |    3.0 |     1979.0 |    0.998 | TFT?
# 496 |     D |        C |    5.0 |     1984.0 |    0.001 | EXPLOITING
# 497 |     C |        C |    3.0 |     1987.0 |    0.998 | TFT?
# 498 |     D |        C |    5.0 |     1992.0 |    0.001 | EXPLOITING
# 499 |     C |        C |    3.0 |     1995.0 |    0.998 | TFT?
# 500 |     D |        C |    5.0 |     2000.0 |    0.001 | EXPLOITING
#
# 🤖 GEMINI ANALYSIS    (Step 500)
# ------------------------------------------------------------
# The PPO agent has learned an "Alternating" strategy, cycling between cooperation (C) and defection (D). This results in a 50% cooperation rate.
#
# Against `always_cooperate`, this strategy yields a moderately effective outcome. While `always_cooperate` never defects, the alternating strategy capitalizes on this by defecting every other turn.
#
# **Effectiveness Analysis:**
#
# *   **Agent Defects (D), Opponent Cooperates (C):** Agent receives a high reward.
# *   **Agent Cooperates (C), Opponent Cooperates (C):** Agent receives a lower reward.
#
# Therefore, the alternating strategy exploits `always_cooperate` for an advantage, resulting in a net positive reward structure for the agent, even though it isn't maximizing possible cooperation.
#
# ------------------------------------------------------------
#
# 📋 CONTINUING STEP LOG:
# Step | Agent | Opponent | Reward | Cumulative | P(Coop)  | Notes
# --------------------------------------------------------------------------------
#
# 📊 MATCH SUMMARY:
# Agent: PPO_vs_always_cooperate
# Total Reward: 2000.0
# Average Reward per Episode: 4.00
# Agent Cooperation Rate: 50.0%
# Opponent Cooperation Rate: 100.0%
#
# ================================================================================
# 🧠 COMPREHENSIVE GEMINI STRATEGY ANALYSIS
# ================================================================================
# Strategy comparison unavailable: 429 You exceeded your current quota, please check ...
#
# ================================================================================
# 📊 FINAL PPO PERFORMANCE SUMMARY
# ================================================================================
#          tit_for_tat: 1401.0 pts | Avg:  2.80 | Coop: 80.6% | vs 80.6% opp
# generous_tit_for_tat: 1428.0 pts | Avg:  2.86 | Coop: 76.2% | vs 79.6% opp
#     tit_for_two_tats: 1975.0 pts | Avg:  3.95 | Coop: 49.2% | vs 98.2% opp
#        always_defect:  491.0 pts | Avg:  0.98 | Coop:  1.8% | vs  0.0% opp
#     always_cooperate: 2000.0 pts | Avg:  4.00 | Coop: 50.0% | vs 100.0% opp

# %%
import random
import numpy as np
import gym
import torch
import json
import time
import warnings
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import BaseCallback
import google.generativeai as genai
from typing import List, Dict, Tuple

# Suppress warnings
warnings.filterwarnings("ignore", category=UserWarning)

# ==================================
# 📌 GEMINI API INTEGRATION
# ==================================
class GeminiAnalyzer:
    def __init__(self, api_key: str):
        """Initialize Gemini API for strategy analysis"""
        genai.configure(api_key=api_key)
        self.model = genai.GenerativeModel('gemini-2.0-flash')
        
    def analyze_strategy_evolution(self, agent_id: str, move_history: List[str], 
                                 opponent_history: List[str], probabilities: List[float],
                                 rewards: List[float], opponent_name: str, 
                                 is_training: bool = False, training_step: int = 0) -> str:
        """Analyze how the PPO agent's strategy evolves over time with enhanced strategy detection"""
        
        # Add rate limiting to respect API limits
        time.sleep(0.5)
        
        # Calculate additional metrics for strategy analysis
        recent_moves = move_history[-20:] if len(move_history) >= 20 else move_history
        recent_opp_moves = opponent_history[-20:] if len(opponent_history) >= 20 else opponent_history
        
        # Pattern analysis
        consecutive_cooperations = 0
        consecutive_defections = 0
        max_coop_streak = 0
        max_defect_streak = 0
        current_coop_streak = 0
        current_defect_streak = 0
        
        for move in move_history:
            if move == 'C':
                current_coop_streak += 1
                current_defect_streak = 0
                max_coop_streak = max(max_coop_streak, current_coop_streak)
            else:
                current_defect_streak += 1
                current_coop_streak = 0
                max_defect_streak = max(max_defect_streak, current_defect_streak)
        
        # Tit-for-tat analysis
        tit_for_tat_matches = 0
        if len(move_history) > 1 and len(opponent_history) > 0:
            for i in range(1, min(len(move_history), len(opponent_history))):
                if move_history[i] == opponent_history[i-1]:
                    tit_for_tat_matches += 1
        
        tit_for_tat_percentage = (tit_for_tat_matches / max(1, len(move_history)-1)) * 100
        
        # Response to opponent's last move
        responses_to_coop = [move_history[i] for i in range(len(move_history)) if i > 0 and opponent_history[i-1] == 'C']
        responses_to_defect = [move_history[i] for i in range(len(move_history)) if i > 0 and opponent_history[i-1] == 'D']
        
        coop_after_coop = responses_to_coop.count('C') / max(1, len(responses_to_coop)) * 100
        coop_after_defect = responses_to_defect.count('C') / max(1, len(responses_to_defect)) * 100
        
        # Create enhanced analysis prompt with training/testing context
        training_context = ""
        if is_training:
            training_context = f"""
        TRAINING CONTEXT:
        - Training Step: {training_step:,}
        - Phase: LEARNING (agent is actively updating its policy)
        - Focus: How is the agent's strategy EVOLVING during training?
        """
        else:
            training_context = """
        TESTING CONTEXT:
        - Phase: EVALUATION (agent is using learned policy)
        - Focus: What strategy has the agent LEARNED from training?
        """
        
        prompt = f"""
        You are analyzing a PPO reinforcement learning agent playing the Prisoner's Dilemma. Your task is to identify what strategy the agent has learned and how it's adapting.

        GAME CONTEXT:
        - Agent ID: {agent_id}
        - Opponent Strategy: {opponent_name}
        - Total Moves Played: {len(move_history)}
        {training_context}
        
        MOVE SEQUENCES (most recent 30 moves):
        Agent:    {' '.join(move_history[-30:])}
        Opponent: {' '.join(opponent_history[-30:])}
        
        BEHAVIORAL METRICS:
        - Agent Cooperation Rate: {move_history.count('C') / len(move_history) * 100:.1f}%
        - Opponent Cooperation Rate: {opponent_history.count('C') / len(opponent_history) * 100:.1f}%
        - Tit-for-Tat Adherence: {tit_for_tat_percentage:.1f}%
        - Cooperate after Opponent Cooperates: {coop_after_coop:.1f}%
        - Cooperate after Opponent Defects: {coop_after_defect:.1f}%
        - Max Cooperation Streak: {max_coop_streak}
        - Max Defection Streak: {max_defect_streak}
        - Current Streak: {current_coop_streak if move_history[-1] == 'C' else current_defect_streak} {'cooperations' if move_history[-1] == 'C' else 'defections'}
        
        DECISION PROBABILITIES (last 15):
        Cooperation Probabilities: {[f'{p:.3f}' for p in probabilities[-15:]]}
        
        PERFORMANCE METRICS:
        - Recent Rewards (last 15): {[f'{r:.1f}' for r in rewards[-15:]]}
        - Average Recent Reward: {np.mean(rewards[-20:]) if len(rewards) >= 20 else np.mean(rewards):.2f}
        - Reward Trend: {'Improving' if len(rewards) >= 10 and np.mean(rewards[-5:]) > np.mean(rewards[-10:-5]) else 'Declining' if len(rewards) >= 10 else 'Establishing'}
        
        STRATEGIC ANALYSIS QUESTIONS:
        1. **Primary Strategy Identification**: What well-known strategy does this agent most closely resemble? 
           Consider: Tit-for-Tat, Always Cooperate, Always Defect, Generous Tit-for-Tat, Random etc.
        
        2. **Adaptation Pattern**: How is the agent modifying its approach based on the opponent's behavior?
        
        3. **Learning Evidence**: What evidence shows the agent is {'learning and evolving' if is_training else 'applying learned strategy'}?
        
        4. **Exploitation vs Cooperation**: Is the agent being exploitative, cooperative, or strategic?
        
        5. **Prediction**: Based on current patterns, how will the agent likely behave in the next 10 moves?
        
        6. **Strategy Effectiveness**: How well is this {'evolving' if is_training else 'learned'} strategy performing against {opponent_name}?
        
        {'7. **Training Progress**: What changes do you observe compared to earlier in training? Is the strategy stabilizing?' if is_training else ''}
        
        Please provide a concise but comprehensive analysis (max 250 words) focusing on strategy identification and {'learning evolution' if is_training else 'learned patterns'}.
        """
        
        try:
            response = self.model.generate_content(prompt)
            return response.text
        except Exception as e:
            return f"Gemini analysis temporarily unavailable: {str(e)[:100]}..."
    
    def compare_strategies(self, results: Dict[str, Dict], is_training: bool = False) -> str:
        """Compare PPO performance across different opponent strategies with enhanced analysis"""
        
        # Add rate limiting
        time.sleep(1.0)
        
        # Calculate cross-strategy metrics
        best_performance = max(results.values(), key=lambda x: x['total_reward'])
        worst_performance = min(results.values(), key=lambda x: x['total_reward'])
        
        training_context = "TRAINING ANALYSIS" if is_training else "TESTING ANALYSIS"
        phase_description = "learning and adaptation" if is_training else "final learned strategy"
        
        prompt = f"""
        {training_context}: Analyze the PPO agent's {phase_description} by comparing its performance across different Prisoner's Dilemma opponents.

        PERFORMANCE SUMMARY:
        {json.dumps(results, indent=2)}
        
        COMPARATIVE ANALYSIS:
        - Best Performance: {[k for k, v in results.items() if v['total_reward'] == best_performance['total_reward']][0]} (Score: {best_performance['total_reward']:.1f})
        - Worst Performance: {[k for k, v in results.items() if v['total_reward'] == worst_performance['total_reward']][0]} (Score: {worst_performance['total_reward']:.1f})
        - Performance Range: {best_performance['total_reward'] - worst_performance['total_reward']:.1f} points
        
        STRATEGIC QUESTIONS TO ANALYZE:
        
        1. **Overall Strategy Classification**: Based on all matchups, what is the PPO agent's {'emerging' if is_training else 'primary learned'} strategy?
           - Is it closer to Tit-for-Tat, Always Defect, Generous strategies, or something unique?
        
        2. **Opponent-Specific Adaptations**: How does the agent's cooperation rate change based on opponent type?
           - Against cooperative opponents vs. aggressive opponents
           - Does it show strategic flexibility or fixed behavior?
        
        3. **Exploitation Patterns**: 
           - Which opponents does it successfully exploit?
           - Which opponents exploit it?
           - What does this reveal about its {'developing' if is_training else 'learned'} weaknesses/strengths?
        
        4. **Learning Sophistication**: 
           - Does the agent show sophisticated counter-strategies?
           - Or is it using simple heuristics?
        
        5. **Strategic Robustness**: 
           - Is this a well-rounded strategy or does it have clear vulnerabilities?
           - How would it perform against novel opponents?
        
        6. **Reward Optimization**: 
           - Is the agent maximizing mutual benefit or self-interest?
           - How does this align with game theory predictions?
        
        {'7. **Training Evolution**: How is the strategy developing? What patterns suggest continued learning?' if is_training else '7. **Final Assessment**: How sophisticated and effective is the final learned strategy?'}
        
        Provide comprehensive strategic insights about what the PPO agent has {'learned so far and how it\'s evolving' if is_training else 'learned and how sophisticated its strategy is'} (max 400 words).
        Focus on identifying the core strategic principles it has discovered through reinforcement learning.
        """
        
        try:
            response = self.model.generate_content(prompt)
            return response.text
        except Exception as e:
            return f"Gemini comparison temporarily unavailable: {str(e)[:100]}..."

# ==================================
# 📌 ENHANCED PRISONER'S DILEMMA ENVIRONMENT
# ==================================
class PrisonersDilemmaEnv(gym.Env):
    def __init__(self, strategy, agent_id="PPO_AGENT", history_len=10):
        super(PrisonersDilemmaEnv, self).__init__()
        self.history_len = history_len
        self.agent_id = agent_id
        self.action_space = gym.spaces.Discrete(2)  # 0: Cooperate, 1: Defect
        self.observation_space = gym.spaces.Box(low=0, high=5, shape=(3 * self.history_len,), dtype=np.float32)

        self.strategy = strategy
        self.agent_history = []
        self.opponent_history = []
        self.reward_history = []
        
        # Enhanced tracking for Gemini analysis
        self.full_agent_history = []
        self.full_opponent_history = []
        self.full_reward_history = []
        self.action_probabilities = []

    def step(self, action):
        opponent_action = 0 if self.strategy(self.agent_history, self.opponent_history, False) == 'C' else 1
        reward = self.get_reward(action, opponent_action)

        # Update histories
        self.agent_history.append(action)
        self.opponent_history.append(opponent_action)
        self.reward_history.append(reward)
        
        # Update full histories for analysis
        self.full_agent_history.append(action)
        self.full_opponent_history.append(opponent_action)
        self.full_reward_history.append(reward)

        # Maintain sliding window
        if len(self.agent_history) > self.history_len:
            self.agent_history.pop(0)
            self.opponent_history.pop(0)
            self.reward_history.pop(0)

        obs = self._get_obs()
        return obs, reward, False, {}

    def reset(self):
        self.agent_history = []
        self.opponent_history = []
        self.reward_history = []
        return self._get_obs()

    def _get_obs(self):
        pad = lambda x: x + [0] * (self.history_len - len(x))
        return np.array(pad(self.agent_history) + pad(self.opponent_history) + pad(self.reward_history), dtype=np.float32)

    def get_reward(self, action, opponent_action):
        # Classic Prisoner's Dilemma payoff matrix
        if action == 0 and opponent_action == 0:      # Both cooperate
            return 3
        elif action == 1 and opponent_action == 1:    # Both defect
            return 1
        elif action == 0 and opponent_action == 1:    # Agent cooperates, opponent defects
            return 0
        else:                                         # Agent defects, opponent cooperates
            return 5
    
    def add_action_probability(self, prob):
        """Store action probability for analysis"""
        self.action_probabilities.append(prob)

# ==================================
# 📌 GEMINI TRAINING CALLBACK
# ==================================
class GeminiTrainingCallback(BaseCallback):
    def __init__(self, gemini_analyzer: GeminiAnalyzer, analysis_frequency: int = 10000, verbose: int = 0):
        super(GeminiTrainingCallback, self).__init__(verbose)
        self.gemini_analyzer = gemini_analyzer
        self.analysis_frequency = analysis_frequency
        self.last_analysis_step = 0
        
    def _on_step(self) -> bool:
        # Check if it's time for analysis
        if self.num_timesteps - self.last_analysis_step >= self.analysis_frequency:
            self.last_analysis_step = self.num_timesteps
            
            # Get environment data for analysis
            try:
                # Access the first environment (assuming DummyVecEnv)
                env = self.training_env.envs[0]
                
                if hasattr(env, 'full_agent_history') and len(env.full_agent_history) > 50:
                    # Convert to symbolic moves
                    agent_moves = ['C' if a == 0 else 'D' for a in env.full_agent_history]
                    opponent_moves = ['C' if a == 0 else 'D' for a in env.full_opponent_history]
                    
                    # Get strategy name from environment
                    strategy_name = getattr(env, 'strategy_name', 'Unknown')
                    
                    print(f"\n{'='*60}")
                    print(f"🧠 GEMINI TRAINING ANALYSIS - Step {self.num_timesteps:,}")
                    print(f"{'='*60}")
                    
                    # Perform Gemini analysis
                    analysis = self.gemini_analyzer.analyze_strategy_evolution(
                        agent_id=env.agent_id,
                        move_history=agent_moves,
                        opponent_history=opponent_moves,
                        probabilities=env.action_probabilities[-100:] if len(env.action_probabilities) > 100 else env.action_probabilities,
                        rewards=env.full_reward_history,
                        opponent_name=strategy_name,
                        is_training=True,
                        training_step=self.num_timesteps
                    )
                    
                    print(analysis)
                    print("="*60)
                    
            except Exception as e:
                if self.verbose > 0:
                    print(f"Training analysis error: {str(e)[:100]}...")
        
        return True

# ==================================
# 📌 STRATEGIES (with proper conversion)
# ==================================
def to_symbolic(hist):
    return ['C' if a == 0 else 'D' for a in hist]

def tit_for_tat(agent_hist, opp_hist, __):
    return 'C' if not agent_hist else ('C' if agent_hist[-1] == 0 else 'D')

def tit_for_two_tats(agent_hist, opp_hist, __):
    if len(agent_hist) >= 2 and agent_hist[-2:] == [1, 1]:
        return 'D'
    return 'C'

def generous_tit_for_tat(agent_hist, opp_hist, __, cooperation_prob=0.1):
    if not agent_hist:
        return 'C'
    if agent_hist[-1] == 1:
        return 'C' if random.random() < cooperation_prob else 'D'
    return 'C'

def always_cooperate(*args): return 'C'
def always_defect(*args): return 'D'
def random_strategy(*args): return random.choice(['C', 'D'])
def friedman(agent_hist, opp_hist, __): return 'D' if 1 in agent_hist else 'C'

def joss(agent_hist, opp_hist, __):
    if agent_hist and random.random() < 0.1:
        return 'D'
    if agent_hist: 
        return 'C' if agent_hist[-1] == 0 else 'D'
    return 'C'

def grasskamp(agent_hist, opp_hist, __):
    return 'D' if len(agent_hist) >= 3 and agent_hist[-3:] == [1, 1, 1] else 'C'

def sample(agent_hist, opp_hist, __): return random.choice(['C', 'C', 'D'])
def tester(agent_hist, opp_hist, __): return 'D' if not agent_hist else 'C'
def opportunist(agent_hist, opp_hist, __): return 'D' if agent_hist and agent_hist[-1] == 0 else 'C'
def backstabber(agent_hist, opp_hist, __): return 'C' if len(agent_hist) < 5 else 'D'
def chaos_agent(*args): return random.choice(['C', 'D'])

# ==================================
# 📌 ENHANCED TRAIN PPO WITH GEMINI ANALYSIS
# ==================================
def train_ppo_with_gemini(gemini_api_key: str, history_len=10, total_timesteps=150000, analysis_frequency=30000):
    """Train PPO with Gemini analysis during training"""
    
    strategies = {
        
        "tit_for_two_tats": tit_for_two_tats,
       
    }

    # Initialize Gemini analyzer
    analyzer = GeminiAnalyzer(gemini_api_key)
    
    print("🚀 Training PPO Agent with Gemini Analysis...")
    print(f"Total timesteps: {total_timesteps:,}")
    print(f"Analysis frequency: every {analysis_frequency:,} steps")
    print("="*60)

    # Create environments with strategy names for better tracking
    envs = []
    for i, (name, strategy) in enumerate(strategies.items()):
        def make_env(s=strategy, n=name, aid=f"PPO_vs_{name}_training"):
            env = PrisonersDilemmaEnv(s, agent_id=aid, history_len=history_len)
            env.strategy_name = n  # Add strategy name for callback
            return env
        envs.append(make_env)
    
    vec_env = DummyVecEnv(envs)

    # Create PPO model
    model = PPO("MlpPolicy", vec_env, verbose=1, ent_coef=0.01)
    
    # Create Gemini callback for training analysis
    gemini_callback = GeminiTrainingCallback(
        gemini_analyzer=analyzer,
        analysis_frequency=analysis_frequency,
        verbose=1
    )
    
    # Train with Gemini analysis
    model.learn(total_timesteps=total_timesteps, callback=gemini_callback)
    
    # Final training analysis
    print("\n" + "="*80)
    print("🎯 FINAL GEMINI TRAINING ANALYSIS")
    print("="*80)
    
    # Collect final training data from all environments
    training_results = {}
    for i, (name, _) in enumerate(strategies.items()):
        env = vec_env.envs[i]
        if hasattr(env, 'full_agent_history') and len(env.full_agent_history) > 0:
            agent_moves = ['C' if a == 0 else 'D' for a in env.full_agent_history]
            opponent_moves = ['C' if a == 0 else 'D' for a in env.full_opponent_history]
            
            training_results[name] = {
                'total_reward': float(np.sum(env.full_reward_history)),
                'average_reward': float(np.mean(env.full_reward_history)),
                'cooperation_rate': agent_moves.count('C') / len(agent_moves),
                'opponent_cooperation_rate': opponent_moves.count('C') / len(opponent_moves),
                'total_episodes': len(env.full_agent_history),
                'agent_id': env.agent_id
            }
    
    if training_results:
        final_analysis = analyzer.compare_strategies(training_results, is_training=True)
        print(final_analysis)
    
    # Save model
    model.save("ppo_all_strategies_full_history_with_gemini")
    print("\n✅ Model saved as 'ppo_all_strategies_full_history_with_gemini'")
    
    return model, training_results

# ==================================
# 📌 ENHANCED TEST WITH DETAILED LOGGING AND GEMINI ANALYSIS
# ==================================
def test_ppo_with_gemini(gemini_api_key: str, model_path: str = None, history_len=10, 
                        print_steps=True, analyze_every=100, num_episodes=500):
    """Test PPO with detailed step logging and Gemini analysis integration"""
    
    strategies = {
    
        "tit_for_two_tats": tit_for_two_tats,
       
    }

    # Initialize Gemini analyzer
    analyzer = GeminiAnalyzer(gemini_api_key)
    
    # Load model
    if model_path:
        print(f"\n🔹 Loading PPO Model from: {model_path}")
        model = PPO.load(model_path)
    else:
        print("\n🔹 Loading Default PPO Model")
        try:
            model = PPO.load("ppo_all_strategies_full_history_with_gemini")
        except:
            model = PPO.load("ppo_all_strategies_full_history")
    
    results = {}
    detailed_results = {}

    for name, strategy in strategies.items():
        print(f"\n{'='*60}")
        print(f"🧪 TESTING PPO AGAINST: {name.upper()}")
        print(f"{'='*60}")
        
        agent_id = f"PPO_vs_{name}_test"
        env = DummyVecEnv([lambda s=strategy, aid=agent_id: PrisonersDilemmaEnv(s, agent_id=aid, history_len=history_len)])
        obs = env.reset()
        total_reward = 0
        
        # Detailed logging header
        if print_steps:
            print(f"\n📋 DETAILED STEP-BY-STEP LOG:")
            print(f"{'Step':<4} | {'Agent':<5} | {'Opponent':<8} | {'Reward':<6} | {'Cumulative':<10} | {'P(Coop)':<8} | {'Notes'}")
            print("-" * 80)

        for i in range(num_episodes):
            # Get action and probabilities more robustly
            action, _ = model.predict(obs, deterministic=False)
            
            # Get action probabilities with proper device handling
            try:
                # Ensure tensor is on the same device as the model
                device = next(model.policy.parameters()).device
                obs_tensor = torch.FloatTensor(obs).to(device)
                
                with torch.no_grad():
                    # Extract features and get logits
                    features = model.policy.extract_features(obs_tensor)
                    latent_pi = model.policy.mlp_extractor.forward_actor(features)
                    logits = model.policy.action_net(latent_pi)
                    action_probs = torch.softmax(logits, dim=-1)
                    prob_cooperate = float(action_probs[0][0].cpu())
            except Exception as e:
                # Fallback: use a simple heuristic based on recent actions
                prob_cooperate = 0.5  # Default probability
                if i == 0:  # Only print warning once
                    print(f"Warning: Using default probability due to: {str(e)[:50]}...")
            
            # Take step
            obs, reward, done, _ = env.step(action)
            action_val = int(action[0])
            
            # Store probability
            env.envs[0].add_action_probability(prob_cooperate)
            
            opponent_action = env.envs[0].opponent_history[-1]
            total_reward += reward[0]
            
            # Detailed step logging
            if print_steps:
                # Determine notes for interesting patterns
                notes = ""
                if i > 0:
                    prev_opp = env.envs[0].full_opponent_history[-2] if len(env.envs[0].full_opponent_history) >= 2 else None
                    if prev_opp is not None:
                        if action_val == prev_opp:
                            notes += "TFT? "
                        if action_val == 0 and opponent_action == 1:
                            notes += "EXPLOITED "
                        elif action_val == 1 and opponent_action == 0:
                            notes += "EXPLOITING "
                
                print(f"{i+1:>3d} | {'C' if action_val==0 else 'D':>5} | {'C' if opponent_action==0 else 'D':>8} | "
                      f"{reward[0]:>6.1f} | {total_reward:>10.1f} | {prob_cooperate:>8.3f} | {notes}")
            
            # Periodic Gemini analysis
            if (i + 1) % analyze_every == 0:
                print(f"\n{'🤖 GEMINI ANALYSIS':<20} (Step {i+1})")
                print("-" * 60)
                
                agent_moves = ['C' if a == 0 else 'D' for a in env.envs[0].full_agent_history]
                opponent_moves = ['C' if a == 0 else 'D' for a in env.envs[0].full_opponent_history]
                
                analysis = analyzer.analyze_strategy_evolution(
                    agent_id=agent_id,
                    move_history=agent_moves,
                    opponent_history=opponent_moves,
                    probabilities=env.envs[0].action_probabilities,
                    rewards=env.envs[0].full_reward_history,
                    opponent_name=name,
                    is_training=False
                )
                print(analysis)
                print("-" * 60)
                
                if print_steps:
                    print(f"\n📋 CONTINUING STEP LOG:")
                    print(f"{'Step':<4} | {'Agent':<5} | {'Opponent':<8} | {'Reward':<6} | {'Cumulative':<10} | {'P(Coop)':<8} | {'Notes'}")
                    print("-" * 80)

        # Store detailed results
        agent_moves = ['C' if a == 0 else 'D' for a in env.envs[0].full_agent_history]
        opponent_moves = ['C' if a == 0 else 'D' for a in env.envs[0].full_opponent_history]
        
        detailed_results[name] = {
            'total_reward': float(total_reward),
            'average_reward': float(total_reward / num_episodes),
            'cooperation_rate': agent_moves.count('C') / len(agent_moves),
            'opponent_cooperation_rate': opponent_moves.count('C') / len(opponent_moves),
            'avg_reward': float(np.mean(env.envs[0].full_reward_history)),
            'final_probabilities': env.envs[0].action_probabilities[-10:] if len(env.envs[0].action_probabilities) >= 10 else env.envs[0].action_probabilities,
            'agent_id': agent_id,
            'total_episodes': num_episodes
        }
        
        results[name] = total_reward
        
        # Summary for this opponent
        print(f"\n📊 MATCH SUMMARY:")
        print(f"Agent: {agent_id}")
        print(f"Total Reward: {total_reward:.1f}")
        print(f"Average Reward per Episode: {total_reward/num_episodes:.2f}")
        print(f"Agent Cooperation Rate: {detailed_results[name]['cooperation_rate']:.1%}")
        print(f"Opponent Cooperation Rate: {detailed_results[name]['opponent_cooperation_rate']:.1%}")

        # Final comprehensive analysis
        print("\n" + "="*80)
        print("🧠 COMPREHENSIVE GEMINI STRATEGY ANALYSIS")
        print("="*80)
        
        final_analysis = analyzer.compare_strategies(detailed_results)
        print(final_analysis)
        
        print("\n" + "="*80)
        print("📊 FINAL PPO PERFORMANCE SUMMARY")
        print("="*80)
        for strategy, score in results.items():
            details = detailed_results[strategy]
            print(f"{strategy:>20}: {score:>6.1f} pts | Avg: {details['average_reward']:>5.2f} | "
                  f"Coop: {details['cooperation_rate']:>5.1%} | "
                  f"vs {details['opponent_cooperation_rate']:>5.1%} opp")
        
        return results, detailed_results

# ==================================
# 📌 MAIN EXECUTION WITH GEMINI
# ==================================
def main():
    # You need to set your Gemini API key here
    GEMINI_API_KEY = "AIzaSyALn5gEk1DeBNoIFRBdk52K3d_S5JKyC3M"  # Replace with your actual API key
    
    if not GEMINI_API_KEY or GEMINI_API_KEY == "":
        print("⚠️  Please set your Gemini API key in the GEMINI_API_KEY variable")
        print("You can get one from: https://makersuite.google.com/app/apikey")
        return
    
    print("🚀 Training PPO Agent with Gemini Analysis...")
    train_ppo_with_gemini(GEMINI_API_KEY, total_timesteps=250000)
    
    print("\n🧪 Testing PPO with Enhanced Analysis...")
    results, detailed_results = test_ppo_with_gemini(
        gemini_api_key=GEMINI_API_KEY,
        print_steps=True,       # Enable detailed step-by-step logging
        analyze_every=100,      # Analyze every 100 steps
        num_episodes=500        # Number of episodes per opponent
    )

# ==================================
# 🚀 RUN TRAINING & TESTING
# ==================================
if __name__ == "__main__":
    main()
# Out:
#   File "/tmp/ipykernel_35/4206120097.py", line 199
#     """
#        ^
# SyntaxError: f-string expression part cannot include a backslash

# %%
import random
import numpy as np
import gym
import torch
import json
import time
import warnings
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import BaseCallback
import google.generativeai as genai
from typing import List, Dict, Tuple

# Suppress warnings
warnings.filterwarnings("ignore", category=UserWarning)

# ==================================
# 📌 ENHANCED GEMINI API INTEGRATION WITH PPO METRICS
# ==================================
class GeminiAnalyzer:
    def __init__(self, api_key: str):
        """Initialize Gemini API for strategy analysis"""
        genai.configure(api_key=api_key)
        self.model = genai.GenerativeModel('gemini-2.0-flash')
        
    def analyze_strategy_evolution(self, agent_id: str, move_history: List[str], 
                                 opponent_history: List[str], probabilities: List[float],
                                 rewards: List[float], opponent_name: str, 
                                 ppo_metrics: Dict = None,
                                 is_training: bool = False, training_step: int = 0) -> str:
        """Analyze how the PPO agent's strategy evolves with comprehensive RL metrics"""
        
        # Add rate limiting to respect API limits
        time.sleep(0.5)
        
        # Calculate additional metrics for strategy analysis
        recent_moves = move_history[-20:] if len(move_history) >= 20 else move_history
        recent_opp_moves = opponent_history[-20:] if len(opponent_history) >= 20 else opponent_history
        
        # Pattern analysis
        consecutive_cooperations = 0
        consecutive_defections = 0
        max_coop_streak = 0
        max_defect_streak = 0
        current_coop_streak = 0
        current_defect_streak = 0
        
        for move in move_history:
            if move == 'C':
                current_coop_streak += 1
                current_defect_streak = 0
                max_coop_streak = max(max_coop_streak, current_coop_streak)
            else:
                current_defect_streak += 1
                current_coop_streak = 0
                max_defect_streak = max(max_defect_streak, current_defect_streak)
        
        # Tit-for-tat analysis
        tit_for_tat_matches = 0
        if len(move_history) > 1 and len(opponent_history) > 0:
            for i in range(1, min(len(move_history), len(opponent_history))):
                if move_history[i] == opponent_history[i-1]:
                    tit_for_tat_matches += 1
        
        tit_for_tat_percentage = (tit_for_tat_matches / max(1, len(move_history)-1)) * 100
        
        # Response to opponent's last move
        responses_to_coop = [move_history[i] for i in range(len(move_history)) if i > 0 and opponent_history[i-1] == 'C']
        responses_to_defect = [move_history[i] for i in range(len(move_history)) if i > 0 and opponent_history[i-1] == 'D']
        
        coop_after_coop = responses_to_coop.count('C') / max(1, len(responses_to_coop)) * 100
        coop_after_defect = responses_to_defect.count('C') / max(1, len(responses_to_defect)) * 100
        
        # Value function and policy analysis
        value_trend = "N/A"
        policy_entropy_trend = "N/A"
        exploration_analysis = "N/A"
        advantage_analysis = "N/A"
        
        if ppo_metrics:
            # Value function analysis
            if 'value_estimates' in ppo_metrics and len(ppo_metrics['value_estimates']) > 10:
                recent_values = ppo_metrics['value_estimates'][-10:]
                early_values = ppo_metrics['value_estimates'][:10] if len(ppo_metrics['value_estimates']) > 20 else ppo_metrics['value_estimates'][:5]
                if len(early_values) > 0:
                    value_trend = f"Recent: {np.mean(recent_values):.3f}, Early: {np.mean(early_values):.3f} ({'Rising' if np.mean(recent_values) > np.mean(early_values) else 'Falling'})"
            
            # Policy entropy analysis
            if 'policy_entropy' in ppo_metrics and len(ppo_metrics['policy_entropy']) > 5:
                entropy_recent = np.mean(ppo_metrics['policy_entropy'][-10:])
                policy_entropy_trend = f"Current: {entropy_recent:.4f} ({'High exploration' if entropy_recent > 0.5 else 'Low exploration' if entropy_recent < 0.2 else 'Moderate exploration'})"
            
            # Exploration vs exploitation analysis
            if 'action_probabilities' in ppo_metrics and len(ppo_metrics['action_probabilities']) > 10:
                recent_probs = ppo_metrics['action_probabilities'][-20:]
                prob_variance = np.var(recent_probs)
                avg_confidence = np.mean([max(p, 1-p) for p in recent_probs])
                exploration_analysis = f"Prob variance: {prob_variance:.4f}, Avg confidence: {avg_confidence:.3f} ({'Exploring' if prob_variance > 0.05 else 'Exploiting'})"
            
            # Advantage analysis
            if 'advantages' in ppo_metrics and len(ppo_metrics['advantages']) > 5:
                recent_advantages = ppo_metrics['advantages'][-15:]
                avg_advantage = np.mean(recent_advantages)
                advantage_std = np.std(recent_advantages)
                advantage_analysis = f"Mean: {avg_advantage:.3f}, Std: {advantage_std:.3f} ({'High variance' if advantage_std > 1.0 else 'Stable learning'})"

        # Create enhanced analysis prompt with training/testing context
        training_context = ""
        if is_training:
            training_context = f"""
        TRAINING CONTEXT:
        - Training Step: {training_step:,}
        - Phase: LEARNING (agent is actively updating its policy)
        - Focus: How is the agent's strategy EVOLVING during training?
        """
        else:
            training_context = """
        TESTING CONTEXT:
        - Phase: EVALUATION (agent is using learned policy)
        - Focus: What strategy has the agent LEARNED from training?
        """
        
        # Enhanced prompt with PPO-specific metrics
        prompt = f"""
        You are analyzing a PPO (Proximal Policy Optimization) reinforcement learning agent playing the Prisoner's Dilemma. 
        Your task is to identify what strategy the agent has learned and how its policy is evolving using both behavioral and internal RL metrics.

        GAME CONTEXT:
        - Agent ID: {agent_id}
        - Opponent Strategy: {opponent_name}
        - Total Moves Played: {len(move_history)}
        {training_context}
        
        MOVE SEQUENCES (most recent 30 moves):
        Agent:    {' '.join(move_history[-30:])}
        Opponent: {' '.join(opponent_history[-30:])}
        
        BEHAVIORAL METRICS:
        - Agent Cooperation Rate: {move_history.count('C') / len(move_history) * 100:.1f}%
        - Opponent Cooperation Rate: {opponent_history.count('C') / len(opponent_history) * 100:.1f}%
        - Tit-for-Tat Adherence: {tit_for_tat_percentage:.1f}%
        - Cooperate after Opponent Cooperates: {coop_after_coop:.1f}%
        - Cooperate after Opponent Defects: {coop_after_defect:.1f}%
        - Max Cooperation Streak: {max_coop_streak}
        - Max Defection Streak: {max_defect_streak}
        - Current Streak: {current_coop_streak if move_history[-1] == 'C' else current_defect_streak} {'cooperations' if move_history[-1] == 'C' else 'defections'}
        
        POLICY NETWORK METRICS:
        - Decision Probabilities (last 15): {[f'{p:.3f}' for p in probabilities[-15:]]}
        - Probability Variance (recent): {np.var(probabilities[-20:]) if len(probabilities) >= 20 else np.var(probabilities):.4f}
        - Decision Confidence Trend: {'High' if np.mean([max(p, 1-p) for p in probabilities[-10:]]) > 0.8 else 'Moderate' if np.mean([max(p, 1-p) for p in probabilities[-10:]]) > 0.6 else 'Low'}
        
        PPO LEARNING METRICS:
        - Value Function Trend: {value_trend}
        - Policy Entropy: {policy_entropy_trend}
        - Exploration Analysis: {exploration_analysis}
        - Advantage Estimates: {advantage_analysis}
        
        PERFORMANCE METRICS:
        - Recent Rewards (last 15): {[f'{r:.1f}' for r in rewards[-15:]]}
        - Average Recent Reward: {np.mean(rewards[-20:]) if len(rewards) >= 20 else np.mean(rewards):.2f}
        - Reward Trend: {'Improving' if len(rewards) >= 10 and np.mean(rewards[-5:]) > np.mean(rewards[-10:-5]) else 'Declining' if len(rewards) >= 10 else 'Establishing'}
        - Reward Variance: {np.var(rewards[-20:]) if len(rewards) >= 20 else np.var(rewards):.3f}
        
        STRATEGIC ANALYSIS QUESTIONS (Enhanced with RL perspective):
        
        1. **Policy Learning Assessment**: How has the PPO policy network learned to map states to actions?
           - Is the policy becoming more deterministic (low entropy) or maintaining exploration?
           - Are decision probabilities showing clear patterns or randomness?
        
        2. **Value Function Understanding**: What does the value function trend suggest about state evaluation?
           - Is the agent learning to accurately predict future rewards?
           - How does value estimation correlate with actual performance?
        
        3. **Exploration vs Exploitation Balance**: 
           - Is the agent still exploring (high probability variance) or exploiting learned strategy?
           - How does policy entropy relate to strategic behavior?
        
        4. **Advantage Learning**: What do advantage estimates reveal about action selection?
           - Are advantages stable (indicating consistent strategy) or volatile (still learning)?
           - How do advantages correlate with opponent responses?
        
        6. **Policy Gradient Insights**: Based on probability patterns and entropy:
           - Is the policy converging to a stable strategy?
           - Are there signs of continued policy updates or has it plateaued?
        
        7. **Opponent Modeling**: Does the agent show evidence of learning opponent patterns?(name the opponent based on ur observation and explain how the agent is playing with the opponet)
           - How quickly does it adapt to opponent strategy changes?
           - Is it using history effectively for decision making?
        
        8. **Risk and Uncertainty**: How does the agent handle uncertainty?
           - Does it maintain cautious (cooperative) or aggressive (defective) defaults?
           - How does probability variance relate to performance variance?
        
        {'9. **Training Dynamics**: What changes in RL metrics suggest about learning progress?' if is_training else '9. **Final Policy Assessment**: How sophisticated and robust is the learned policy?'}
        
        Please provide a comprehensive analysis (max 500 words) that integrates both behavioral patterns and PPO learning dynamics and give ur answer in points similar to question.
        Focus on how the internal RL metrics explain the observed strategic behavior and {'learning trajectory' if is_training else 'final learned strategy'}.
        """
        
        try:
            response = self.model.generate_content(prompt)
            return response.text
        except Exception as e:
            return f"Gemini analysis temporarily unavailable: {str(e)[:100]}..."
    
    def compare_strategies(self, results: Dict[str, Dict], is_training: bool = False) -> str:
        """Compare PPO performance across different opponent strategies with enhanced RL analysis"""
        
        # Add rate limiting
        time.sleep(1.0)
        
        # Calculate cross-strategy metrics
        best_performance = max(results.values(), key=lambda x: x['total_reward'])
        worst_performance = min(results.values(), key=lambda x: x['total_reward'])
        
        training_context = "TRAINING ANALYSIS" if is_training else "TESTING ANALYSIS"
        phase_description = "policy learning and adaptation" if is_training else "final learned policy"
        
        prompt = f"""
        {training_context}: Analyze the PPO agent's {phase_description} by comparing its performance across different Prisoner's Dilemma opponents.
        Focus on how PPO's learning mechanisms produced different strategic adaptations.

        PERFORMANCE SUMMARY:
        {json.dumps(results, indent=2)}
        
        COMPARATIVE ANALYSIS:
        - Best Performance: {[k for k, v in results.items() if v['total_reward'] == best_performance['total_reward']][0]} (Score: {best_performance['total_reward']:.1f})
        - Worst Performance: {[k for k, v in results.items() if v['total_reward'] == worst_performance['total_reward']][0]} (Score: {worst_performance['total_reward']:.1f})
        - Performance Range: {best_performance['total_reward'] - worst_performance['total_reward']:.1f} points
        - Performance Variance: {np.var([v['total_reward'] for v in results.values()]):.2f}
        
        PPO LEARNING ANALYSIS QUESTIONS:
        
        1. **Policy Generalization**: How well did PPO learn a generalizable strategy vs. opponent-specific adaptations?(explain how it is performing with the opponent at hand and also name the opponent )
           - Does the agent show consistent strategic principles across opponents?(if more than one opponent can be observed)
           - Or did it overfit to specific opponent patterns?
        
        2. **Multi-Task Learning**: How effectively did PPO handle the multi-environment training?
           - Did training against diverse opponents create a robust policy?
           - Are there signs of catastrophic forgetting or interference?
        
        3. **Value Function Accuracy**: How do performance differences relate to value estimation quality?
           - Which opponents did the agent learn to evaluate most accurately?(Imp)
           - Where do we see value function errors affecting performance?
        
        4. **Policy Gradient Effectiveness**: What does the cooperation rate variation tell us about policy learning?
           - Did PPO successfully learn different action probabilities for different contexts?
           - How well did it balance exploration vs exploitation across environments?
        
        5. **Strategic Sophistication**: Based on the results, how sophisticated is the learned policy?
           - Simple reactive strategies (Tit-for-Tat variants)?
           - Complex multi-step reasoning?
           - Opponent modeling and counter-strategies?
        
        6. **Robustness Analysis**: How robust is the learned strategy?
           - Consistent performance across opponents suggests robust learning
           - High variance suggests overfitting or instability
        
        7. **Exploitation vs Cooperation Trade-off**: How did PPO resolve the exploration-exploitation dilemma?
           - Did it learn when to be cooperative vs when to exploit?
           - How does this relate to the classical game theory solutions?
        
        8. **Learning Efficiency**: Which strategic patterns did PPO learn quickly vs slowly?
           - What does this suggest about the difficulty of different strategic concepts?
           - How well did the reward structure guide learning?
        
        {'9. **Training Trajectory**: What patterns suggest continued learning potential?' if is_training else '9. **Final Assessment**: How does this compare to human expert strategies?'}
        
        Provide comprehensive insights about PPO's learning effectiveness and the sophistication of its {'evolving' if is_training else 'final'} strategic intelligence (max 600 words).
        Integrate game theory concepts with reinforcement learning analysis to explain what the agent has discovered.
        """
        
        try:
            response = self.model.generate_content(prompt)
            return response.text
        except Exception as e:
            return f"Gemini comparison temporarily unavailable: {str(e)[:100]}..."

# ==================================
# 📌 ENHANCED PRISONER'S DILEMMA ENVIRONMENT WITH PPO METRICS
# ==================================
class PrisonersDilemmaEnv(gym.Env):
    def __init__(self, strategy, agent_id="PPO_AGENT", history_len=10):
        super(PrisonersDilemmaEnv, self).__init__()
        self.history_len = history_len
        self.agent_id = agent_id
        self.action_space = gym.spaces.Discrete(2)  # 0: Cooperate, 1: Defect
        self.observation_space = gym.spaces.Box(low=0, high=5, shape=(3 * self.history_len,), dtype=np.float32)

        self.strategy = strategy
        self.agent_history = []
        self.opponent_history = []
        self.reward_history = []
        
        # Enhanced tracking for Gemini analysis
        self.full_agent_history = []
        self.full_opponent_history = []
        self.full_reward_history = []
        self.action_probabilities = []
        
        # PPO-specific metrics tracking
        self.value_estimates = []
        self.policy_entropy = []
        self.advantages = []
        self.step_count = 0

    def step(self, action):
        opponent_action = 0 if self.strategy(self.agent_history, self.opponent_history, False) == 'C' else 1
        reward = self.get_reward(action, opponent_action)

        # Update histories
        self.agent_history.append(action)
        self.opponent_history.append(opponent_action)
        self.reward_history.append(reward)
        
        # Update full histories for analysis
        self.full_agent_history.append(action)
        self.full_opponent_history.append(opponent_action)
        self.full_reward_history.append(reward)
        self.step_count += 1

        # Maintain sliding window
        if len(self.agent_history) > self.history_len:
            self.agent_history.pop(0)
            self.opponent_history.pop(0)
            self.reward_history.pop(0)

        obs = self._get_obs()
        return obs, reward, False, {}

    def reset(self):
        self.agent_history = []
        self.opponent_history = []
        self.reward_history = []
        self.step_count = 0
        return self._get_obs()

    def _get_obs(self):
        pad = lambda x: x + [0] * (self.history_len - len(x))
        return np.array(pad(self.agent_history) + pad(self.opponent_history) + pad(self.reward_history), dtype=np.float32)

    def get_reward(self, action, opponent_action):
        # Classic Prisoner's Dilemma payoff matrix
        if action == 0 and opponent_action == 0:      # Both cooperate
            return 3
        elif action == 1 and opponent_action == 1:    # Both defect
            return 1
        elif action == 0 and opponent_action == 1:    # Agent cooperates, opponent defects
            return 0
        else:                                         # Agent defects, opponent cooperates
            return 5
    
    def add_action_probability(self, prob):
        """Store action probability for analysis"""
        self.action_probabilities.append(prob)
    
    def add_ppo_metrics(self, value_est=None, entropy=None, advantage=None):
        """Store PPO-specific metrics for analysis"""
        if value_est is not None:
            self.value_estimates.append(value_est)
        if entropy is not None:
            self.policy_entropy.append(entropy)
        if advantage is not None:
            self.advantages.append(advantage)

# ==================================
# 📌 ENHANCED GEMINI TRAINING CALLBACK WITH PPO METRICS
# ==================================
class GeminiTrainingCallback(BaseCallback):
    def __init__(self, gemini_analyzer: GeminiAnalyzer, analysis_frequency: int = 10000, verbose: int = 0):
        super(GeminiTrainingCallback, self).__init__(verbose)
        self.gemini_analyzer = gemini_analyzer
        self.analysis_frequency = analysis_frequency
        self.last_analysis_step = 0
        
    def _on_step(self) -> bool:
        # Check if it's time for analysis
        if self.num_timesteps - self.last_analysis_step >= self.analysis_frequency:
            self.last_analysis_step = self.num_timesteps
            
            # Get environment data for analysis
            try:
                # Access the first environment (assuming DummyVecEnv)
                env = self.training_env.envs[0]
                
                if hasattr(env, 'full_agent_history') and len(env.full_agent_history) > 50:
                    # Convert to symbolic moves
                    agent_moves = ['C' if a == 0 else 'D' for a in env.full_agent_history]
                    opponent_moves = ['C' if a == 0 else 'D' for a in env.full_opponent_history]
                    
                    # Get strategy name from environment
                    strategy_name = getattr(env, 'strategy_name', 'Unknown')
                    
                    # Collect PPO metrics
                    ppo_metrics = {
                        'value_estimates': getattr(env, 'value_estimates', []),
                        'policy_entropy': getattr(env, 'policy_entropy', []),
                        'advantages': getattr(env, 'advantages', []),
                        'action_probabilities': getattr(env, 'action_probabilities', [])
                    }
                    
                    print(f"\n{'='*60}")
                    print(f"🧠 GEMINI TRAINING ANALYSIS - Step {self.num_timesteps:,}")
                    print(f"{'='*60}")
                    
                    # Perform Gemini analysis with PPO metrics
                    analysis = self.gemini_analyzer.analyze_strategy_evolution(
                        agent_id=env.agent_id,
                        move_history=agent_moves,
                        opponent_history=opponent_moves,
                        probabilities=env.action_probabilities[-100:] if len(env.action_probabilities) > 100 else env.action_probabilities,
                        rewards=env.full_reward_history,
                        opponent_name=strategy_name,
                        ppo_metrics=ppo_metrics,
                        is_training=True,
                        training_step=self.num_timesteps
                    )
                    
                    print(analysis)
                    print("="*60)
                    
            except Exception as e:
                if self.verbose > 0:
                    print(f"Training analysis error: {str(e)[:100]}...")
        
        return True

# ==================================
# 📌 STRATEGIES (with proper conversion)
# ==================================
def to_symbolic(hist):
    return ['C' if a == 0 else 'D' for a in hist]

def tit_for_tat(agent_hist, opp_hist, __):
    return 'C' if not agent_hist else ('C' if agent_hist[-1] == 0 else 'D')

def tit_for_two_tats(agent_hist, opp_hist, __):
    if len(agent_hist) >= 2 and agent_hist[-2:] == [1, 1]:
        return 'D'
    return 'C'

def generous_tit_for_tat(agent_hist, opp_hist, __, cooperation_prob=0.1):
    if not agent_hist:
        return 'C'
    if agent_hist[-1] == 1:
        return 'C' if random.random() < cooperation_prob else 'D'
    return 'C'

def always_cooperate(*args): return 'C'
def always_defect(*args): return 'D'
def random_strategy(*args): return random.choice(['C', 'D'])
def friedman(agent_hist, opp_hist, __): return 'D' if 1 in agent_hist else 'C'

def joss(agent_hist, opp_hist, __):
    if agent_hist and random.random() < 0.1:
        return 'D'
    if agent_hist: 
        return 'C' if agent_hist[-1] == 0 else 'D'
    return 'C'

def grasskamp(agent_hist, opp_hist, __):
    return 'D' if len(agent_hist) >= 3 and agent_hist[-3:] == [1, 1, 1] else 'C'

def sample(agent_hist, opp_hist, __): return random.choice(['C', 'C', 'D'])
def tester(agent_hist, opp_hist, __): return 'D' if not agent_hist else 'C'
def opportunist(agent_hist, opp_hist, __): return 'D' if agent_hist and agent_hist[-1] == 0 else 'C'
def backstabber(agent_hist, opp_hist, __): return 'C' if len(agent_hist) < 5 else 'D'
def chaos_agent(*args): return random.choice(['C', 'D'])

# ==================================
# 📌 ENHANCED TRAIN PPO WITH COMPREHENSIVE METRICS
# ==================================
def train_ppo_with_gemini(gemini_api_key: str, history_len=10, total_timesteps=200000, analysis_frequency=40000):
    """Train PPO with comprehensive Gemini analysis including PPO metrics"""
    
    strategies = {
        "tit_for_tat": tit_for_tat,
        "tit_for_two_tats": tit_for_two_tats,
        "always_defect": always_defect,
        "always_cooperate": always_cooperate,
    }

    # Initialize Gemini analyzer
    analyzer = GeminiAnalyzer(gemini_api_key)
    
    print("🚀 Training PPO Agent with Enhanced Gemini Analysis...")
    print(f"Total timesteps: {total_timesteps:,}")
    print(f"Analysis frequency: every {analysis_frequency:,} steps")
    print("="*60)

    # Create environments with strategy names for better tracking
    envs = []
    for i, (name, strategy) in enumerate(strategies.items()):
        def make_env(s=strategy, n=name, aid=f"PPO_vs_{name}_training"):
            env = PrisonersDilemmaEnv(s, agent_id=aid, history_len=history_len)
            env.strategy_name = n  # Add strategy name for callback
            return env
        envs.append(make_env)
    
    vec_env = DummyVecEnv(envs)

    # Create PPO model with metrics tracking
    model = PPO("MlpPolicy", vec_env, verbose=1, ent_coef=0.01, tensorboard_log="./ppo_tensorboard/")
    
    # Create Gemini callback for training analysis
    gemini_callback = GeminiTrainingCallback(
        gemini_analyzer=analyzer,
        analysis_frequency=analysis_frequency,
        verbose=1
    )
    
    # Train with Gemini analysis
    model.learn(total_timesteps=total_timesteps, callback=gemini_callback)
    
    # Final training analysis with PPO metrics
    print("\n" + "="*80)
    print("🎯 FINAL GEMINI TRAINING ANALYSIS WITH PPO METRICS")
    print("="*80)
    
    # Collect final training data from all environments
    training_results = {}
    for i, (name, _) in enumerate(strategies.items()):
        env = vec_env.envs[i]
        if hasattr(env, 'full_agent_history') and len(env.full_agent_history) > 0:
            agent_moves = ['C' if a == 0 else 'D' for a in env.full_agent_history]
            opponent_moves = ['C' if a == 0 else 'D' for a in env.full_opponent_history]
            
            training_results[name] = {
                'total_reward': float(np.sum(env.full_reward_history)),
                'average_reward': float(np.mean(env.full_reward_history)),
                'cooperation_rate': agent_moves.count('C') / len(agent_moves),
                'opponent_cooperation_rate': opponent_moves.count('C') / len(opponent_moves),
                'total_episodes': len(env.full_agent_history),
                'agent_id': env.agent_id,
                'reward_variance': float(np.var(env.full_reward_history)),
                'probability_variance': float(np.var(env.action_probabilities)) if env.action_probabilities else 0,
                'final_confidence': float(np.mean([max(p, 1-p) for p in env.action_probabilities[-20:]])) if len(env.action_probabilities) >= 20 else 0
            }
    
    if training_results:
        final_analysis = analyzer.compare_strategies(training_results, is_training=True)
        print(final_analysis)
    
    # Save model
    model.save("ppo_enhanced_with_metrics")
    print("\n✅ Model saved as 'ppo_enhanced_with_metrics'")
    
    return model, training_results

# ==================================
# 📌 ENHANCED TEST WITH PPO METRICS EXTRACTION
# ==================================
def test_ppo_with_enhanced_analysis(gemini_api_key: str, model_path: str = None, history_len=10, 
                                  print_steps=True, analyze_every=100, num_episodes=500):
    """Test PPO with comprehensive PPO metrics analysis"""
    
    strategies = {
        "tit_for_tat": tit_for_tat,
      
        "tit_for_two_tats": tit_for_two_tats,
        "always_defect": always_defect,
        "always_cooperate": always_cooperate,
    }

    # Initialize Gemini analyzer
    analyzer = GeminiAnalyzer(gemini_api_key)
    
    # Load model
    if model_path:
        print(f"\n🔹 Loading PPO Model from: {model_path}")
        model = PPO.load(model_path)
    else:
        print("\n🔹 Loading Default PPO Model")
        try:
            model = PPO.load("ppo_enhanced_with_metrics")
        except:
            try:
                model = PPO.load("ppo_all_strategies_full_history_with_gemini")
            except:
                model = PPO.load("ppo_all_strategies_full_history")
    
    results = {}
    detailed_results = {}

    for name, strategy in strategies.items():
        print(f"\n{'='*60}")
        print(f"🧪 TESTING PPO AGAINST: {name.upper()}")
        print(f"{'='*60}")
        
        agent_id = f"PPO_vs_{name}_test"
        env = DummyVecEnv([lambda s=strategy, aid=agent_id: PrisonersDilemmaEnv(s, agent_id=aid, history_len=history_len)])
        obs = env.reset()
        total_reward = 0
        
        # Detailed logging header
        if print_steps:
            print(f"\n📋 DETAILED STEP-BY-STEP LOG:")
            print(f"{'Step':<4} | {'Agent':<5} | {'Opponent':<8} | {'Reward':<6} | {'Cumulative':<10} | {'P(Coop)':<8} | {'Notes'}")
            print("-" * 80)

        for i in range(num_episodes):
            # Get action and probabilities more robustly
            action, _ = model.predict(obs, deterministic=False)
            
            # Get action probabilities with proper device handling
            try:
                # Ensure tensor is on the same device as the model
                device = next(model.policy.parameters()).device
                obs_tensor = torch.FloatTensor(obs).to(device)
                
                with torch.no_grad():
                    # Extract features and get logits
                    features = model.policy.extract_features(obs_tensor)
                    latent_pi = model.policy.mlp_extractor.forward_actor(features)
                    logits = model.policy.action_net(latent_pi)
                    action_probs = torch.softmax(logits, dim=-1)
                    prob_cooperate = float(action_probs[0][0].cpu())
            except Exception as e:
                # Fallback: use a simple heuristic based on recent actions
                prob_cooperate = 0.5  # Default probability
                if i == 0:  # Only print warning once
                    print(f"Warning: Using default probability due to: {str(e)[:50]}...")
            
            # Take step
            obs, reward, done, _ = env.step(action)
            action_val = int(action[0])
            
            # Store probability
            env.envs[0].add_action_probability(prob_cooperate)
            
            opponent_action = env.envs[0].opponent_history[-1]
            total_reward += reward[0]
            
            # Detailed step logging
            if print_steps:
                # Determine notes for interesting patterns
                notes = ""
                if i > 0:
                    prev_opp = env.envs[0].full_opponent_history[-2] if len(env.envs[0].full_opponent_history) >= 2 else None
                    if prev_opp is not None:
                        if action_val == prev_opp:
                            notes += "TFT? "
                        if action_val == 0 and opponent_action == 1:
                            notes += "EXPLOITED "
                        elif action_val == 1 and opponent_action == 0:
                            notes += "EXPLOITING "
                
                print(f"{i+1:>3d} | {'C' if action_val==0 else 'D':>5} | {'C' if opponent_action==0 else 'D':>8} | "
                      f"{reward[0]:>6.1f} | {total_reward:>10.1f} | {prob_cooperate:>8.3f} | {notes}")
            
            # Periodic Gemini analysis
            if (i + 1) % analyze_every == 0:
                print(f"\n{'🤖 GEMINI ANALYSIS':<20} (Step {i+1})")
                print("-" * 60)
                
                agent_moves = ['C' if a == 0 else 'D' for a in env.envs[0].full_agent_history]
                opponent_moves = ['C' if a == 0 else 'D' for a in env.envs[0].full_opponent_history]
                
                analysis = analyzer.analyze_strategy_evolution(
                    agent_id=agent_id,
                    move_history=agent_moves,
                    opponent_history=opponent_moves,
                    probabilities=env.envs[0].action_probabilities,
                    rewards=env.envs[0].full_reward_history,
                    opponent_name=name,
                    is_training=False
                )
                print(analysis)
                print("-" * 60)
                
                if print_steps:
                    print(f"\n📋 CONTINUING STEP LOG:")
                    print(f"{'Step':<4} | {'Agent':<5} | {'Opponent':<8} | {'Reward':<6} | {'Cumulative':<10} | {'P(Coop)':<8} | {'Notes'}")
                    print("-" * 80)

        # Store detailed results
        agent_moves = ['C' if a == 0 else 'D' for a in env.envs[0].full_agent_history]
        opponent_moves = ['C' if a == 0 else 'D' for a in env.envs[0].full_opponent_history]
        
        detailed_results[name] = {
            'total_reward': float(total_reward),
            'average_reward': float(total_reward / num_episodes),
            'cooperation_rate': agent_moves.count('C') / len(agent_moves),
            'opponent_cooperation_rate': opponent_moves.count('C') / len(opponent_moves),
            'avg_reward': float(np.mean(env.envs[0].full_reward_history)),
            'final_probabilities': env.envs[0].action_probabilities[-10:] if len(env.envs[0].action_probabilities) >= 10 else env.envs[0].action_probabilities,
            'agent_id': agent_id,
            'total_episodes': num_episodes
        }
        
        results[name] = total_reward
        
        # Summary for this opponent
        print(f"\n📊 MATCH SUMMARY:")
        print(f"Agent: {agent_id}")
        print(f"Total Reward: {total_reward:.1f}")
        print(f"Average Reward per Episode: {total_reward/num_episodes:.2f}")
        print(f"Agent Cooperation Rate: {detailed_results[name]['cooperation_rate']:.1%}")
        print(f"Opponent Cooperation Rate: {detailed_results[name]['opponent_cooperation_rate']:.1%}")

        # Final comprehensive analysis
        print("\n" + "="*80)
        print("🧠 COMPREHENSIVE GEMINI STRATEGY ANALYSIS")
        print("="*80)
        
        final_analysis = analyzer.compare_strategies(detailed_results)
        print(final_analysis)
        
        print("\n" + "="*80)
        print("📊 FINAL PPO PERFORMANCE SUMMARY")
        print("="*80)
        for strategy, score in results.items():
            details = detailed_results[strategy]
            print(f"{strategy:>20}: {score:>6.1f} pts | Avg: {details['average_reward']:>5.2f} | "
                  f"Coop: {details['cooperation_rate']:>5.1%} | "
                  f"vs {details['opponent_cooperation_rate']:>5.1%} opp")
        
        return results, detailed_results

# ==================================
# 📌 MAIN EXECUTION WITH GEMINI
# ==================================
def main():
    # You need to set your Gemini API key here
    GEMINI_API_KEY = "AIzaSyALn5gEk1DeBNoIFRBdk52K3d_S5JKyC3M"  # Replace with your actual API key
    
    if not GEMINI_API_KEY or GEMINI_API_KEY == "":
        print("⚠️  Please set your Gemini API key in the GEMINI_API_KEY variable")
        print("You can get one from: https://makersuite.google.com/app/apikey")
        return
    
    print("🚀 Training PPO Agent with Gemini Analysis...")
    train_ppo_with_gemini(GEMINI_API_KEY, total_timesteps=200000)
    
    print("\n🧪 Testing PPO with Enhanced Analysis...")
    results, detailed_results = test_ppo_with_enhanced_analysis(
        gemini_api_key=GEMINI_API_KEY,
        print_steps=True,       # Enable detailed step-by-step logging
        analyze_every=100,      # Analyze every 100 steps
        num_episodes=500        # Number of episodes per opponent
    )

# ==================================
# 🚀 RUN TRAINING & TESTING
# ==================================
if __name__ == "__main__":
    main()
# Out:
# 🚀 Training PPO Agent with Gemini Analysis...
# 🚀 Training PPO Agent with Enhanced Gemini Analysis...
# Total timesteps: 200,000
# Analysis frequency: every 40,000 steps
# ============================================================
# Using cpu device
# Logging to ./ppo_tensorboard/PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 4581 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 8192 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1870       |
# |    iterations           | 2          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00584854 |
# |    clip_fraction        | 0.014      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.688     |
# |    explained_variance   | 0.0015     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 179        |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.00209   |
# |    value_loss           | 994        |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1568         |
# |    iterations           | 3            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0060851406 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.683       |
# |    explained_variance   | 0.513        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 241          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00258     |
# |    value_loss           | 1.08e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1426        |
# |    iterations           | 4           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008095121 |
# |    clip_fraction        | 0.0484      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.673      |
# |    explained_variance   | 0.702       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 176         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00508    |
# |    value_loss           | 920         |
# -----------------------------------------
#
# ============================================================
# 🧠 GEMINI TRAINING ANALYSIS - Step 40,000
# ============================================================
# /usr/local/lib/python3.11/dist-packages/numpy/core/fromnumeric.py:3787: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.11/dist-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /usr/local/lib/python3.11/dist-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.11/dist-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.11/dist-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Here's an analysis of the PPO agent's learning trajectory in the Prisoner's Dilemma, integrating behavioral and RL metrics:
#
# **1. Policy Learning Assessment:**
#
# *   The `Decision Confidence Trend` is `Low`, which means the agent's policy network outputs varying probabilities for cooperation and defection. The `Probability Variance` is `nan`, so we can't use it to assess the deterministic behavior.
#
# **2. Value Function Understanding:**
#
# *   `Value Function Trend` is N/A. Without value function data, we cannot assess the agent's ability to accurately predict future rewards or how value estimation correlates with performance.
#
# **3. Exploration vs Exploitation Balance:**
#
# *   The `Low Decision Confidence Trend` suggests the agent is still exploring and refining its strategy and haven't yet converged to an optimal policy. Policy entropy is N/A.
#
# **4. Advantage Learning:**
#
# *   `Advantage Estimates` is N/A, we cannot determine how stable the advantages are or how they correlate with the opponent responses.
#
# **6. Policy Gradient Insights:**
#
# *   The `Low Decision Confidence Trend` suggests the policy hasn't fully converged. The agent is still exploring different actions, implying the policy is undergoing continued updates, but it is still unsure on when to make each decision.
#
# **7. Opponent Modeling:**
#
# *   The agent is playing against `tit_for_tat` strategy. `tit_for_tat` strategy cooperates on the first move and then mirrors the opponent's previous move. The agent's `Cooperate after Opponent Cooperates` is 58.1% and `Cooperate after Opponent Defects` is 54.9%, this suggests that the agent is attempting to mimic the `tit_for_tat` strategy but doing a bad job at it because it is not stable or predictable and doesn't cooperate enough after opponent cooperates, neither defects enough after the opponent defects.
#
# **8. Risk and Uncertainty:**
#
# *   Given the fluctuating probabilities and non-converged policy, the agent is handling uncertainty with a mixed approach. It is neither fully defaulting to cooperation nor defection. The low Probability Variance and unstable Reward Variance suggest an inconsistent approach to the dilemma.
#
# **9. Training Dynamics:**
#
# *   The declining `Reward Trend` coupled with fluctuating probabilities suggests that the agent may be stuck in a local optimum. It hasn't yet found a stable and rewarding strategy against `tit_for_tat`.
#
# ============================================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1227        |
# |    iterations           | 5           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008476782 |
# |    clip_fraction        | 0.0876      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.816       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 175         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00653    |
# |    value_loss           | 766         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1224        |
# |    iterations           | 6           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.005617625 |
# |    clip_fraction        | 0.0294      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.654      |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 124         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00275    |
# |    value_loss           | 595         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1221        |
# |    iterations           | 7           |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.006852452 |
# |    clip_fraction        | 0.0533      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.64       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.2        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00329    |
# |    value_loss           | 462         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1218         |
# |    iterations           | 8            |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0062885154 |
# |    clip_fraction        | 0.0639       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.615       |
# |    explained_variance   | 0.953        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 46           |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00425     |
# |    value_loss           | 341          |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1215       |
# |    iterations           | 9          |
# |    time_elapsed         | 60         |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.01602827 |
# |    clip_fraction        | 0.0937     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.573     |
# |    explained_variance   | 0.958      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 81.9       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00519   |
# |    value_loss           | 336        |
# ----------------------------------------
#
# ============================================================
# 🧠 GEMINI TRAINING ANALYSIS - Step 80,000
# ============================================================
# Here's a comprehensive analysis of the PPO agent's strategy in the Prisoner's Dilemma, integrating behavioral and RL metrics:
#
# 1.  **Policy Learning Assessment**: The `Decision Confidence Trend` is `Low`, suggesting the policy network hasn't converged to a highly deterministic mapping.  The `Probability Variance` is `nan`, so it cannot be directly used to determine the state of the policy, thus we must depend on the confidence trend. Without seeing the values of the decision probabilities, the policy is likely making probabilistic choices between cooperation and defection based on its observation of the opponent and the environment.
#
# 2.  **Value Function Understanding**: `Value Function Trend: N/A` indicates that the value function is not available, or not being tracked. Without this, it's impossible to assess how well the agent predicts future rewards or evaluate states.
#
# 3.  **Exploration vs Exploitation Balance**: The `Decision Confidence Trend` being low suggests the agent is still exploring, rather than fully exploiting a learned strategy. `Policy Entropy: N/A`, which should ideally indicate degree of exploration.
#
# 4.  **Advantage Learning**: `Advantage Estimates: N/A`. Without advantage estimates, we can't determine the agent's assessment of its actions relative to the expected value, which is key to understanding the policy gradient's direction.
#
# 5.  **Policy Gradient Insights**: Given the `Decision Confidence Trend` is `Low`, and the decision probabilities being unavailable, the policy probably is still in training and not yet converged to a stable strategy. The agent continues to update its policy, rather than sticking to a single mode of play.
#
# 6.  **Opponent Modeling**: The opponent is `tit_for_tat`. The agent's `Cooperate after Opponent Cooperates: 67.0%` is higher than `Cooperate after Opponent Defects: 59.7%` which indicates that the agent has some level of understanding of the opponent's strategy.
#
# 7.  **Risk and Uncertainty**: The agent's cooperation rate of `64.4%` indicates a relatively cautious or cooperative default. While the agent is willing to cooperate, it's not doing so unconditionally. The higher `Reward Variance: 2.560` could be linked to the uncertainty in opponent behavior, particularly after a defection.
#
# 8.  **Training Dynamics**: The `Reward Trend: Declining` and the `Reward Variance: 2.560` suggest that the learning process is unstable. Given the high cooperation rates, agent has not converged to a single strategy.
#
# ============================================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1138        |
# |    iterations           | 10          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.004762253 |
# |    clip_fraction        | 0.0277      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.516      |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 74.9        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00244    |
# |    value_loss           | 345         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1143         |
# |    iterations           | 11           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0044187238 |
# |    clip_fraction        | 0.0443       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.491       |
# |    explained_variance   | 0.967        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.2         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00387     |
# |    value_loss           | 277          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1139         |
# |    iterations           | 12           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0049776807 |
# |    clip_fraction        | 0.033        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.482       |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.8         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00351     |
# |    value_loss           | 221          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1143        |
# |    iterations           | 13          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.006468555 |
# |    clip_fraction        | 0.0456      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.451      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.6        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00485    |
# |    value_loss           | 187         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1144         |
# |    iterations           | 14           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0053482107 |
# |    clip_fraction        | 0.0574       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.438       |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.3         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00278     |
# |    value_loss           | 147          |
# ------------------------------------------
#
# ============================================================
# 🧠 GEMINI TRAINING ANALYSIS - Step 120,000
# ============================================================
# Here's an analysis of the PPO agent's learning trajectory in the Prisoner's Dilemma, integrating behavioral and RL metrics:
#
# *   **1. Policy Learning Assessment:** Decision Probabilities are not available, and the probability variance is `nan`, we cannot infer specific patterns in decision-making. The "Decision Confidence Trend: Low" suggests that the policy hasn't fully converged.
#
# *   **2. Value Function Understanding:** Value Function Trend is N/A. Therefore, we cannot determine if the agent is effectively predicting future rewards or if its value estimations align with its performance.
#
# *   **3. Exploration vs Exploitation Balance:** Given the `nan` probability variance, it's hard to determine exploration.
#
# *   **4. Advantage Learning:** Advantage Estimates are N/A.
#
# *   **6. Policy Gradient Insights:** The lack of specific policy network metrics and PPO learning metrics makes it difficult to definitively assess policy convergence or ongoing updates. The `nan` probability variance and low decision confidence could indicate the policy hasn't fully stabilized, and further training might lead to refinement.
#
# *   **7. Opponent Modeling:** The agent is playing against "tit_for_tat". The agent's cooperation rate of 68.0% matches the opponent's, suggesting it's learned to mostly cooperate. The "Tit-for-Tat Adherence" is 59.5%, which is around the cooperation rate, but "Cooperate after Opponent Defects: 63.4%" is very high which is similar to mirroring.
#
# *   **8. Risk and Uncertainty:** The agent's high cooperation rate (68.0%) suggests a cautious default. High reward variance (4.060) could be related to uncertainty in predicting the opponent's response.
#
# *   **9. Training Dynamics:** With training step is 120,000 and improvement in reward trend suggests that PPO is doing well in learning to cooperate with the opponent.
#
# In conclusion, the PPO agent appears to have learned a predominantly cooperative strategy against Tit-for-Tat, but the RL metrics indicate that it hasn't fully converged. The agent mostly mimics the opponent as evident by "Cooperate after Opponent Defects: 63.4%", as well as, the agent's and opponent's similar cooperation rate (68%).
#
# ============================================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1113        |
# |    iterations           | 15          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.005909575 |
# |    clip_fraction        | 0.0571      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.429      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15          |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0041     |
# |    value_loss           | 106         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1114        |
# |    iterations           | 16          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.005737384 |
# |    clip_fraction        | 0.0545      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.409      |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.09        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00466    |
# |    value_loss           | 73.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1118         |
# |    iterations           | 17           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 139264       |
# | train/                  |              |
# |    approx_kl            | 0.0043652346 |
# |    clip_fraction        | 0.0471       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.39        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.61         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00278     |
# |    value_loss           | 48.9         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1121       |
# |    iterations           | 18         |
# |    time_elapsed         | 131        |
# |    total_timesteps      | 147456     |
# | train/                  |            |
# |    approx_kl            | 0.00640806 |
# |    clip_fraction        | 0.0531     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.366     |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.47       |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.00404   |
# |    value_loss           | 30.9       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1125         |
# |    iterations           | 19           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 155648       |
# | train/                  |              |
# |    approx_kl            | 0.0065305484 |
# |    clip_fraction        | 0.0488       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.322       |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.61         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00351     |
# |    value_loss           | 19.9         |
# ------------------------------------------
#
# ============================================================
# 🧠 GEMINI TRAINING ANALYSIS - Step 160,000
# ============================================================
# Here's an analysis of the PPO agent's learning process in the Prisoner's Dilemma, integrating behavioral and RL metrics:
#
# *   **Policy Learning Assessment:** Decision Probabilities are missing, but the "Decision Confidence Trend: Low" suggests the policy network hasn't converged to a deterministic strategy yet. It still contains some randomness.
#
# *   **Value Function Understanding:** Value Function Trend is N/A, so we can't determine how well the agent predicts future rewards or if its value estimation correlates with actual performance.
#
# *   **Exploration vs Exploitation Balance:** The lack of information about probability variance and Policy Entropy makes it difficult to assess the exploration/exploitation balance. The low decision confidence, however, hints at continued exploration.
#
# *   **Advantage Learning:** Advantage Estimates are N/A, which prevents us from determining how useful they are for better action selection.
#
# *   **Policy Gradient Insights:** The missing Decision Probabilities make it impossible to see pattern and the missing Policy Entropy makes it difficult to determine whether the policy is converging to a stable strategy.
#
# *   **Opponent Modeling:** The agent is playing against "tit_for_tat". The Agent Cooperation Rate (70.5%) is similar to the Opponent Cooperation Rate (70.5%). The Agent "Cooperate after Opponent Cooperates" (72.7%) is close to that of "tit_for_tat", but high percentage of the Agent's "Cooperate after Opponent Defects" (65.4%), indicates that the agent is learning to "forgive" more frequently than a pure tit-for-tat strategy. The move sequence "C D C D C D C C D C D C D C C C C C C C C C D C C C C D C D" shows there's no immediate mirror of the opponent behavior, the agent doesn't always reciprocate.
#
# *   **Risk and Uncertainty:** The cooperation rate of 70.5% indicates a cautiously cooperative default. The Reward Variance (2.790) combined with the Low decision confidence further suggest the agent is handling some uncertainty.
#
# *   **Training Dynamics:** The "Reward Trend: Improving" suggests that even with exploration, the agent is gradually finding more successful strategies. The recent reward pattern (several "3.0" followed by "5.0", "0.0", and then repeated) aligns with the agent successfully cooperating or defecting when the opponent cooperates, and then experiencing the consequence (either joint reward or exploitation/punishment). The "Training Step: 160,000" indicates that the agent has been training for a while, the high number of steps suggests that PPO may have converged to a suboptimal policy due to the stochastic nature of the Prisoner's Dilemma and the exploration inherent in RL. The agent seems stuck at a 70% cooperation rate, which is less than optimal and is a sign that agent may not fully exploit the tit-for-tat strategy which would be a near 100% collaboration and high rewards.
#
# ============================================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1095        |
# |    iterations           | 20          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.006291282 |
# |    clip_fraction        | 0.0445      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.277      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.767       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0047     |
# |    value_loss           | 11.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1098         |
# |    iterations           | 21           |
# |    time_elapsed         | 156          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0051525156 |
# |    clip_fraction        | 0.0473       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.242       |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.48         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00356     |
# |    value_loss           | 5.74         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1101         |
# |    iterations           | 22           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0034825266 |
# |    clip_fraction        | 0.0378       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.221       |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.01         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00395     |
# |    value_loss           | 4.41         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1103         |
# |    iterations           | 23           |
# |    time_elapsed         | 170          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0038562496 |
# |    clip_fraction        | 0.0406       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.21        |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.574        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00477     |
# |    value_loss           | 2.73         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1106         |
# |    iterations           | 24           |
# |    time_elapsed         | 177          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0027517006 |
# |    clip_fraction        | 0.0383       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.189       |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.454        |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0049      |
# |    value_loss           | 1.97         |
# ------------------------------------------
#
# ============================================================
# 🧠 GEMINI TRAINING ANALYSIS - Step 200,000
# ============================================================
# Here's an analysis of the PPO agent's learning and strategic behavior in the Prisoner's Dilemma, considering both behavioral and RL metrics:
#
# *   **Policy Learning Assessment**: The lack of decision probabilities and the 'nan' probability variance makes it difficult to directly assess how the policy is mapping states to actions. A low decision confidence trend suggests the agent is not very sure of its actions. However, the combination of behavioral metrics and the reward structure allows us to infer some understanding.
#
# *   **Value Function Understanding**: The 'N/A' value function trend means we cannot determine if the agent is learning to accurately predict future rewards.
#
# *   **Exploration vs Exploitation Balance**: Again, the 'nan' probability variance, exploration analysis, and policy entropy leaves the current understanding to be incomplete.
#
# *   **Advantage Learning**: With advantage estimates as 'N/A', it's not possible to determine whether the advantage estimates indicate a stable strategy.
#
# *   **Policy Gradient Insights**: Due to missing probability patterns, it is not possible to determine whether the policy is converging or it has plateued.
#
# *   **Opponent Modeling**: The agent is playing against 'tit_for_tat'. Agent's Cooperation rate matches the opponent's, which suggests the agent has learned to reciprocate. The 'Cooperate after Opponent Cooperates' is 74.2% and 'Cooperate after Opponent Defects' is 65.8% suggests that the agent tends to punish the tit_for_tat, but sometimes forgives defecting actions by continuing to cooperate. Tit-for-Tat adherence 62.9% isn't super high, which also indicates this occasional forgiveness.
#
# *   **Risk and Uncertainty**: The agent seems to be trying to balance risk (defection) and reward (cooperation). The Cooperation Rate is 71.8% indicates a generally cooperative default. A variance in reward(3.540) indicates some volatility.
#
# *   **Training Dynamics**: The declining reward trend (Average Recent Reward: 2.60) suggests that the agent isn't getting better as training progresses or is starting to converge on a sub-optimal strategy. Given that the agent cooperates after the opponent cooperates 74.2% of the time and the fact that the cooperation rate matches the opponent rate, the agent is not really learning to maximize rewards; rather, it's trying to copy/play-along with the opponent which it is not the optimal solution given that defecting results in more reward.
#
# **Conclusion:**
#
# Based on all of these points, it seems that the agent has picked up some traits of the strategy of 'tit_for_tat', but the internal RL metrics are not really getting better as time progresses. The lack of information about policy entropy, advantage estimation, and value function learning makes it harder to assess the learning trajectory. The agent has not really learned the optimal strategy, but it's converging to play along with its opponent.
#
# ============================================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1085         |
# |    iterations           | 25           |
# |    time_elapsed         | 188          |
# |    total_timesteps      | 204800       |
# | train/                  |              |
# |    approx_kl            | 0.0024128521 |
# |    clip_fraction        | 0.0358       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.177       |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.38         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00219     |
# |    value_loss           | 9.32         |
# ------------------------------------------
#
# ================================================================================
# 🎯 FINAL GEMINI TRAINING ANALYSIS WITH PPO METRICS
# ================================================================================
# Here's an analysis of the PPO agent's learning in the Prisoner's Dilemma, based on the provided performance summary, addressing the posed questions and integrating game theory concepts:
#
# **Overall Assessment:** PPO demonstrates a capacity for strategic adaptation, but it doesn't achieve a universally robust or deeply sophisticated policy. It excels at exploiting naive strategies (always cooperate), learns to cooperate conditionally against tit-for-tat strategies, and defensively defects against constant defectors. However, it shows signs of overfitting and limited capacity for complex multi-step reasoning.
#
# **1. Policy Generalization:** PPO doesn't learn a highly generalizable strategy. Its highest reward is achieved when the opponent always cooperates. In this environment, PPO learns to almost always defect (low cooperation rate), exploiting the opponent's naivety for maximum gain. Conversely, it's least successful against "always defect," where it learns to defect most of the time as well, settling for minimal losses. PPO shows an opponent-specific adaptation to "Tit-for-Tat" by moderately cooperating, suggesting it has learned to reciprocate cooperation for mutual benefit. This indicates learning, but not necessarily generalization. Instead it seems to adopt strategies tailored to specific opponents.
#
# **2. Multi-Task Learning:** The training seems to have produced some degree of robustness, as evidenced by PPO's ability to play reasonably well against different opponents. However, the widely varying performance scores suggest that PPO does not necessarily learn a general strategy; each specific model performs well against it's single opponent.
#
# **3. Value Function Accuracy:** We can infer value function accuracy based on the performance. The agent likely estimates the value of defecting against 'always cooperate' accurately, explaining its high reward. Conversely, against 'always defect', its value function might underestimate the negative consequences of cooperation (even briefly), leading to occasional cooperation and thus suboptimal performance. Tit-for-tat, it appears to reasonably estimate the value of cooperation, even though the policy of the tit-for-tat agent does not change.
#
# **4. Policy Gradient Effectiveness:** The significant variation in cooperation rates demonstrates the effectiveness of policy gradients in learning different action probabilities for different contexts. PPO successfully learns to cooperate more against tit-for-tat (balancing exploitation with sustained mutual reward) and to defect more against opponents who always defect. This demonstrates the algorithm's ability to fine-tune action probabilities based on environmental feedback.
#
# **5. Strategic Sophistication:** PPO exhibits relatively low strategic sophistication. It learns basic reactive strategies, particularly "tit-for-tat" in its own way by generally defecting until the opponent defects. There's limited evidence of complex multi-step reasoning or opponent modeling. It does not try to deviate from tit-for-tat to possibly defect or cooperate at random intervals. This suggests a lack of high-order strategic thinking.
#
# **6. Robustness Analysis:** PPO shows some robustness, but is not universally robust, as it does have an upper hand with "always cooperate", a middle hand with "tit-for-tat", and a severe lower hand with "always defect". Consistent performance only exists when comparing the same agent against the same opponent. This suggests limited generalizability of the learned policy.
#
# **7. Exploitation vs Cooperation Trade-off:** PPO shows a clear tendency towards exploitation when possible. When facing 'always cooperate', it almost entirely exploits. Against 'tit-for-tat' and 'tit-for-two-tats', it learns that some level of cooperation is beneficial for sustained reward. This aligns with game theory principles, where defecting is the dominant strategy in a single-shot Prisoner's Dilemma, but cooperation can emerge in repeated games under certain conditions.
#
# **8. Learning Efficiency:** PPO likely learned to exploit the 'always cooperate' opponent quickly. Learning a conditional cooperation strategy (tit-for-tat) likely took longer, as it requires the agent to learn to recognize patterns and adjust its behavior accordingly. The difficulty of learning different strategic concepts is reflected in the different reward levels.
#
# **9. Training Trajectory:** To further assess PPO's continued learning potential, we would need to examine the learning curves. If the reward stabilizes early on, it suggests limited further learning. Oscillating reward curves might indicate ongoing exploration. A steadily increasing reward curve would suggest continued learning potential.
#
# **Integration of Game Theory Concepts:**
#
# *   **Dominant Strategy:** PPO struggles to break the dominant strategy of defection when facing 'always defect'.
# *   **Iterated Prisoner's Dilemma:** PPO learns elements of strategies relevant in the iterated Prisoner's Dilemma, particularly reciprocity (tit-for-tat) and identifying exploitable opponents.
# *   **Nash Equilibrium:** PPO's behavior against 'always defect' tends towards the Nash Equilibrium of mutual defection.
#
# In conclusion, PPO demonstrates a capacity for strategic learning in the Prisoner's Dilemma, but it is primarily reactive and exploitative. It struggles with complex reasoning and generalizing across different opponent behaviors. The performance differences reflect the effectiveness of policy gradients in adjusting action probabilities based on specific environmental feedback and the relative ease of learning to exploit naive strategies. Further training with more diverse opponents and exploration of more sophisticated reward structures might be necessary to foster a more robust and deeply strategic agent.
#
#
# ✅ Model saved as 'ppo_enhanced_with_metrics'
#
# 🧪 Testing PPO with Enhanced Analysis...
#
# 🔹 Loading Default PPO Model
#
# ============================================================
# 🧪 TESTING PPO AGAINST: TIT_FOR_TAT
# ============================================================
#
# 📋 DETAILED STEP-BY-STEP LOG:
# Step | Agent | Opponent | Reward | Cumulative | P(Coop)  | Notes
# --------------------------------------------------------------------------------
#   1 |     C |        C |    3.0 |        3.0 |    0.601 |
#   2 |     C |        C |    3.0 |        6.0 |    0.816 | TFT?
#   3 |     C |        C |    3.0 |        9.0 |    0.696 | TFT?
#   4 |     D |        C |    5.0 |       14.0 |    0.446 | EXPLOITING
#   5 |     C |        D |    0.0 |       14.0 |    0.258 | TFT? EXPLOITED
#   6 |     D |        C |    5.0 |       19.0 |    0.154 | TFT? EXPLOITING
#   7 |     D |        D |    1.0 |       20.0 |    0.057 |
#   8 |     D |        D |    1.0 |       21.0 |    0.011 | TFT?
#   9 |     D |        D |    1.0 |       22.0 |    0.015 | TFT?
#  10 |     D |        D |    1.0 |       23.0 |    0.020 | TFT?
#  11 |     C |        D |    0.0 |       23.0 |    0.862 | EXPLOITED
#  12 |     C |        C |    3.0 |       26.0 |    0.680 |
#  13 |     D |        C |    5.0 |       31.0 |    0.056 | EXPLOITING
#  14 |     C |        D |    0.0 |       31.0 |    0.889 | TFT? EXPLOITED
#  15 |     C |        C |    3.0 |       34.0 |    0.236 |
#  16 |     D |        C |    5.0 |       39.0 |    0.036 | EXPLOITING
#  17 |     D |        D |    1.0 |       40.0 |    0.565 |
#  18 |     D |        D |    1.0 |       41.0 |    0.585 | TFT?
#  19 |     C |        D |    0.0 |       41.0 |    0.867 | EXPLOITED
#  20 |     D |        C |    5.0 |       46.0 |    0.277 | TFT? EXPLOITING
#  21 |     C |        D |    0.0 |       46.0 |    0.744 | TFT? EXPLOITED
#  22 |     C |        C |    3.0 |       49.0 |    0.757 |
#  23 |     C |        C |    3.0 |       52.0 |    0.455 | TFT?
#  24 |     C |        C |    3.0 |       55.0 |    0.416 | TFT?
#  25 |     C |        C |    3.0 |       58.0 |    0.695 | TFT?
#  26 |     D |        C |    5.0 |       63.0 |    0.264 | EXPLOITING
#  27 |     C |        D |    0.0 |       63.0 |    0.972 | TFT? EXPLOITED
#  28 |     D |        C |    5.0 |       68.0 |    0.671 | TFT? EXPLOITING
#  29 |     C |        D |    0.0 |       68.0 |    0.982 | TFT? EXPLOITED
#  30 |     D |        C |    5.0 |       73.0 |    0.574 | TFT? EXPLOITING
#  31 |     C |        D |    0.0 |       73.0 |    0.990 | TFT? EXPLOITED
#  32 |     C |        C |    3.0 |       76.0 |    0.896 |
#  33 |     C |        C |    3.0 |       79.0 |    0.630 | TFT?
#  34 |     C |        C |    3.0 |       82.0 |    0.787 | TFT?
#  35 |     D |        C |    5.0 |       87.0 |    0.526 | EXPLOITING
#  36 |     C |        D |    0.0 |       87.0 |    0.936 | TFT? EXPLOITED
#  37 |     D |        C |    5.0 |       92.0 |    0.630 | TFT? EXPLOITING
#  38 |     C |        D |    0.0 |       92.0 |    0.954 | TFT? EXPLOITED
#  39 |     C |        C |    3.0 |       95.0 |    0.889 |
#  40 |     C |        C |    3.0 |       98.0 |    0.717 | TFT?
#  41 |     D |        C |    5.0 |      103.0 |    0.692 | EXPLOITING
#  42 |     C |        D |    0.0 |      103.0 |    0.992 | TFT? EXPLOITED
#  43 |     C |        C |    3.0 |      106.0 |    0.862 |
#  44 |     C |        C |    3.0 |      109.0 |    0.851 | TFT?
#  45 |     C |        C |    3.0 |      112.0 |    0.690 | TFT?
#  46 |     C |        C |    3.0 |      115.0 |    0.708 | TFT?
#  47 |     C |        C |    3.0 |      118.0 |    0.628 | TFT?
#  48 |     C |        C |    3.0 |      121.0 |    0.522 | TFT?
#  49 |     C |        C |    3.0 |      124.0 |    0.785 | TFT?
#  50 |     C |        C |    3.0 |      127.0 |    0.682 | TFT?
#  51 |     C |        C |    3.0 |      130.0 |    0.625 | TFT?
#  52 |     D |        C |    5.0 |      135.0 |    0.557 | EXPLOITING
#  53 |     C |        D |    0.0 |      135.0 |    0.998 | TFT? EXPLOITED
#  54 |     C |        C |    3.0 |      138.0 |    0.848 |
#  55 |     C |        C |    3.0 |      141.0 |    0.780 | TFT?
#  56 |     D |        C |    5.0 |      146.0 |    0.739 | EXPLOITING
#  57 |     C |        D |    0.0 |      146.0 |    0.997 | TFT? EXPLOITED
#  58 |     C |        C |    3.0 |      149.0 |    0.856 |
#  59 |     C |        C |    3.0 |      152.0 |    0.612 | TFT?
#  60 |     C |        C |    3.0 |      155.0 |    0.726 | TFT?
#  61 |     C |        C |    3.0 |      158.0 |    0.834 | TFT?
#  62 |     D |        C |    5.0 |      163.0 |    0.628 | EXPLOITING
#  63 |     C |        D |    0.0 |      163.0 |    0.994 | TFT? EXPLOITED
#  64 |     C |        C |    3.0 |      166.0 |    0.829 |
#  65 |     C |        C |    3.0 |      169.0 |    0.734 | TFT?
#  66 |     D |        C |    5.0 |      174.0 |    0.672 | EXPLOITING
#  67 |     C |        D |    0.0 |      174.0 |    0.995 | TFT? EXPLOITED
#  68 |     C |        C |    3.0 |      177.0 |    0.856 |
#  69 |     D |        C |    5.0 |      182.0 |    0.612 | EXPLOITING
#  70 |     C |        D |    0.0 |      182.0 |    0.985 | TFT? EXPLOITED
#  71 |     D |        C |    5.0 |      187.0 |    0.633 | TFT? EXPLOITING
#  72 |     C |        D |    0.0 |      187.0 |    0.972 | TFT? EXPLOITED
#  73 |     C |        C |    3.0 |      190.0 |    0.421 |
#  74 |     C |        C |    3.0 |      193.0 |    0.784 | TFT?
#  75 |     C |        C |    3.0 |      196.0 |    0.848 | TFT?
#  76 |     C |        C |    3.0 |      199.0 |    0.828 | TFT?
#  77 |     C |        C |    3.0 |      202.0 |    0.805 | TFT?
#  78 |     C |        C |    3.0 |      205.0 |    0.801 | TFT?
#  79 |     C |        C |    3.0 |      208.0 |    0.702 | TFT?
#  80 |     C |        C |    3.0 |      211.0 |    0.707 | TFT?
#  81 |     C |        C |    3.0 |      214.0 |    0.625 | TFT?
#  82 |     D |        C |    5.0 |      219.0 |    0.557 | EXPLOITING
#  83 |     C |        D |    0.0 |      219.0 |    0.998 | TFT? EXPLOITED
#  84 |     C |        C |    3.0 |      222.0 |    0.848 |
#  85 |     C |        C |    3.0 |      225.0 |    0.780 | TFT?
#  86 |     C |        C |    3.0 |      228.0 |    0.739 | TFT?
#  87 |     C |        C |    3.0 |      231.0 |    0.745 | TFT?
#  88 |     D |        C |    5.0 |      236.0 |    0.632 | EXPLOITING
#  89 |     C |        D |    0.0 |      236.0 |    0.997 | TFT? EXPLOITED
#  90 |     C |        C |    3.0 |      239.0 |    0.829 |
#  91 |     C |        C |    3.0 |      242.0 |    0.734 | TFT?
#  92 |     C |        C |    3.0 |      245.0 |    0.672 | TFT?
#  93 |     C |        C |    3.0 |      248.0 |    0.536 | TFT?
#  94 |     C |        C |    3.0 |      251.0 |    0.632 | TFT?
#  95 |     C |        C |    3.0 |      254.0 |    0.652 | TFT?
#  96 |     C |        C |    3.0 |      257.0 |    0.785 | TFT?
#  97 |     C |        C |    3.0 |      260.0 |    0.682 | TFT?
#  98 |     C |        C |    3.0 |      263.0 |    0.625 | TFT?
#  99 |     C |        C |    3.0 |      266.0 |    0.557 | TFT?
# 100 |     D |        C |    5.0 |      271.0 |    0.524 | EXPLOITING
#
# 🤖 GEMINI ANALYSIS    (Step 100)
# ------------------------------------------------------------
# Here's an analysis of the PPO agent's learned strategy in the Prisoner's Dilemma, focusing on the interplay between behavioral observations and the PPO learning metrics:
#
# 1.  **Policy Learning Assessment**: The PPO policy network has learned to mostly cooperate, evidenced by the 74% cooperation rate. The decision probabilities in the last 15 moves show a fluctuating yet generally cooperative inclination, with values hovering mostly above 0.5 (probability of cooperation). However, there is some randomness present. The policy isn't fully deterministic, as indicated by the probability variance.
#
# 2.  **Value Function Understanding**: N/A - There is no info about value function.
#
# 3.  **Exploration vs. Exploitation Balance**: The agent seems to be primarily exploiting a learned strategy, but some exploration remains. The probability variance (0.0178) suggests a moderate degree of exploration, preventing the policy from becoming entirely fixed. This exploration might be beneficial in adapting to slight variations in the opponent's behavior.
#
# ...
#     *   Reward trend is declining
#
# 7.  **Risk and Uncertainty**: The agent handles uncertainty with a generally cautious but not entirely trusting approach. The high cooperation rate and streak of cooperations suggests a default of cooperation, but the defect decisions demonstrate it's not purely altruistic. The recent reward variance of 3.188 may be partly due to these occasional defect decisions or responses to the opponent's moves.
#
# 8. **Final Policy Assessment**: The learned policy is moderately sophisticated. It involves cooperation, but it's more forgiving than tit-for-tat as it is cooperating more after the opponent defects than when they cooperate, suggesting that it isn't merely mimicking the opponent's previous move. However, its reliance on cooperation and the declining reward trend suggests the agent could be exploited by a purely defective agent.
#
# ------------------------------------------------------------
#
# 📋 CONTINUING STEP LOG:
# Step | Agent | Opponent | Reward | Cumulative | P(Coop)  | Notes
# --------------------------------------------------------------------------------
# 401 |     C |        C |    3.0 |     1106.0 |    0.717 | TFT?
# 402 |     D |        C |    5.0 |     1111.0 |    0.826 | EXPLOITING
# 403 |     C |        D |    0.0 |     1111.0 |    0.990 | TFT? EXPLOITED
# 404 |     D |        C |    5.0 |     1116.0 |    0.648 | TFT? EXPLOITING
# 405 |     C |        D |    0.0 |     1116.0 |    0.986 | TFT? EXPLOITED
# 406 |     C |        C |    3.0 |     1119.0 |    0.871 |
# 407 |     C |        C |    3.0 |     1122.0 |    0.717 | TFT?
# 408 |     C |        C |    3.0 |     1125.0 |    0.692 | TFT?
# 409 |     D |        C |    5.0 |     1130.0 |    0.682 | EXPLOITING
# 410 |     C |        D |    0.0 |     1130.0 |    0.973 | TFT? EXPLOITED
# 411 |     C |        C |    3.0 |     1133.0 |    0.729 |
# 412 |     C |        C |    3.0 |     1136.0 |    0.671 | TFT?
# 413 |     C |        C |    3.0 |     1139.0 |    0.581 | TFT?
# 414 |     C |        C |    3.0 |     1142.0 |    0.826 | TFT?
# 415 |     D |        C |    5.0 |     1147.0 |    0.739 | EXPLOITING
# 416 |     C |        D |    0.0 |     1147.0 |    0.997 | TFT? EXPLOITED
# 417 |     C |        C |    3.0 |     1150.0 |    0.829 |
# 418 |     C |        C |    3.0 |     1153.0 |    0.734 | TFT?
# 419 |     C |        C |    3.0 |     1156.0 |    0.672 | TFT?
# 420 |     C |        C |    3.0 |     1159.0 |    0.536 | TFT?
# 421 |     C |        C |    3.0 |     1162.0 |    0.632 | TFT?
# 422 |     C |        C |    3.0 |     1165.0 |    0.652 | TFT?
# 423 |     C |        C |    3.0 |     1168.0 |    0.785 | TFT?
# 424 |     C |        C |    3.0 |     1171.0 |    0.682 | TFT?
# 425 |     D |        C |    5.0 |     1176.0 |    0.625 | EXPLOITING
# 426 |     C |        D |    0.0 |     1176.0 |    0.997 | TFT? EXPLOITED
# 427 |     C |        C |    3.0 |     1179.0 |    0.848 |
# 428 |     D |        C |    5.0 |     1184.0 |    0.780 | EXPLOITING
# 429 |     C |        D |    0.0 |     1184.0 |    0.998 | TFT? EXPLOITED
# 430 |     C |        C |    3.0 |     1187.0 |    0.747 |
# 431 |     C |        C |    3.0 |     1190.0 |    0.853 | TFT?
# 432 |     C |        C |    3.0 |     1193.0 |    0.622 | TFT?
# 433 |     C |        C |    3.0 |     1196.0 |    0.824 | TFT?
# 434 |     C |        C |    3.0 |     1199.0 |    0.617 | TFT?
# 435 |     C |        C |    3.0 |     1202.0 |    0.720 | TFT?
# 436 |     C |        C |    3.0 |     1205.0 |    0.635 | TFT?
# 437 |     C |        C |    3.0 |     1208.0 |    0.682 | TFT?
# 438 |     C |        C |    3.0 |     1211.0 |    0.625 | TFT?
# 439 |     C |        C |    3.0 |     1214.0 |    0.557 | TFT?
# 440 |     D |        C |    5.0 |     1219.0 |    0.524 | EXPLOITING
# 441 |     C |        D |    0.0 |     1219.0 |    0.998 | TFT? EXPLOITED
# 442 |     C |        C |    3.0 |     1222.0 |    0.848 |
# 443 |     C |        C |    3.0 |     1225.0 |    0.780 | TFT?
# 444 |     C |        C |    3.0 |     1228.0 |    0.739 | TFT?
# 445 |     C |        C |    3.0 |     1231.0 |    0.745 | TFT?
# 446 |     C |        C |    3.0 |     1234.0 |    0.632 | TFT?
# 447 |     D |        C |    5.0 |     1239.0 |    0.652 | EXPLOITING
# 448 |     C |        D |    0.0 |     1239.0 |    0.991 | TFT? EXPLOITED
# 449 |     C |        C |    3.0 |     1242.0 |    0.838 |
# 450 |     C |        C |    3.0 |     1245.0 |    0.729 | TFT?
# 451 |     C |        C |    3.0 |     1248.0 |    0.619 | TFT?
# 452 |     D |        C |    5.0 |     1253.0 |    0.745 | EXPLOITING
# 453 |     C |        D |    0.0 |     1253.0 |    0.993 | TFT? EXPLOITED
# 454 |     D |        C |    5.0 |     1258.0 |    0.648 | TFT? EXPLOITING
# 455 |     C |        D |    0.0 |     1258.0 |    0.986 | TFT? EXPLOITED
# 456 |     C |        C |    3.0 |     1261.0 |    0.871 |
# 457 |     C |        C |    3.0 |     1264.0 |    0.717 | TFT?
# 458 |     C |        C |    3.0 |     1267.0 |    0.692 | TFT?
# 459 |     C |        C |    3.0 |     1270.0 |    0.682 | TFT?
# 460 |     C |        C |    3.0 |     1273.0 |    0.821 | TFT?
# 461 |     C |        C |    3.0 |     1276.0 |    0.801 | TFT?
# 462 |     C |        C |    3.0 |     1279.0 |    0.702 | TFT?
# 463 |     C |        C |    3.0 |     1282.0 |    0.707 | TFT?
# 464 |     C |        C |    3.0 |     1285.0 |    0.625 | TFT?
# 465 |     D |        C |    5.0 |     1290.0 |    0.557 | EXPLOITING
# 466 |     C |        D |    0.0 |     1290.0 |    0.998 | TFT? EXPLOITED
# 467 |     C |        C |    3.0 |     1293.0 |    0.848 |
# 468 |     C |        C |    3.0 |     1296.0 |    0.780 | TFT?
# 469 |     C |        C |    3.0 |     1299.0 |    0.739 | TFT?
# 470 |     D |        C |    5.0 |     1304.0 |    0.745 | EXPLOITING
# 471 |     C |        D |    0.0 |     1304.0 |    0.993 | TFT? EXPLOITED
# 472 |     C |        C |    3.0 |     1307.0 |    0.648 |
# 473 |     C |        C |    3.0 |     1310.0 |    0.864 | TFT?
# 474 |     C |        C |    3.0 |     1313.0 |    0.717 | TFT?
# 475 |     C |        C |    3.0 |     1316.0 |    0.826 | TFT?
# 476 |     C |        C |    3.0 |     1319.0 |    0.739 | TFT?
# 477 |     D |        C |    5.0 |     1324.0 |    0.652 | EXPLOITING
# 478 |     C |        D |    0.0 |     1324.0 |    0.991 | TFT? EXPLOITED
# 479 |     C |        C |    3.0 |     1327.0 |    0.838 |
# 480 |     C |        C |    3.0 |     1330.0 |    0.729 | TFT?
# 481 |     C |        C |    3.0 |     1333.0 |    0.619 | TFT?
# 482 |     C |        C |    3.0 |     1336.0 |    0.745 | TFT?
# 483 |     C |        C |    3.0 |     1339.0 |    0.632 | TFT?
# 484 |     C |        C |    3.0 |     1342.0 |    0.652 | TFT?
# 485 |     C |        C |    3.0 |     1345.0 |    0.785 | TFT?
# 486 |     C |        C |    3.0 |     1348.0 |    0.682 | TFT?
# 487 |     D |        C |    5.0 |     1353.0 |    0.625 | EXPLOITING
# 488 |     C |        D |    0.0 |     1353.0 |    0.997 | TFT? EXPLOITED
# 489 |     C |        C |    3.0 |     1356.0 |    0.848 |
# 490 |     C |        C |    3.0 |     1359.0 |    0.780 | TFT?
# 491 |     C |        C |    3.0 |     1362.0 |    0.739 | TFT?
# 492 |     D |        C |    5.0 |     1367.0 |    0.745 | EXPLOITING
# 493 |     C |        D |    0.0 |     1367.0 |    0.993 | TFT? EXPLOITED
# 494 |     C |        C |    3.0 |     1370.0 |    0.648 |
# 495 |     C |        C |    3.0 |     1373.0 |    0.864 | TFT?
# 496 |     C |        C |    3.0 |     1376.0 |    0.717 | TFT?
# 497 |     D |        C |    5.0 |     1381.0 |    0.826 | EXPLOITING
# 498 |     C |        D |    0.0 |     1381.0 |    0.990 | TFT? EXPLOITED
# 499 |     C |        C |    3.0 |     1384.0 |    0.648 |
# 500 |     C |        C |    3.0 |     1387.0 |    0.864 | TFT?
#
# 🤖 GEMINI ANALYSIS    (Step 500)
# ------------------------------------------------------------
# Here's an analysis of the PPO agent's learned strategy in the Prisoner's Dilemma, integrating behavioral and internal RL metrics:
#
# *   **Policy Learning Assessment:** The agent's decision probabilities from the policy network are generally high (mostly above 0.7) and the decision confidence trend is high indicating it is frequently leaning towards cooperation. Given the low probability variance (0.0148), the agent is becoming more deterministic and exploiting learned strategies rather than actively exploring. The policy is not becoming fully deterministic though, as values fluctuate between 0.625 and 0.997, but still suggests a bias for cooperation.
#
# *   **Exploration vs Exploitation Balance**: The relatively low probability variance and the high decision confidence trend suggests the agent is largely exploiting a learned strategy. The policy entropy is unavailable but would have been useful to see if the agent has stopped exploring entirely or not.
#
# *   **Opponent Modeling:** The agent is playing against a *Tit-for-Tat* opponent. Although the agent cooperates a substantial amount of time, the *Cooperate after Opponent Defects* metric is relatively high at 80%, and the agent only adheres to the same move as the opponent in 66.3% of cases. It is attempting to cooperate even when the *Tit-for-Tat* strategy would suggest it defect. This is likely due to the higher potential reward for mutual cooperation and the possibility to take advantage of the opponent who will go back to cooperating.
#
# *   **Policy Gradient Insights**: The agent's high and consistent decision probabilities, along with low probability variance, suggests that the policy is converging to a stable strategy, in other words, it has plateaued. The consistent decision probabilities means the agent is less likely to change its behavior drastically based on short-term rewards or fluctuations in the environment.
#
# *   **Risk and Uncertainty**: The agent is generally cautiously cooperative, defaulting to cooperation even after the opponent defects 80% of the time. The declining reward trend and reward variance, however, suggest that this level of cooperation is coming at a cost. The variance shows that sometimes the strategy pays off, but overall the reward is trending downwards, meaning it is not sustainable against a *Tit-for-Tat* opponent.
#
# *   **Final Policy Assessment**: The agent has learned a moderately sophisticated policy. It appears to attempt a "forgiving" version of *Tit-for-Tat*. It mostly cooperates, adhering to Tit-for-Tat roughly 2/3 of the time, but sometimes cooperates even after the opponent defects. This strategy likely aims to maximize mutual cooperation rewards but is exploitable in the long run by the *Tit-for-Tat* opponent, as evidenced by the declining reward trend. The policy is reasonably robust in that it maintains a level of cooperation and doesn't devolve into constant defection, but it's not optimally exploiting the Tit-for-Tat opponent.
#
# ------------------------------------------------------------
#
# 📋 CONTINUING STEP LOG:
# Step | Agent | Opponent | Reward | Cumulative | P(Coop)  | Notes
# --------------------------------------------------------------------------------
#
# 📊 MATCH SUMMARY:
# Agent: PPO_vs_tit_for_tat_test
# Total Reward: 1387.0
# Average Reward per Episode: 2.77
# Agent Cooperation Rate: 79.0%
# Opponent Cooperation Rate: 79.0%
#
# ================================================================================
# 🧠 COMPREHENSIVE GEMINI STRATEGY ANALYSIS
# ================================================================================
# Based on the provided data, we can analyze the PPO agent's learning in the Prisoner's Dilemma, specifically against a Tit-for-Tat opponent.
#
# **Policy Generalization:**
#
# Since we only have data for one opponent (Tit-for-Tat), we can't assess policy generalization *across* opponents. However, we *can* analyze how the PPO agent adapted *specifically* to the Tit-for-Tat strategy. The PPO agent achieved a total reward of 1387.0, with a cooperation rate of 0.79, mirroring the Tit-for-Tat opponent's cooperation rate. The final probabilities show the agent tends to cooperate often, with probabilities generally over 0.70, even exceeding 0.98 in some cases. This strongly suggests that the PPO agent learned that cooperating with Tit-for-Tat is beneficial. Tit-for-Tat cooperates unless the opponent defects, so the PPO agent learned to mostly cooperate to maintain mutual cooperation and avoid cycles of defection. The probabilities aren't uniformly 1, suggesting a small degree of continued exploration or a learned strategy of occasional defection to test the opponent.
#
# **Multi-Task Learning:**
#
# With data available for only one environment (Tit-for-Tat), we cannot analyze multi-task learning.
#
# **Value Function Accuracy:**
#
# Because the PPO agent is achieving a good score against Tit-for-Tat, we can infer that the value function estimation is reasonably accurate in predicting the long-term consequences of cooperation and defection in this specific scenario. The high cooperation rate suggests the value function correctly assigns a high value to continued cooperation. If the value function underestimated the benefit of cooperation, we'd expect a lower cooperation rate.
#
# **Policy Gradient Effectiveness:**
#
# The PPO agent effectively used policy gradients to learn the appropriate action probabilities. The cooperation rate of 0.79 indicates that PPO learned to differentiate between the context of interacting with Tit-for-Tat (where cooperation is generally rewarded) and other potential scenarios (not analyzed here) where defection might be more advantageous. The probabilities indicate the learned policy successfully adjusted its behavior to the opponent's strategy.
#
# **Strategic Sophistication:**
#
# The PPO agent learned a relatively simple but effective reactive strategy. It discovered that mimicking the Tit-for-Tat behavior, or more accurately, predominantly cooperating, leads to a good outcome. This is not necessarily a complex multi-step reasoning process but rather a learned adaptation to the immediate rewards and punishments associated with cooperation and defection when playing against Tit-for-Tat.
#
# **Robustness Analysis:**
#
# Since the agent only played against Tit-for-Tat, we can't assess the robustness of its strategy. A high variance in performance *across* multiple opponents would indicate overfitting or instability, but we don't have that data.
#
# **Exploitation vs Cooperation Trade-off:**
#
# Against Tit-for-Tat, PPO primarily learned cooperation is the superior strategy, which aligns with the classic game theory solution. It seems to have resolved the exploration-exploitation dilemma by initially exploring defection but eventually converging to a predominantly cooperative policy. The small number of actions where the cooperation probability is lower may suggest occasional attempts to exploit Tit-for-Tat (which would likely be met with retaliation).
#
# **Learning Efficiency:**
#
# PPO likely learned the effectiveness of cooperation quickly against Tit-for-Tat. The relative simplicity of the Tit-for-Tat strategy makes it easy for a reinforcement learning agent to model and adapt to. The consistent positive reward signal obtained through cooperation likely guided the learning process efficiently.
#
# **Final Assessment:**
#
# Against Tit-for-Tat, the PPO agent learned a strategy that resembles a slightly more forgiving version of Tit-for-Tat itself. While not demonstrating deep strategic reasoning, it effectively adapted to the opponent's behavior and achieved a favorable outcome. It mimics human behavior in the sense that humans also tend to cooperate with cooperative individuals. A human expert would likely employ a similar strategy, especially if aware of the opponent's Tit-for-Tat strategy.
#
#
# ================================================================================
# 📊 FINAL PPO PERFORMANCE SUMMARY
# ================================================================================
#          tit_for_tat: 1387.0 pts | Avg:  2.77 | Coop: 79.0% | vs 79.0% opp
